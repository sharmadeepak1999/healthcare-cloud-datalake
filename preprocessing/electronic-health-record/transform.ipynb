# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Reading data from the SPARCS dataset into a dataframe

# %%
data = pd.read_csv("../../datasets/electronic_health_record/input/electronic_health_record_dataset.csv", low_memory=False)

# %%
health_data = data.copy()

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061634 entries, 0 to 2061633
# Data columns (total 33 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   Hospital Service Area                object
#  1   Hospital County                      object
#  2   Operating Certificate Number         float64
#  3   Permanent Facility Id                float64
#  4   Facility Name                        object
#  5   Age Group                            object
#  6   Zip Code - 3 digits                  object
#  7   Gender                               object
#  8   Race                                 object
#  9   Ethnicity                            object
#  10  Length of Stay                       object
#  11  Type of Admission                    object
#  12  Patient Disposition                  object
#  13  Discharge Year                       int64
#  14  CCSR Diagnosis Code                  object
#  15  CCSR Diagnosis Description           object
#  16  CCSR Procedure Code                  object
#  17  CCSR Procedure Description           object
#  18  APR DRG Code                         int64
#  19  APR DRG Description                  object
#  20  APR MDC Code                         int64
#  21  APR MDC Description                  object
#  22  APR Severity of Illness Code         int64
#  23  APR Severity of Illness Description  object
#  24  APR Risk of Mortality                object
#  25  APR Medical Surgical Description     object
#  26  Payment Typology 1                   object
#  27  Payment Typology 2                   object
#  28  Payment Typology 3                   object
#  29  Birth Weight                         object
#  30  Emergency Department Indicator       object
#  31  Total Charges                        object
#  32  Total Costs                          object
# dtypes: float64(2), int64(4), object(27)
# memory usage: 519.1+ MB

# %% [markdown]
# Attributes and unique value present in them

# %%
def print_unique_values(dataframe):
    for col in dataframe.columns:
        print(f"{col}:\n{dataframe[col].unique()}", end="\n\n")

# %%
print_unique_values(health_data)
# Out:
# Hospital Service Area:
# ['New York City' 'Hudson Valley' nan 'Long Island' 'Capital/Adirond'
#  'Central NY' 'Finger Lakes' 'Western NY' 'Southern Tier']
#
# Hospital County:
# ['Bronx' 'Rockland' nan 'Manhattan' 'Westchester' 'Kings' 'Queens'
#  'Orange' 'Nassau' 'Sullivan' 'Otsego' 'Herkimer' 'Delaware' 'Monroe'
#  'Ontario' 'Cortland' 'Columbia' 'Albany' 'Suffolk' 'Onondaga' 'Madison'
#  'Steuben' 'Cayuga' 'Montgomery' 'Erie' 'Jefferson' 'Oswego' 'Yates'
#  'Wayne' 'Genesee' 'Schoharie' 'Ulster' 'Oneida' 'Schenectady' 'Broome'
#  'St Lawrence' 'Schuyler' 'Richmond' 'Niagara' 'Chemung' 'Essex'
#  'Chautauqua' 'Dutchess' 'Putnam' 'Chenango' 'Tompkins' 'Warren' 'Fulton'
#  'Wyoming' 'Franklin' 'Cattaraugus' 'Saratoga' 'Lewis' 'Livingston'
#  'Allegany' 'Orleans' 'Clinton']
#
# Operating Certificate Number:
# [7000006. 4324000.      nan 7002054. 7002002. 7002032. 5902001. 7001016.
#  7002001. 7000024. 7002024. 7000002. 7001009. 7002050. 7000008. 7002021.
#  7003007. 7003000. 7002009. 7001045. 5903001. 5904001. 3522000. 5902002.
#  4329000. 3529000. 3535001. 7002053. 2908000. 3523000. 5263000. 2950002.
#  4322000. 3801000. 2129700. 1254700. 3824000. 7001037. 2701001. 7003010.
#  3429000. 5907001. 2701005. 1101000. 5907002. 1001000.  101000. 7001021.
#  5127000. 3301008. 2625700. 5123000. 5001000. 7000001. 7000011. 7001003.
#   501000. 5957000. 2801001. 7003003. 7003001. 1401005. 7002012. 2201000.
#  3702000. 2754001. 6120700. 5820000. 1801000. 3421000. 2701003. 3402000.
#  5149000. 5501001. 1226701. 3202002. 4601001. 3202003.  301001. 4423701.
#  4823700. 7002026. 7004003. 1404000. 1401008. 3121001. 1401013.  701000.
#  4458701. 5151001. 4402000.  701001. 5022000. 2951001. 2901000. 1401010.
#  7003004. 5154000. 7002017. 5155000. 3301003. 5932000. 2952005. 5922000.
#  1552701. 5153000.  602001.  303001. 1302001. 1229700. 1327000. 2601001.
#  3950000.  824000. 3102000. 5401001. 4429000. 5601000. 5957001. 7001020.
#   632000. 5920000. 1701000. 5526700. 4401000. 7002020. 2950001. 7004010.
#  6027000. 3301007.  601000. 3101000. 1623001.  401001. 7001024. 4501000.
#  3201002. 2424700. 5002001. 1427000. 7000014. 7001035. 2953000. 2238700.
#  5154001. 1401014. 5157003. 2527000. 5263700.  228000. 2909000. 2952006.
#  2221700. 7001002. 7001046. 5149001. 5901000. 7001008. 3622700.  901001.
#  4402001.  226700. 4720700. 5501000. 1624000.]
#
# Permanent Facility Id:
# [3.0580e+03 1.1680e+03 1.1690e+03 7.7600e+02        nan 3.9750e+03
#  1.4390e+03 1.4660e+03 1.0450e+03 1.4640e+03 1.3010e+03 1.4380e+03
#  1.1860e+03 1.4560e+03 1.1650e+03 1.2940e+03 1.3240e+03 1.4860e+03
#  1.1720e+03 1.4540e+03 1.6330e+03 1.6260e+03 1.4450e+03 1.6920e+03
#  1.0610e+03 1.0720e+03 1.0470e+03 1.4370e+03 1.4580e+03 6.9400e+02
#  1.0460e+03 7.7900e+02 7.0400e+02 7.0800e+02 1.4690e+03 1.1220e+03
#  1.4460e+03 5.1100e+02 1.3040e+03 1.4630e+03 6.9900e+02 9.7100e+02
#  5.2800e+02 7.7500e+02 7.3900e+02 3.6200e+02 1.6500e+02 7.4600e+02
#  1.3200e+03 4.0900e+02 1.6370e+03 6.7800e+02 1.0990e+03 1.1240e+03
#  4.1300e+02 1.5800e+02 1.1330e+03 1.4600e+02 2.0000e+00 1.0000e+00
#  1.3060e+03 8.9100e+02 6.3600e+02 9.0590e+03 4.0100e+02 8.8500e+02
#  8.6600e+02 1.1780e+03 1.1640e+03 1.1750e+03 1.2880e+03 8.5000e+01
#  1.1380e+03 4.8200e+02 1.6290e+03 1.0970e+03 1.6280e+03 2.1000e+02
#  1.4470e+03 3.6700e+02 1.2000e+01 4.1200e+02 1.1580e+03 1.0280e+03
#  3.3900e+02 4.7100e+02 6.7600e+02 3.4000e+02 4.1100e+02 7.2700e+02
#  6.7100e+02 8.9500e+02 1.0216e+04 9.9000e+02 1.7000e+02 5.9800e+02
#  8.2900e+02 5.9900e+02 4.3000e+01 8.1200e+02 8.5800e+02 1.4600e+03
#  1.7400e+03 2.6700e+02 2.1300e+02 5.8300e+02 2.1800e+02 1.7370e+03
#  2.9200e+02 1.1600e+02 8.1700e+02 8.8900e+02 8.0400e+02 1.1800e+02
#  8.7300e+02 5.5000e+02 5.4100e+02 4.9000e+02 2.1600e+02 1.6380e+03
#  9.2400e+02 1.4500e+03 9.3800e+02 1.0980e+03 5.1800e+02 6.3000e+02
#  1.1290e+03 5.5200e+02 4.8400e+02 3.0300e+02 9.1300e+02 1.0300e+02
#  5.8000e+01 1.8100e+02 1.7400e+02 1.9200e+02 3.9700e+02 7.5200e+02
#  4.2000e+01 1.2800e+02 5.7400e+02 9.7700e+02 8.1500e+02 1.0050e+03
#  1.8000e+02 1.3050e+03 1.1100e+02 1.1390e+03 3.3760e+03 1.6300e+03
#  1.1170e+03 2.4500e+02 3.3000e+02 1.0020e+03 7.9800e+02 1.4530e+03
#  5.2700e+02 1.7380e+03 1.0355e+04 1.1530e+03 6.2800e+02 9.8000e+01
#  5.6500e+02 3.2400e+02 6.6000e+01 1.6350e+03 6.3500e+02 8.1800e+02
#  5.8900e+02 3.8300e+02 8.7000e+02 2.8000e+02 1.1760e+03 1.3180e+03
#  5.6300e+02 3.7900e+02 8.4800e+02 9.2500e+02 3.0670e+03 2.0700e+02
#  2.0800e+02 9.4300e+02 3.9300e+02 9.6800e+02 3.9000e+01 5.1300e+02
#  5.5100e+02 3.7700e+02 1.2860e+03 1.3090e+03 8.9600e+02 1.0390e+03
#  1.2930e+03 7.1800e+02 1.3500e+02 1.6390e+03 1.3150e+03 3.7000e+01
#  1.0223e+04 1.0139e+04 9.8900e+02 3.2500e+02]
#
# Facility Name:
# ['Montefiore Med Center - Jack D Weiler Hosp of A Einstein College Div'
#  'Montefiore Medical Center-Wakefield Hospital'
#  'Montefiore Medical Center - Henry & Lucy Moses Div' 'Montefiore Nyack'
#  'Redacted for Confidentiality'
#  'New York Presbyterian Hospital - Allen Hospital'
#  'Mount Sinai Beth Israel' 'Mount Sinai West'
#  'White Plains Hospital Center'
#  'New York-Presbyterian Hospital - Columbia Presbyterian Center'
#  'Kings County Hospital Center' 'Bellevue Hospital Center'
#  'North Central Bronx Hospital' 'Mount Sinai Hospital'
#  'Jacobi Medical Center' 'Coney Island Hospital' 'Mount Sinai Brooklyn'
#  'Henry J. Carter Specialty Hospital'
#  'Lincoln Medical & Mental Health Center' 'Metropolitan Hospital Center'
#  'Queens Hospital Center' 'Elmhurst Hospital Center'
#  'Harlem Hospital Center' 'Woodhull Medical & Mental Health Center'
#  'Montefiore Mount Vernon Hospital' 'Montefiore New Rochelle Hospital'
#  'New York-Presbyterian Westchester Behavioral Health Center'
#  'New York-Presbyterian/Lower Manhattan Hospital'
#  'New York-Presbyterian Hospital - New York Weill Cornell Center'
#  "St Luke's Cornwall Hospital/Newburgh"
#  'Winifred Masterson Burke Rehabilitation Hospital'
#  'Good Samaritan Hospital of Suffern' 'St Anthony Community Hospital'
#  'Bon Secours Community Hospital' 'Mount Sinai Morningside'
#  'New York - Presbyterian Hospital' 'NYU Langone Orthopedic Hospital'
#  'NYU Langone Hospital-Long Island' 'NYU Langone Hospital-Brooklyn'
#  'NYU Langone Hospitals' 'Garnet Health Medical Center'
#  'Garnet Health Medical Center - Catskills'
#  'Nassau University Medical Center' 'Helen Hayes Hospital'
#  'A.O. Fox Memorial Hospital' 'Little Falls Hospital' "O'Connor Hospital"
#  'Mary Imogene Bassett Hospital' 'University Hospital of Brooklyn'
#  'Highland Hospital' 'New York - Presbyterian/Queens'
#  'F.F. Thompson Hospital' 'SJRH - Park Care Pavilion'
#  'SJRH - Dobbs Ferry Pavillion' 'Strong Memorial Hospital'
#  'Guthrie Cortland Medical Center'
#  "St. Joseph's MC-St. Vincent's Westchester Division"
#  'Columbia Memorial Hospital'
#  'Albany Medical Center - South Clinical Campus'
#  'Albany Medical Center Hospital'
#  'New York - Presbyterian Brooklyn Methodist Hospital'
#  'Stony Brook Eastern Long Island Hospital' 'Crouse Hospital'
#  'Crouse Hospital - Commonwealth Division'
#  'Community Memorial Hospital Inc' 'Long Island Community Hospital'
#  'Corning Hospital' 'BronxCare Hospital Center' 'Calvary Hospital Inc'
#  'Brooklyn Hospital Center - Downtown Campus' 'Auburn Community Hospital'
#  "Blythedale Children's Hospital"
#  "St. Mary's Healthcare - Amsterdam Memorial Campus"
#  'Jamaica Hospital Medical Center' 'SJRH - St Johns Division'
#  'Flushing Hospital Medical Center' 'Erie County Medical Center'
#  'Hospital for Special Surgery' 'Samaritan Medical Center'
#  'Lakeview Center for Mental Health and Wellness'
#  'Unity Specialty Hospital'
#  'Soldiers and Sailors Memorial Hospital of Yates County'
#  'Newark-Wayne Community Hospital'
#  'United Memorial Medical Center North Street Campus'
#  'The Unity Hospital of Rochester' 'Clifton Springs Hospital and Clinic'
#  'United Memorial Medical Center Bank Street Campus'
#  'Rochester General Hospital' 'Oswego Hospital' 'Geneva General Hospital'
#  'John T Mather Memorial Hospital of Port Jefferson New York Inc'
#  'Cobleskill Regional Hospital' 'HealthAlliance Hospital Broadway Campus'
#  'Margaretville Hospital' 'St Elizabeth Medical Center' 'Ellis Hospital'
#  'Faxton-St Lukes Healthcare St Lukes Division'
#  'Our Lady of Lourdes Memorial Hospital' 'Gouverneur Hospital'
#  'Schuyler Hospital' 'New York Eye and Ear Infirmary of Mount Sinai'
#  'Staten Island University Hosp-North' 'Kenmore Mercy Hospital'
#  'Mercy Hospital of Buffalo' "Mount St. Mary's Hospital and Health Center"
#  'Sisters of Charity Hospital'
#  "Staten Island University Hospital Prince's Bay"
#  'Sisters of Charity Hospital - St. Joseph Campus'
#  'Arnot Ogden Medical Center' 'Clifton-Fine Hospital'
#  'Stony Brook Southampton Hospital' 'Massena Hospital'
#  "St. Joseph's Hospital" 'Ira Davenport Memorial Hospital'
#  'Syosset Hospital' 'North Shore University Hospital' 'Glen Cove Hospital'
#  'Roswell Park Cancer Institute' 'Long Island Jewish Forest Hills'
#  'South Shore University Hospital' 'Lenox Hill Hospital'
#  'Peconic Bay Medical Center' "St. Joseph's Medical Center"
#  'Long Island Jewish Valley Stream' "St. Joseph's Hospital Health Center"
#  'Phelps Hospital' 'Plainview Hospital' "St. Mary's Healthcare"
#  'The University of Vermont Health Network - Elizabethtown Community Hospital'
#  'Huntington Hospital' 'UPMC Chautauqua at WCA'
#  'United Health Services Hospitals Inc. - Wilson Medical Center'
#  'Vassar Brothers Medical Center' 'Delaware Valley Hospital Inc'
#  'Northern Dutchess Hospital' 'Oneida Health Hospital' 'Putnam Hospital'
#  'United Health Services Hospitals Inc. - Binghamton General Hospital'
#  'Chenango Memorial Hospital Inc' 'Niagara Falls Memorial Medical Center'
#  'Cayuga Medical Center at Ithaca' 'Canton-Potsdam Hospital'
#  'Glens Falls Hospital'
#  'Mid-Hudson Valley Division of Westchester Medical Center'
#  'Maimonides Medical Center' 'Westfield Memorial Hospital Inc'
#  'Westchester Medical Center' "Cohen Children's Medical Center"
#  'Long Island Jewish Medical Center' 'Northern Westchester Hospital'
#  'Stony Brook University Hospital' 'Nathan Littauer Hospital'
#  'Ellenville Regional Hospital' 'Claxton-Hepburn Medical Center'
#  'Memorial Hospital for Cancer and Allied Diseases'
#  'Mount Sinai South Nassau' 'Richmond University Medical Center'
#  'David H. Koch Center For Cancer Care'
#  'Wyoming County Community Hospital'
#  'UPSTATE University Hospital at Community General'
#  'Brooks-TLC Hospital System, Inc.'
#  'Eastern Niagara Hospital - Lockport Division'
#  'Adirondack Medical Center-Saranac Lake Site' 'Olean General Hospital'
#  'St Johns Episcopal Hospital So Shore'
#  'University Hospital SUNY Health Science Center' 'Saratoga Hospital'
#  'Rome Memorial Hospital, Inc' 'Lewis County General Hospital'
#  'St. James Hospital' 'Bertrand Chaffee Hospital' 'SBH Health System'
#  'Wyckoff Heights Medical Center' 'St. Francis Hospital & Heart Center'
#  'Carthage Area Hospital Inc'
#  "Ellis Hospital - Bellevue Woman's Care Center Division"
#  'Good Samaritan Hospital Medical Center'
#  'Millard Fillmore Suburban Hospital' 'Buffalo General Medical Center'
#  "John R. Oishei Children's Hospital" 'St Catherine of Siena Hospital'
#  'Nicholas H. Noyes Memorial Hospital'
#  'Garnet Health Medical Center - Catskills - G. Hermann Site'
#  'Memorial Hosp of Wm F & Gertrude F Jones A/K/A Jones Memorial Hosp'
#  'Mercy Hospital' 'St. Joseph Hospital' 'River Hospital, Inc.'
#  'Brookdale Hospital Medical Center' 'Interfaith Medical Center'
#  'St. Charles Hospital' 'NewYork-Presbyterian/Hudson Valley Hospital'
#  'New York Community Hospital of Brooklyn, Inc' 'Medina Memorial Hospital'
#  'The University of Vermont Health Network - Champlain Valley Physicians Hospital'
#  'Mount Sinai Hospital - Mount Sinai Hospital of Queens'
#  'Kingsbrook Jewish Medical Center' 'Cuba Memorial Hospital Inc'
#  'Calvary Hospital' 'New York-Presbyterian David H. Koch Center'
#  "HealthAlliance Hospital Mary's Avenue Campus"
#  'The University of Vermont Health Network - Alice Hyde Medical Center']
#
# Age Group:
# ['50 to 69' '18 to 29' '0 to 17' '70 or Older' '30 to 49']
#
# Zip Code - 3 digits:
# ['107' '104' '100' '113' '125' '109' nan '108' '105' 'OOS' '111' '117'
#  '114' '115' '112' '106' '103' '101' '116' '110' '127' '119' '126' '118'
#  '128' '133' '121' '124' '120' '123' '130' '137' '136' '134' '138' '149'
#  '131' '135' '144' '146' '145' '148' '140' '147' '141' '142' '129' '132'
#  '143' '139' '122']
#
# Gender:
# ['F' 'M' 'U']
#
# Race:
# ['White' 'Black/African American' 'Other Race' 'Multi-racial']
#
# Ethnicity:
# ['Not Span/Hispanic' 'Spanish/Hispanic' 'Unknown' 'Multi-ethnic']
#
# Length of Stay:
# ['3' '1' '2' '4' '6' '17' '8' '11' '5' '13' '7' '21' '49' '31' '9' '120 +'
#  '22' '10' '20' '16' '23' '12' '29' '99' '19' '25' '34' '28' '65' '32'
#  '43' '36' '26' '83' '14' '15' '44' '41' '46' '64' '18' '89' '35' '42'
#  '45' '98' '110' '58' '48' '73' '52' '24' '54' '59' '40' '38' '116' '70'
#  '97' '50' '30' '77' '27' '101' '33' '86' '68' '100' '47' '78' '63' '55'
#  '61' '81' '37' '93' '84' '75' '53' '51' '57' '87' '71' '39' '80' '72'
#  '82' '95' '90' '69' '109' '67' '88' '96' '114' '56' '60' '66' '102' '62'
#  '106' '92' '119' '76' '85' '79' '74' '91' '107' '117' '111' '103' '113'
#  '108' '118' '94' '115' '112' '104' '105']
#
# Type of Admission:
# ['Emergency' 'Urgent' 'Elective' 'Newborn' 'Trauma' 'Not Available']
#
# Patient Disposition:
# ['Home or Self Care' 'Short-term Hospital' 'Left Against Medical Advice'
#  'Home w/ Home Health Services' 'Expired' 'Medicaid Cert Nursing Facility'
#  'Skilled Nursing Home' 'Psychiatric Hospital or Unit of Hosp'
#  'Inpatient Rehabilitation Facility' 'Hospice - Home'
#  'Facility w/ Custodial/Supportive Care' 'Hospice - Medical Facility'
#  'Medicare Cert Long Term Care Hospital'
#  "Cancer Center or Children's Hospital" 'Another Type Not Listed'
#  'Court/Law Enforcement' 'Federal Health Care Facility'
#  'Critical Access Hospital' 'Hosp Basd Medicare Approved Swing Bed']
#
# Discharge Year:
# [2022]
#
# CCSR Diagnosis Code:
# ['INF012' 'SKN001' 'PRG016' 'PRG022' 'MBD001' 'RSP005' 'EYE005' 'GEN002'
#  'INJ030' 'PRG023' 'NVS006' 'PRG024' 'PRG020' 'CIR008' 'NVS009' 'DIG004'
#  'MBD018' 'DIG001' 'RSP009' 'MBD017' 'PRG011' 'DIG010' 'DIG007' 'CIR019'
#  'DIG020' 'INF002' 'DIG022' 'PNL001' 'MUS011' 'PRG028' 'DIG019' 'INJ037'
#  'PRG013' 'INJ002' 'BLD005' 'END011' 'NVS011' 'SYM013' 'DIG025' 'CIR013'
#  'RSP006' 'CIR035' 'NVS010' 'CIR020' 'MUS002' 'INJ008' 'MBD008' 'GEN003'
#  'SKN007' 'INJ026' 'DIG024' 'FAC006' 'END009' 'MUS013' 'RSP002' 'GEN004'
#  'CIR036' 'END003' 'SYM001' 'NEO070' 'PRG005' 'DIG012' 'RSP017' 'SYM012'
#  'PRG029' 'END016' 'NVS018' 'PRG019' 'INJ034' 'INJ001' 'GEN006' 'CIR031'
#  'MUS026' 'CIR009' 'MBD003' 'MBD002' 'NEO066' 'NEO005' 'NEO058' 'INJ003'
#  'RSP003' 'INJ004' 'INJ005' 'DIG009' 'SYM006' 'DIG017' 'DIG013' 'SYM010'
#  'NEO039' 'CIR017' 'CIR001' 'INJ012' 'DIG003' 'PRG026' 'PRG018' 'INJ022'
#  'INJ006' 'DIG016' 'CIR033' 'EAR002' 'CIR021' 'MUS014' 'DIG021' 'INJ035'
#  'CIR025' 'RSP012' 'MBD025' 'INF008' 'RSP010' 'PRG012' 'MUS006' 'NEO013'
#  'INJ033' 'BLD001' 'RSP016' 'CIR003' 'SKN004' 'NVS002' 'CIR026' 'MAL008'
#  'RSP008' 'MAL004' 'NEO030' 'END001' 'CIR038' 'PRG014' 'INJ036' 'CIR014'
#  'SYM002' 'INF003' 'CIR012' 'CIR004' 'NEO010' 'CIR011' 'NEO035' 'EAR003'
#  'END012' 'SYM016' 'MUS009' 'DIG018' 'DIG005' 'GEN022' 'MUS023' 'SYM017'
#  'FAC010' 'MAL001' 'NEO017' 'GEN025' 'DIG002' 'NEO048' 'BLD004' 'MUS024'
#  'MBD007' 'MUS033' 'DIG023' 'DIG011' 'RSP014' 'NVS004' 'BLD003' 'NVS016'
#  'NEO015' 'NEO074' 'CIR023' 'INJ032' 'RSP013' 'NEO068' 'MBD004' 'GEN011'
#  'SYM007' 'NVS008' 'NEO022' 'NEO002' 'NVS015' 'CIR018' 'NEO065' 'NEO051'
#  'CIR029' 'INF006' 'MUS029' 'NVS020' 'MUS031' 'PRG017' 'NVS012' 'BLD006'
#  'NEO073' 'DIG015' 'CIR006' 'NVS017' 'PRG003' 'PRG027' 'BLD007' 'NEO060'
#  'RSP011' 'INF007' 'CIR024' 'SYM004' 'MUS016' 'SKN006' 'GEN007' 'SYM008'
#  'MBD021' 'RSP004' 'MUS028' 'INJ011' 'SYM015' 'INJ010' 'NEO049' 'MUS022'
#  'NEO064' 'INJ017' 'INJ031' 'FAC003' 'MUS038' 'GEN013' 'MUS010' 'SYM005'
#  'MBD014' 'DIG014' 'NVS007' 'GEN001' 'GEN005' 'MBD012' 'FAC025' 'MBD009'
#  'NVS014' 'INJ045' 'CIR030' 'END015' 'END013' 'GEN012' 'MBD005' 'PNL007'
#  'CIR039' 'EAR006' 'NEO043' 'INJ020' 'CIR005' 'CIR016' 'SYM014' 'RSP007'
#  'GEN018' 'MBD006' 'INJ042' 'NEO045' 'MAL010' 'INJ040' 'GEN017' 'FAC009'
#  'MUS037' 'CIR032' 'MUS021' 'INJ019' 'INF004' 'MUS001' 'SKN002' 'PRG006'
#  'CIR015' 'NVS021' 'BLD002' 'MBD019' 'EYE010' 'EYE006' 'INJ024' 'INJ025'
#  'NEO072' 'NEO029' 'BLD010' 'EYE012' 'NEO018' 'EYE008' 'INJ056' 'DIG008'
#  'NEO033' 'CIR027' 'PRG021' 'GEN016' 'GEN026' 'INJ021' 'PRG010' 'NVS001'
#  'NEO008' 'INF005' 'INJ043' 'INJ023' 'NEO057' 'NEO067' 'PNL013' 'NVS013'
#  'MUS025' 'INJ013' 'NVS005' 'SYM003' 'NVS019' 'PNL009' 'INJ073' 'EAR001'
#  'NEO031' 'PRG009' 'MUS007' 'CIR028' 'NEO012' 'INJ050' 'MUS003' 'CIR007'
#  'MBD011' 'GEN021' 'MBD010' 'MUS034' 'INJ027' 'PNL002' 'NEO014' 'MBD026'
#  'PRG004' 'NEO001' 'MAL002' 'PNL006' 'NEO024' 'NEO069' 'RSP001' 'END007'
#  'MAL007' 'NEO023' 'GEN019' 'PNL004' 'PNL012' 'INF010' 'MUS030' 'MBD020'
#  'MAL003' 'CIR022' 'PNL011' 'INJ016' 'SKN003' 'NEO037' 'DIG006' 'GEN009'
#  'NEO036' 'NEO050' 'NEO016' 'MBD013' 'NEO009' 'NEO006' 'NEO028' 'NEO025'
#  'BLD008' 'FAC004' 'INJ071' 'NEO004' 'NEO027' 'NEO034' 'CIR010' 'MUS008'
#  'INF001' 'END008' 'INJ061' 'SYM011' 'NEO021' 'NEO019' 'GEN008' 'PNL008'
#  'NEO071' 'MAL006' 'EYE001' 'INJ009' 'NEO059' 'INJ007' 'END010' 'MUS012'
#  'INJ041' 'MBD022' 'INJ018' 'NEO032' 'GEN020' 'INJ044' 'NEO047' 'NEO053'
#  'NEO062' 'RSP015' 'GEN023' 'FAC016' 'INJ039' 'FAC022' 'NEO040' 'EYE004'
#  'NEO052' 'INF009' 'NEO041' 'INJ060' 'NEO011' 'MUS017' 'INJ069' 'MUS015'
#  'INJ070' 'INJ072' 'INJ048' 'EYE003' 'END002' 'INJ051' 'NEO056' 'FAC008'
#  'NEO063' 'NEO054' 'NEO044' 'NEO038' 'INJ014' 'MUS018' 'INJ046' 'SKN005'
#  'MUS019' 'PNL005' 'MAL005' 'NEO020' 'NEO061' 'MUS027' 'PNL014' 'NVS003'
#  'END014' 'PRG015' 'NEO003' 'CIR034' 'PRG007' 'GEN014' 'EYE002' 'PNL010'
#  'MUS020' 'NEO007' 'PNL003' 'INJ047' 'BLD009' 'INJ015' 'INJ064' 'GEN015'
#  'MUS004' 'FAC014' 'NEO042' 'GEN010' 'INJ028' 'INJ063' 'INJ038' 'MUS032'
#  'INJ053' 'INJ049' 'FAC013' 'EAR005' 'NEO046' 'MAL009' 'INJ058' 'NEO055'
#  'EAR004' 'FAC007' 'NEO026' 'INJ059' 'MBD027' 'EYE007' 'CIR002' 'INJ057'
#  'MBD023' 'PRG025' 'PRG001' 'EYE011' 'INJ076' 'INJ054' 'INJ062' 'MUS036'
#  'INJ074' 'FAC020' 'NVS022' 'INJ068' 'INJ055' 'INJ075' 'GEN024' 'EYE009'
#  'MUS035' 'FAC002' 'INF011' 'MUS005' 'INJ067' 'MBD024' 'FAC012' 'XXX000']
#
# CCSR Diagnosis Description:
# ['COVID-19' 'Skin and subcutaneous tissue infections' 'Previous C-section'
#  'Prolonged pregnancy'
#  'Schizophrenia spectrum and other psychotic disorders' 'Acute bronchitis'
#  'Retinal and vitreous conditions' 'Acute and unspecified renal failure'
#  'Drug induced or toxic related condition'
#  'Complications specified during childbirth'
#  'Other nervous system disorders (often hereditary or degenerative)'
#  'Malposition, disproportion or other labor complications'
#  'Hypertension and hypertensive-related conditions complicating pregnancy; childbirth; and the puerperium'
#  'Hypertension with complications and secondary hypertension'
#  'Epilepsy; convulsions' 'Esophageal disorders' 'Opioid-related disorders'
#  'Intestinal infection' 'Asthma' 'Alcohol-related disorders'
#  'Early or threatened labor' 'Abdominal hernia' 'Gastritis and duodenitis'
#  'Heart failure' 'Pancreatic disorders (excluding diabetes)' 'Septicemia'
#  'Noninfectious gastroenteritis' 'Liveborn'
#  'Spondylopathies/spondyloarthropathy (including infective)'
#  'Other specified complications in pregnancy'
#  'Other specified and unspecified liver disease'
#  'Complication of other surgical or medical care, injury, initial encounter'
#  'Maternal care related to fetal conditions'
#  'Fracture of the spine and back, initial encounter'
#  'Sickle cell trait/anemia' 'Fluid and electrolyte disorders'
#  'Neurocognitive disorders' 'Respiratory signs and symptoms'
#  'Other specified and unspecified gastrointestinal disorders'
#  'Acute pulmonary embolism' 'Other specified upper respiratory infections'
#  'Varicose veins of lower extremity' 'Headache; including migraine'
#  'Cerebral infarction' 'Osteomyelitis'
#  'Traumatic brain injury (TBI); concussion, initial encounter'
#  'Disruptive, impulse-control and conduct disorders'
#  'Chronic kidney disease' 'Other specified and unspecified skin disorders'
#  'Other specified injury'
#  'Postprocedural or postoperative digestive system complication'
#  'Encounter for antineoplastic therapies' 'Obesity' 'Osteoporosis'
#  'Pneumonia (except that caused by tuberculosis)'
#  'Urinary tract infections'
#  'Postthrombotic syndrome and venous insufficiency/hypertension'
#  'Diabetes mellitus with complication' 'Syncope' 'Secondary malignancies'
#  'Ectopic pregnancy and complications of ectopic pregnancy'
#  'Intestinal obstruction and ileus'
#  'Postprocedural or postoperative respiratory system complication'
#  'Circulatory signs and symptoms'
#  'Uncomplicated pregnancy, delivery or puerperium'
#  'Other specified and unspecified nutritional and metabolic disorders'
#  'Myopathies'
#  'Diabetes or abnormal glucose tolerance complicating pregnancy; childbirth; or the puerperium'
#  'Complication of genitourinary device, implant or graft, initial encounter'
#  'Fracture of head and neck, initial encounter'
#  'Other specified and unspecified diseases of kidney and ureters'
#  'Hypotension' 'Muscle disorders' 'Acute myocardial infarction'
#  'Bipolar and related disorders' 'Depressive disorders'
#  'Malignant neuroendocrine tumors'
#  'Head and neck cancers - nasopharyngeal' 'Non-Hodgkin lymphoma'
#  'Fracture of torso, initial encounter' 'Influenza'
#  'Fracture of the upper limb, initial encounter'
#  'Fracture of the lower limb (except hip), initial encounter'
#  'Appendicitis and other appendiceal conditions'
#  'Abdominal pain and other digestive/abdomen signs and symptoms'
#  'Biliary tract disease' 'Diverticulosis and diverticulitis'
#  'Nervous system signs and symptoms'
#  'Male reproductive system cancers - prostate' 'Cardiac dysrhythmias'
#  'Chronic rheumatic heart disease'
#  'Open wounds to limbs, initial encounter'
#  'Diseases of mouth; excluding dental'
#  'OB-related trauma to perineum and vulva'
#  'Maternal care related to disorders of the placenta and placental implantation'
#  'Poisoning by drugs, initial encounter'
#  'Fracture of the neck of the femur (hip), initial encounter'
#  'Peritonitis and intra-abdominal abscess'
#  'Acute phlebitis; thrombophlebitis and thromboembolism'
#  'Diseases of middle ear and mastoid (except otitis media)'
#  'Acute hemorrhagic cerebrovascular disease'
#  'Pathological fracture, initial encounter' 'Gastrointestinal hemorrhage'
#  'Complication of internal orthopedic device or implant, initial encounter'
#  'Sequela of cerebral infarction and other cerebrovascular disease'
#  'Respiratory failure; insufficiency; arrest'
#  'Other specified substance-related disorders' 'Viral infection'
#  'Aspiration pneumonitis' 'Multiple gestation' 'Osteoarthritis'
#  'Gastrointestinal cancers - stomach'
#  'Complication of cardiovascular device, implant or graft, initial encounter'
#  'Nutritional anemia'
#  'Other specified and unspecified lower respiratory disease'
#  'Nonrheumatic and unspecified valve disorders'
#  'Non-pressure ulcer of skin' 'Encephalitis'
#  'Peripheral and visceral vascular disease'
#  'Musculoskeletal congenital conditions'
#  'Chronic obstructive pulmonary disease and bronchiectasis'
#  'Nervous system congenital anomalies' 'Breast cancer - all other types'
#  'Thyroid disorders'
#  'Postprocedural or postoperative circulatory system complication'
#  'Polyhydramnios and other problems of amniotic cavity'
#  'Complication of transplanted organs or tissue, initial encounter'
#  'Pulmonary heart disease' 'Fever' 'Bacterial infections'
#  'Nonspecific chest pain' 'Endocarditis and endocardial disease'
#  'Head and neck cancers - all other types'
#  'Coronary atherosclerosis and other heart disease'
#  'Female reproductive system cancers - endometrium'
#  'Diseases of inner ear and related conditions' 'Cystic fibrosis'
#  'Other general signs and symptoms' 'Tendon and synovial disorders'
#  'Hepatic failure' 'Gastroduodenal ulcer' 'Benign ovarian cyst'
#  'Acquired deformities (excluding foot)'
#  'Abnormal findings without diagnosis' 'Other aftercare encounter'
#  'Cardiac and circulatory congenital anomalies'
#  'Gastrointestinal cancers - liver'
#  'Other specified female genital disorders'
#  'Disorders of teeth and gingiva' 'Nervous system cancers - brain'
#  'Acute posthemorrhagic anemia'
#  'Systemic lupus erythematosus and connective tissue disorders'
#  'Trauma- and stressor-related disorders' 'Gout' 'Noninfectious hepatitis'
#  'Regional enteritis and ulcerative colitis' 'Pneumothorax'
#  'Parkinson`s disease' 'Aplastic anemia' 'Sleep wake disorders'
#  'Gastrointestinal cancers - colorectal'
#  'Conditions due to neoplasm or the treatment of neoplasm'
#  'Occlusion or stenosis of precerebral or cerebral arteries without infarction'
#  'Maltreatment/abuse' 'Lung disease due to external agents'
#  'Myelodysplastic syndrome (MDS)'
#  'Other specified and unspecified mood disorders' 'Vesicoureteral reflux'
#  'Malaise and fatigue' 'Paralysis (other than cerebral palsy)'
#  'Respiratory cancers' 'Head and neck cancers - lip and oral cavity'
#  'Polyneuropathies' 'Cardiac arrest and ventricular fibrillation'
#  'Multiple myeloma' 'Endocrine system cancers - pancreas'
#  'Aortic; peripheral; and visceral artery aneurysms' 'HIV infection'
#  'Disorders of jaw'
#  'Other nervous system disorders (neither hereditary nor degenerative)'
#  'Traumatic arthropathy' 'Maternal care for abnormality of pelvic organs'
#  'Transient cerebral ischemia' 'Coagulation and hemorrhagic disorders'
#  'Benign neoplasms' 'Anal and rectal conditions'
#  'Pericarditis and pericardial disease' 'Nerve and nerve root disorders'
#  'Spontaneous abortion and complications of spontaneous abortion'
#  'Complications specified during the puerperium'
#  'Diseases of white blood cells' 'Leukemia - acute myeloid leukemia (AML)'
#  'Pleurisy, pleural effusion and pulmonary collapse' 'Hepatitis'
#  'Other and ill-defined cerebrovascular disease' 'Nausea and vomiting'
#  'Stress fracture, initial encounter'
#  'Postprocedural or postoperative skin complication'
#  'Other specified and unspecified diseases of bladder and urethra'
#  'Symptoms of mental and substance use conditions'
#  'Stimulant-related disorders' 'Acute and chronic tonsillitis'
#  'Other specified bone disease and musculoskeletal deformities'
#  'Open wounds of head and neck, initial encounter'
#  'General sensation/perception signs and symptoms'
#  'Internal organ injury, initial encounter'
#  'Nervous system cancers - all other types'
#  'Scoliosis and other postural dorsopathic deformities'
#  'Leukemia - all other types'
#  'Superficial injury; contusion, initial encounter' 'Allergic reactions'
#  'Encounter for observation and examination for conditions ruled out (excludes infectious disease, neoplasm, mental disorders)'
#  'Low back pain' 'Inflammatory conditions of male genital organs'
#  'Musculoskeletal pain, not low back pain' 'Dysphagia'
#  'Neurodevelopmental disorders' 'Hemorrhoids' 'Cerebral palsy'
#  'Nephritis; nephrosis; renal sclerosis' 'Calculus of urinary tract'
#  'Suicidal ideation/attempt/intentional self-harm'
#  'Other specified status' 'Personality disorders' 'CNS abscess'
#  'Traumatic brain injury (TBI); concussion, subsequent encounter'
#  'Aortic and peripheral arterial embolism or thrombosis'
#  'Other specified and unspecified endocrine disorders'
#  'Pituitary disorders' 'Hyperplasia of prostate'
#  'Anxiety and fear-related disorders'
#  'Hemolytic jaundice and perinatal jaundice'
#  'Other specified diseases of veins and lymphatics'
#  'Other specified and unspecified disorders of the ear'
#  'Urinary system cancers - bladder'
#  'Effect of foreign body entering opening, initial encounter'
#  'Myocarditis and cardiomyopathy' 'Conduction disorders'
#  'Skin/Subcutaneous signs and symptoms'
#  'Other specified and unspecified upper respiratory disease'
#  'Inflammatory diseases of female pelvic organs'
#  'Obsessive-compulsive and related disorders'
#  'Fracture of lower limb (except hip), subsequent encounter'
#  'Urinary system cancers - kidney'
#  'Other specified and unspecified congenital anomalies'
#  'Fracture of torso, subsequent encounter'
#  'Nonmalignant breast conditions'
#  'Implant, device or graft related encounter'
#  'Postprocedural or postoperative musculoskeletal system complication'
#  'Other specified and unspecified circulatory disease'
#  'Acquired foot deformities' 'Burn and corrosion, initial encounter'
#  'Fungal infections' 'Infective arthritis'
#  'Other specified inflammatory condition of skin'
#  'Molar pregnancy and other abnormal products of conception'
#  'Other and ill-defined heart disease'
#  'Postprocedural or postoperative nervous system complication'
#  'Hemolytic anemia' 'Cannabis-related disorders'
#  'Blindness and vision defects' 'Neuro-ophthalmology'
#  'Sprains and strains, initial encounter'
#  'Injury to nerves, muscles and tendons, initial encounter'
#  'Neoplasms of unspecified nature or uncertain behavior'
#  'Breast cancer - ductal carcinoma in situ (DCIS)'
#  'Other specified and unspecified hematologic conditions'
#  'Other specified eye disorders' 'Gastrointestinal cancers - bile duct'
#  'Oculofacial plastics and orbital conditions'
#  'Burns and corrosion, subsequent encounter'
#  'Other specified and unspecified disorders of stomach and duodenum'
#  'Female reproductive system cancers - ovary' 'Arterial dissections'
#  'Maternal intrauterine infection'
#  'Other specified male genital disorders'
#  'Postprocedural or postoperative genitourinary system complication'
#  'Effect of other external causes, initial encounter'
#  'Hemorrhage after first trimester' 'Meningitis'
#  'Head and neck cancers - laryngeal' 'Foodborne intoxications'
#  'Fracture of the neck of the femur (hip), subsequent encounter'
#  'Toxic effects, initial encounter' 'Hodgkin lymphoma' 'Mesothelioma'
#  'Other specified and unspecified perinatal conditions'
#  'Coma; stupor; and brain damage'
#  'Other specified connective tissue disease'
#  'Open wounds of trunk, initial encounter' 'Multiple sclerosis' 'Shock'
#  'Nervous system pain and pain syndromes' 'Perinatal infections'
#  'Injury, sequela' 'Otitis media'
#  'Female reproductive system cancers - uterus'
#  'Early, first or unspecified trimester hemorrhage'
#  'Other specified joint disorders' 'Gangrene'
#  'Gastrointestinal cancers - esophagus'
#  'Open wounds of trunk, subsequent encounter'
#  'Rheumatoid arthritis and related disease' 'Essential hypertension'
#  'Somatic disorders' 'Menstrual disorders' 'Feeding and eating disorders'
#  'Crystal arthropathies (excluding gout)' 'Other unspecified injury'
#  'Short gestation; low birth weight; and fetal growth retardation'
#  'Gastrointestinal cancers - small intestine'
#  'Mental and substance use disorders in remission'
#  'Induced abortion and complications of termination of pregnancy'
#  'Head and neck cancers - eye' 'Digestive congenital anomalies'
#  'Respiratory perinatal condition' 'Sarcoma' 'Cancer of other sites'
#  'Sinusitis' 'Nutritional deficiencies'
#  'Respiratory congenital malformations' 'Bone cancer' 'Endometriosis'
#  'Neonatal cerebral disorders' 'Neonatal digestive and feeding disorders'
#  'Sexually transmitted infections (excluding HIV and hepatitis)'
#  'Aseptic necrosis and osteonecrosis' 'Sedative-related disorders'
#  'Genitourinary congenital anomalies'
#  'Sequela of hemorrhagic cerebrovascular disease'
#  'Hemorrhagic and hematologic disorders of newborn'
#  'Injury to blood vessels, initial encounter' 'Pressure ulcer of skin'
#  'Female reproductive system cancers - vagina'
#  'Gastrointestinal and biliary perforation' 'Hematuria'
#  'Female reproductive system cancers - vulva'
#  'Endocrine system cancers - thyroid' 'Gastrointestinal cancers - anus'
#  'Miscellaneous mental and behavioral disorders/conditions'
#  'Head and neck cancers - tonsils'
#  'Head and neck cancers - hypopharyngeal' 'Skin cancers - all other types'
#  'Skin cancers - melanoma' 'Immunity disorders'
#  'Encounter for prophylactic or other procedures'
#  'Complication of internal orthopedic device or implant, subsequent encounter'
#  'Head and neck cancers - salivary gland'
#  'Skin cancers - squamous cell carcinoma'
#  'Female reproductive system cancers - fallopian tube'
#  'Complications of acute myocardial infarction'
#  'Immune-mediated/reactive arthropathies' 'Tuberculosis' 'Malnutrition'
#  'Sprains and strains, subsequent encounter'
#  'Genitourinary signs and symptoms'
#  'Gastrointestinal cancers - all other types'
#  'Gastrointestinal cancers - gallbladder' 'Urinary incontinence'
#  'Birth trauma' 'Malignant neoplasm, unspecified' 'Cleft lip or palate'
#  'Cornea and external disease'
#  'Spinal cord injury (SCI), initial encounter'
#  'Leukemia - acute lymphoblastic leukemia (ALL)'
#  'Dislocations, initial encounter' 'Disorders of lipid metabolism'
#  'Biomechanical lesions'
#  'Fracture of the upper limb, subsequent encounter'
#  'Hallucinogen-related disorders' 'Crushing injury, initial encounter'
#  'Female reproductive system cancers - cervix'
#  'Prolapse of female genital organs' 'Dislocations, subsequent encounter'
#  'Urinary system cancers - all other types'
#  'Endocrine system cancers - adrenocortical'
#  'Leukemia - chronic myeloid leukemia (CML)' 'Mediastinal disorders'
#  'Menopausal disorders'
#  'Exposure, encounters, screening or contact with infectious disease'
#  'Fracture of the spine and back, subsequent encounter'
#  'Acquired absence of limb or organ'
#  'Male reproductive system cancers - testis'
#  'Uveitis and ocular inflammation' 'Endocrine system cancers - thymus'
#  'Parasitic, other specified and unspecified infections'
#  'Male reproductive system cancers - penis'
#  'Toxic effects, subsequent encounter' 'Cardiac cancers'
#  'Stress fracture, subsequent encounter'
#  'Complication of cardiovascular device, implant or graft, subsequent encounter'
#  'Pathological fracture, subsequent encounter'
#  'Complication of genitourinary device, implant or graft, subsequent encounter'
#  'Complication of other surgical or medical care, injury, subsequent encounter'
#  'Open wounds of head and neck, subsequent encounter' 'Glaucoma'
#  'Diabetes mellitus without complication'
#  'Amputation of a limb, subsequent encounter'
#  'Endocrine system cancers - all other types'
#  'Neoplasm-related encounters' 'Leukemia - hairy cell'
#  'Endocrine system cancers - parathyroid'
#  'Urinary system cancers - ureter and renal pelvis'
#  'Female reproductive system cancers - all other types'
#  'Amputation of a limb, initial encounter'
#  'Atypical fracture, initial encounter'
#  'Spinal cord injury (SCI), subsequent encounter' 'Contact dermatitis'
#  'Atypical fracture, subsequent encounter' 'Respiratory distress syndrome'
#  'Congenital malformations of eye, ear, face, neck'
#  'Gastrointestinal cancers - peritoneum'
#  'Leukemia - chronic lymphocytic leukemia (CLL)' 'Musculoskeletal abscess'
#  'Neonatal abstinence syndrome'
#  'Other specified CNS infection and poliomyelitis'
#  'Postprocedural or postoperative endocrine or metabolic complication'
#  'Obstetric history affecting care in pregnancy'
#  'Head and neck cancers - throat'
#  'Chronic phlebitis; thrombophlebitis and thromboembolism'
#  'Complications following ectopic and/or molar pregnancy'
#  'Erectile dysfunction' 'Cataract and other lens disorders'
#  'Newborn affected by maternal conditions or complications of labor/delivery'
#  'Pathological, stress and atypical fractures, sequela'
#  'Head and neck cancers - pharyngeal' 'Neonatal acidemia and hypoxia'
#  'Internal organ injury, subsequent encounter'
#  'Postprocedural or postoperative complications of the spleen'
#  'Amputation of other body parts, initial encounter'
#  'Other unspecified injuries, subsequent encounter' 'Male infertility'
#  'Juvenile arthritis' 'Medical examination/evaluation'
#  'Male reproductive system cancers - all other types' 'Proteinuria'
#  'Adverse effects of drugs and medicaments, initial encounter'
#  'Other specified injury, subsequent encounter'
#  'Fracture of head and neck, subsequent encounter'
#  'Neurogenic/neuropathic arthropathy'
#  'Injury to blood vessels, subsequent encounter'
#  'Open wounds to limbs, subsequent encounter'
#  'Contraceptive and procreative management'
#  'Postprocedural or postoperative ear and/or mastoid process complication'
#  'Urinary system cancers - urethra' 'Chromosomal abnormalities'
#  'Effect of other external causes, subsequent encounter'
#  'Endocrine system cancers - pituitary gland' 'Hearing loss'
#  'Encounter for mental health conditions'
#  'Skin cancers - basal cell carcinoma'
#  'Poisoning by drugs, subsequent encounter'
#  'Suicide attempt/intentional self-harm; subsequent encounter'
#  'Strabismus' 'Acute rheumatic heart disease'
#  'Effect of foreign body entering opening, subsequent encounter'
#  'Inhalant-related disorders' 'Anesthesia complications during pregnancy'
#  'Antenatal screening' 'Postprocedural or postoperative eye complication'
#  'Complication, sequela'
#  'Superficial injury; contusion, subsequent encounter'
#  'Injury to nerves, muscles and tendons, subsequent encounter'
#  'Autoinflammatory syndromes' 'Effect of other external causes, sequela'
#  'Lifestyle/life management factors'
#  'Sequela of specified nervous system conditions'
#  'Maltreatment/abuse, subsequent encounter'
#  'Crushing injury, subsequent encounter'
#  'Poisoning/toxic effect/adverse effects/underdosing, sequela'
#  'Female infertility' 'Refractive error' 'Osteomalacia'
#  'Encounter for mental health services related to abuse'
#  'Sequela of specified infectious disease conditions'
#  'Other specified chronic arthropathy'
#  'Allergic reactions, subsequent encounter' 'Tobacco-related disorders'
#  'Other specified encounters and counseling' 'Unacceptable PDX']
#
# CCSR Procedure Code:
# ['ADM019' 'ADM015' 'PGN002' 'MHT001' 'OTR004' nan 'ADM017' 'ADM021'
#  'ADM016' 'GIS004' 'SUD004' 'MAM006' 'PGN001' 'GNR003' 'ESA004' 'SKB006'
#  'ADM001' 'ADM010' 'GIS024' 'PGN003' 'MAM010' 'PGN004' 'ESA001' 'URN006'
#  'IMG008' 'ADM022' 'ADM007' 'NCM004' 'IMG006' 'GIS017' 'MHT002' 'ADM003'
#  'MST015' 'ADM012' 'GIS019' 'MST010' 'IMG007' 'PGN008' 'RES010' 'CAR026'
#  'MRS001' 'MST003' 'RES005' 'URN002' 'GIS026' 'MAM011' 'RES007' 'MST020'
#  'CAR024' 'SUD001' 'CNS007' 'ADM011' 'MST009' 'MST011' 'ESA005' 'GIS008'
#  'GIS001' 'GIS009' 'GIS025' 'ADM006' 'MST028' 'GIS007' 'ESA003' 'CNS005'
#  'HEP006' 'MST013' 'MST007' 'MST016' 'GIS006' 'SKB002' 'MAM013' 'RES001'
#  'MAM005' 'CAR029' 'CAR027' 'MST012' 'CAR022' 'GNR006' 'CAR014' 'MST021'
#  'SKB005' 'URN003' 'ADM014' 'CNS010' 'LYM002' 'URN011' 'CAR025' 'GIS010'
#  'CAR004' 'CNS002' 'ENT017' 'LYM003' 'FRS001' 'GNR002' 'MST014' 'CNS004'
#  'HEP004' 'ENT006' 'MST006' 'MAM007' 'FRS002' 'MST030' 'CAR007' 'URN012'
#  'ESA006' 'URN005' 'CAR002' 'IMG005' 'HEP008' 'MST001' 'HEP013' 'GIS027'
#  'FRS009' 'SUD002' 'MST017' 'ENT004' 'IMG004' 'CAR008' 'CAR023' 'HEP010'
#  'MHT003' 'CAR006' 'HEP011' 'RES013' 'SKB003' 'MST002' 'URN008' 'RHB002'
#  'CNS013' 'IMG001' 'MST018' 'CNS014' 'IMG009' 'ADM005' 'HEP005' 'CAR011'
#  'GIS018' 'MST004' 'CAR003' 'CAR017' 'HEP003' 'RES008' 'CAR019' 'RAD004'
#  'GIS016' 'MST019' 'FRS015' 'CAR028' 'ENP005' 'HEP007' 'ADM018' 'PNS005'
#  'PGN006' 'LYM007' 'MST005' 'GNR010' 'NCM002' 'GIS028' 'MST023' 'GNR008'
#  'MAM008' 'MAM004' 'ENT001' 'MST029' 'CNS008' 'LYM008' 'URN004' 'GIS021'
#  'MHT005' 'ADM009' 'SKB008' 'ESA002' 'GNR004' 'CAR010' 'RHB001' 'MST022'
#  'MRS003' 'PLC001' 'IMG002' 'EST002' 'URN009' 'GNR005' 'GIS029' 'PLC002'
#  'GIS022' 'GIS002' 'ENP002' 'MST024' 'FRS006' 'ENT008' 'RES002' 'FRS010'
#  'SKB001' 'OTR001' 'ESA009' 'HEP001' 'CAR012' 'FRS003' 'CAR021' 'MST026'
#  'GIS011' 'CAR009' 'RES012' 'CAR020' 'CNS011' 'CNS001' 'RES004' 'CNS012'
#  'SKB004' 'ENP004' 'PGN005' 'GIS003' 'LYM005' 'GIS020' 'ENT011' 'MRS004'
#  'CNS009' 'PNS001' 'RES003' 'SKB007' 'EST001' 'ENT007' 'RES006' 'RHB004'
#  'FRS007' 'CAR013' 'EST003' 'PNS002' 'ADM008' 'RES011' 'FRS008' 'GNR009'
#  'LYM001' 'LYM004' 'MRS007' 'ENT003' 'EYP001' 'CNS006' 'URN001' 'ADM002'
#  'ENT015' 'PNS003' 'GIS005' 'RES009' 'HEP012' 'CAR001' 'ENP003' 'ENT005'
#  'FRS012' 'MST025' 'CAR015' 'ENT014' 'FRS005' 'MRS002' 'ENT009' 'PGN009'
#  'HEP009' 'NCM001' 'FRS011' 'ENT012' 'CNS003' 'SUD003' 'LYM006' 'MST008'
#  'PGN007' 'MRS005' 'LYM011' 'ENT010' 'MAM015' 'IMG003' 'ESA010' 'URN007'
#  'CAR018' 'ENT013' 'SKB009' 'MAM009' 'EYP002' 'CAR016' 'ADM020' 'MAM001'
#  'GIS015' 'ADM004' 'ENP006' 'ESA008' 'GIS013' 'CAR005' 'URN010' 'MAM002'
#  'HEP002' 'ADM013' 'OST001' 'GNR007' 'ENT002' 'MAM003' 'PNS006' 'GIS012'
#  'ESA007' 'RES014' 'MAM012' 'GIS014' 'MHT004' 'RAD001' 'GNR001' 'RAD002'
#  'ENP001' 'EST005' 'RAD003' 'RHB003' 'FRS013' 'SKB010' 'ESA011' 'OTR002'
#  'PNS004' 'EST004' 'FRS004' 'CHP001' 'MAM014' 'GIS023' 'IMG010' 'NCM003'
#  'OTR003' 'OTR005']
#
# CCSR Procedure Description:
# ['POTENTIAL COVID-19 THERAPIES' 'ADMINISTRATION OF ANTIBIOTICS'
#  'SPONTANEOUS VAGINAL DELIVERY'
#  'PHARMACOTHERAPY FOR MENTAL HEALTH (EXCLUDING SUBSTANCE USE)'
#  'ISOLATION PROCEDURES' nan
#  'ADMINISTRATION OF NUTRITIONAL AND ELECTROLYTIC SUBSTANCES'
#  'ADMINISTRATION OF THERAPEUTIC SUBSTANCES, NEC'
#  'ADMINISTRATION OF ANTI-INFLAMMATORY AGENTS'
#  'GI SYSTEM ENDOSCOPY WITHOUT BIOPSY (DIAGNOSTIC)'
#  'COUNSELING FOR SUBSTANCE USE'
#  'PACEMAKER AND DEFIBRILLATOR INTERROGATION' 'FETAL HEART RATE MONITORING'
#  'INGUINAL AND FEMORAL HERNIA REPAIR' 'NON-INVASIVE VENTILATION'
#  'SKIN LACERATION REPAIR (EXCLUDING PERINEUM)'
#  'TRANSFUSION OF BLOOD AND BLOOD PRODUCTS' 'VACCINATIONS'
#  'OTHER PERITONEAL CAVITY PROCEDURES' 'CESAREAN SECTION'
#  'OTHER CARDIOVASCULAR SYSTEM MEASUREMENT AND MONITORING'
#  'ASSISTED VAGINAL DELIVERY' 'HEMODIALYSIS'
#  'BLADDER CATHETERIZATION AND DRAINAGE' 'ULTRASONOGRAPHY'
#  'COVID-19 VACCINATIONS' 'INTRAVENOUS INDUCTION OF LABOR'
#  'POSITRON EMISSION TOMOGRAPHIC (PET) IMAGING'
#  'COMPUTERIZED TOMOGRAPHY (CT) WITH CONTRAST' 'GASTROSTOMY'
#  'PSYCHOTHERAPY FOR MENTAL HEALTH (EXCLUDING SUBSTANCE USE)'
#  'ADMINISTRATION OF ALBUMIN AND GLOBULIN'
#  'CLOSED REDUCTION OF BONES AND JOINTS' 'CHEMOTHERAPY'
#  'GASTRO-JEJUNAL BYPASS (INCLUDING BARIATRIC)' 'FEMUR FIXATION'
#  'COMPUTERIZED TOMOGRAPHY (CT) WITHOUT CONTRAST' 'ABORTION' 'TRACHEOSTOMY'
#  'PACEMAKER AND DEFIBRILLATOR PROCEDURES' 'CIRCUMCISION'
#  'SUBCUTANEOUS TISSUE, FASCIA, AND MUSCLE BIOPSY'
#  'CHEST TUBE PLACEMENT AND THERAPEUTIC THORACENTESIS'
#  'KIDNEY AND OTHER URINARY TRACT BIOPSY (NON-ENDOSCOPIC)'
#  'UPPER GI THERAPEUTIC PROCEDURES, NEC (OPEN AND LAPAROSCOPIC)'
#  'ELECTROENCEPHALOGRAM (EEG)' 'AIRWAY INTUBATION'
#  'SUBCUTANEOUS TISSUE AND FASCIA EXCISION'
#  'VENOUS AND ARTERIAL CATHETER PLACEMENT' 'SUBSTANCE USE DETOXIFICATION'
#  'CNS EXCISION PROCEDURES'
#  'ADMINISTRATION AND TRANSFUSION OF BONE MARROW, STEM CELLS, PANCREATIC ISLET CELLS, AND T-CELLS'
#  'FIXATION OF UPPER EXTREMITY BONES' 'FIXATION OF LEG AND FOOT BONES'
#  'CARDIAC CHEST COMPRESSION' 'APPENDECTOMY'
#  'ESOPHAGOGASTRODUODENOSCOPY (EGD) WITH BIOPSY' 'COLECTOMY'
#  'OTHER GI SYSTEM DEVICE PROCEDURES' 'INFUSION OF VASOPRESSOR'
#  'SUBCUTANEOUS TISSUE AND FASCIA PROCEDURES, NEC'
#  'GI SYSTEM DRAINAGE (EXCLUDING PARACENTESIS)' 'MECHANICAL VENTILATION'
#  'VENTRICULOSTOMY [PERCUTANEOUS APPROACH]' 'CHOLECYSTECTOMY'
#  'SPINE FUSION' 'HIP ARTHROPLASTY' 'VERTEBRAL DISCECTOMY' 'PARACENTESIS'
#  'INCISION AND DRAINAGE OF SKIN' 'MONITORING OF PERIPHERAL NERVES'
#  'BRONCHOSCOPY (DIAGNOSTIC)' 'MEASUREMENT DURING CARDIAC CATHETERIZATION'
#  'CARDIOVASCULAR DEVICE PROCEDURES, NEC' 'HEART ASSIST DEVICE PROCEDURES'
#  'BONE FIXATION (EXCLUDING EXTREMITIES)'
#  'HEART VALVE REPLACEMENT AND OTHER VALVE PROCEDURES (NON-ENDOVASCULAR)'
#  'CHEST WALL PROCEDURES, NEC' 'PERIPHERAL ARTERIAL BYPASS PROCEDURES'
#  'PERINEAL MUSCLE LACERATION REPAIR (2ND DEGREE OBSTETRICAL AND OTHER)'
#  'PERINEAL SKIN REPAIR (1ST DEGREE OBSTETRICAL AND OTHER)'
#  'URETER AND OTHER URINARY TRACT DILATION' 'REGIONAL ANESTHESIA'
#  'CEREBROSPINAL FLUID SHUNT PROCEDURES'
#  'LYMPH NODE EXCISION (THERAPEUTIC)' 'KIDNEY TRANSPLANT'
#  'PLACEMENT OF TUNNELED OR IMPLANTABLE PORTION OF A VASCULAR ACCESS DEVICE'
#  'GASTRECTOMY' 'PERCUTANEOUS CORONARY INTERVENTIONS (PCI)'
#  'LUMBAR PUNCTURE' 'ENT PROCEDURES, NEC' 'LYMPH NODE DISSECTION'
#  'HYSTERECTOMY' 'ABDOMINAL WALL REPAIR (INCLUDING HERNIA)'
#  'JOINT FUSION (EXCLUDING SPINE)'
#  'INTRACRANIAL EPIDURAL AND SUBDURAL SPACE DRAINAGE'
#  'HEPATOBILIARY RESECTION AND ABLATION'
#  'ENT DRAINAGE (EXCLUDING MYRINGOTOMY)' 'KNEE ARTHROPLASTY'
#  'ELECTROCARDIOGRAM (ECG)' 'OOPHORECTOMY'
#  'MUSCULOSKELETAL PROCEDURES, NEC'
#  'EMBOLECTOMY, ENDARTERECTOMY, AND RELATED VESSEL PROCEDURES (NON-ENDOVASCULAR; EXCLUDING CAROTID)'
#  'URINARY SYSTEM PROCEDURES, NEC' 'CARDIOVERSION'
#  'NEPHROSTOMY AND URETEROSTOMY PROCEDURES (INCLUDING STENTS)'
#  'HEART CONDUCTION MECHANISM PROCEDURES'
#  'MAGNETIC RESONANCE IMAGING (MRI)'
#  'COMMON BILE DUCT SPHINCTEROTOMY AND STENTING' 'ARTHROCENTESIS'
#  'HEPATOBILIARY AND PANCREATIC PROCEDURES, NEC'
#  'UPPER GI THERAPEUTIC PROCEDURES, NEC (ENDOSCOPIC)' 'CERVICAL CERCLAGE'
#  'PHARMACOTHERAPY FOR SUBSTANCE USE'
#  'JOINT TISSUE EXCISION (EXCLUDING DISCECTOMY)' 'DIAGNOSTIC AUDIOLOGY'
#  'FLUOROSCOPY OF NON-CIRCULATORY ORGANS'
#  'ANGIOPLASTY AND RELATED VESSEL PROCEDURES (ENDOVASCULAR; EXCLUDING CAROTID)'
#  'HEART VALVE REPLACEMENT AND OTHER VALVE PROCEDURES (ENDOVASCULAR)'
#  'HEPATOBILIARY AND PANCREATIC DRAINAGE' 'ELECTROCONVULSIVE THERAPY'
#  'CAROTID ENDARTERECTOMY AND STENTING' 'LIVER TRANSPLANT'
#  'LUNG TRANSPLANT' 'MASTECTOMY AND LUMPECTOMY' 'BONE AND JOINT BIOPSY'
#  'NEPHRECTOMY AND URETERECTOMY'
#  'PHYSICAL, OCCUPATIONAL, AND RESPIRATORY THERAPY TREATMENT'
#  'SPINAL EPIDURAL CATHETER PLACEMENT' 'CARDIAC AND CORONARY FLUOROSCOPY'
#  'BONE EXCISION' 'CNS PROCEDURES, NEC' 'PLAIN RADIOGRAPHY'
#  'ADMINISTRATION OF THROMBOLYTICS AND PLATELET INHIBITORS'
#  'PANCREATECTOMY' 'ANEURYSM REPAIR PROCEDURES' 'ILEOSTOMY AND COLOSTOMY'
#  'INCISION AND DRAINAGE OF MUSCULOSKELETAL TISSUE AND JOINTS'
#  'CORONARY ARTERY BYPASS GRAFTS (CABG)' 'PERICARDIAL PROCEDURES'
#  'DIAGNOSTIC ERCP WITH OR WITHOUT BIOPSY'
#  'LUNG, PLEURA, OR DIAPHRAGM RESECTION (OPEN AND THORACOSCOPIC)'
#  'SEPTAL REPAIR AND OTHER THERAPEUTIC HEART PROCEDURES'
#  'RADIATION THERAPY, NEC' 'GI SYSTEM ENDOSCOPIC THERAPEUTIC PROCEDURES'
#  'MUSCLE, TENDON, BURSA, AND LIGAMENT EXCISION'
#  'FEMALE REPRODUCTIVE SYSTEM PROCEDURES, NEC'
#  'INFERIOR VENA CAVA (IVC) FILTER PROCEDURES' 'PITUITARY GLAND RESECTION'
#  'BILIARY AND PANCREATIC CALCULUS REMOVAL'
#  'IRRIGATION (DIAGNOSTIC AND THERAPEUTIC)' 'PERIPHERAL NERVE DENERVATION'
#  'REMOVAL OF PLACENTA AND OTHER RETAINED PRODUCTS OF CONCEPTION'
#  'BONE MARROW BIOPSY'
#  'INCISION AND DRAINAGE OF SUBCUTANEOUS TISSUE AND FASCIA'
#  'GENITOURINARY TRACT PROCEDURES, NEC'
#  'TOMOGRAPHIC NUCLEAR MEDICINE IMAGING'
#  'LOWER GI THERAPEUTIC PROCEDURES, NEC (OPEN AND LAPAROSCOPIC)'
#  'TOE AND MID FOOT AMPUTATION' 'ABDOMINAL WALL PROCEDURES, NEC'
#  'CARDIAC MONITORING' 'CARDIAC STRESS TESTS' 'LARYNGOSCOPY (DIAGNOSTIC)'
#  'MUSCULOSKELETAL DEVICE PROCEDURES, NEC' 'SPINAL CORD DECOMPRESSION'
#  'BONE MARROW ASPIRATION (THERAPEUTIC)'
#  'REMOVAL OF CALCULI AND OTHER MATTER FROM URINARY TRACT'
#  'GI SYSTEM REPAIR (EXCLUDING ANORECTAL)' 'MENTAL HEALTH PROCEDURES, NEC'
#  'RH IMMUNOGLOBULIN AND OTHER SERUM INFUSION'
#  'SKIN EXCISION AND DEBRIDEMENT' 'EXTRACORPOREAL MEMBRANE OXYGENATION'
#  'ENDOSCOPIC CONTROL OF BLEEDING' 'LIGATION AND EMBOLIZATION OF VESSELS'
#  'PHYSICAL, OCCUPATIONAL, AND RESPIRATORY THERAPY EVALUATION'
#  'TENDON, MUSCLE, BURSA, AND LIGAMENT REPAIR (EXCLUDING PERINEAL)'
#  'PROSTATECTOMY' 'IMMOBILIZATION BY SPLINT OR OTHER EXTERNAL DEVICE'
#  'FLUOROSCOPIC ANGIOGRAPHY (EXCLUDING CORONARY)' 'PHOTOTHERAPY'
#  'CYSTECTOMY (INCLUDING FULGURATION) AND URETHRECTOMY'
#  'CONTROL OF BLEEDING (NON-ENDOSCOPIC)'
#  'LOWER GI THERAPEUTIC PROCEDURES, NEC (EXCLUDING OPEN AND LAPAROSCOPIC)'
#  'PACKING AND DRESSING PROCEDURES' 'GI SYSTEM LYSIS OF ADHESIONS'
#  'COLONOSCOPY AND PROCTOSCOPY WITH BIOPSY' 'THYROIDECTOMY'
#  'BELOW KNEE AMPUTATION' 'VULVAR LACERATION REPAIR'
#  'NASAL AND SINUS EXCISION'
#  'LUNG, PLEURA, OR DIAPHRAGM BIOPSY (NON-ENDOSCOPIC)'
#  'FEMALE UPPER GENITAL TRACT EXCISION'
#  'SKIN BIOPSY AND DIAGNOSTIC DRAINAGE' 'ROBOTIC-ASSISTED PROCEDURES'
#  'CARDIAC ASSISTANCE WITH BALLOON PUMP' 'LIVER BIOPSY'
#  'VESSEL REPAIR AND REPLACEMENT' 'SALPINGECTOMY'
#  'ARTERY, VEIN, AND GREAT VESSEL PROCEDURES, NEC'
#  'FINGER AND OTHER UPPER EXTREMITY AMPUTATION' 'SMALL BOWEL RESECTION'
#  'LEFT ATRIAL APPENDAGE PROCEDURES' 'RELEASE OF LUNG AND PLEURA'
#  'SAPHENOUS VEIN HARVEST AND OTHER THERAPEUTIC VESSEL REMOVAL'
#  'MENINGES REPAIR' 'MINIMALLY INVASIVE CNS BIOPSY'
#  'BRONCHOSCOPY (THERAPEUTIC)' 'CNS NEUROSTIMULATOR PROCEDURES'
# ...
#  'DISORDERS OF GALLBLADDER AND BILIARY TRACT'
#  'MAJOR LARGE BOWEL PROCEDURES' 'MALIGNANCY, MALE REPRODUCTIVE SYSTEM'
#  'CARDIAC ARRHYTHMIA AND CONDUCTION DISORDERS'
#  'CARDIAC STRUCTURAL AND VALVULAR DISORDERS'
#  'OTHER EAR, NOSE, MOUTH, THROAT AND CRANIAL OR FACIAL DIAGNOSES'
#  'POISONING OF MEDICINAL AGENTS' 'VIRAL ILLNESS'
#  'FRACTURES AND DISLOCATIONS EXCEPT FEMUR, PELVIS AND BACK'
#  'EXTRACORPOREAL MEMBRANE OXYGENATION (ECMO)' 'CHOLECYSTECTOMY'
#  'DORSAL AND LUMBAR FUSION PROCEDURE EXCEPT FOR CURVATURE OF BACK'
#  'TOXIC EFFECTS OF NON-MEDICINAL SUBSTANCES'
#  'OTHER AND UNSPECIFIED GASTROINTESTINAL HEMORRHAGE'
#  'MALFUNCTION, REACTION, COMPLICATION OF ORTHOPEDIC DEVICE OR PROCEDURE'
#  'MAJOR SMALL BOWEL PROCEDURES'
#  'VERTEBRAL AND INTERVERTEBRAL SPINAL PROCEDURES INCLUDING DISC PROCEDURES'
#  'OTHER DISORDERS OF THE LIVER' 'CHRONIC KIDNEY DISEASE'
#  'TRACHEOSTOMY WITH MV >96 HOURS WITH EXTENSIVE PROCEDURE'
#  'HEPATIC COMA AND OTHER MAJOR ACUTE LIVER DISORDERS'
#  'VAGINAL DELIVERY WITH O.R. PROCEDURE EXCEPT STERILIZATION AND/OR D&C'
#  'INFECTIOUS AND PARASITIC DISEASES INCLUDING HIV WITH O.R. PROCEDURE'
#  'OPIOID ABUSE AND DEPENDENCE' 'DIVERTICULITIS AND DIVERTICULOSIS'
#  'BPD AND OTHER CHRONIC RESPIRATORY DISEASES ARISING IN PERINATAL PERIOD'
#  'MAJOR STOMACH, ESOPHAGEAL AND DUODENAL PROCEDURES'
#  'DIGESTIVE MALIGNANCY'
#  'INSERTION, REVISION AND REPLACEMENTS OF PACEMAKER AND OTHER CARDIAC DEVICES'
#  'OTHER ANEMIA AND DISORDERS OF BLOOD AND BLOOD-FORMING ORGANS'
#  'OTHER SIGNIFICANT HIP AND FEMUR SURGERY'
#  'INTERSTITIAL AND ALVEOLAR LUNG DISEASES'
#  'POST-OPERATIVE, POST-TRAUMATIC, OTHER DEVICE INFECTIONS'
#  'CARDIAC VALVE PROCEDURES WITHOUT AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'DENTAL DISEASES AND DISORDERS'
#  'OTHER SKIN, SUBCUTANEOUS TISSUE AND RELATED PROCEDURES'
#  'NON-BACTERIAL INFECTIONS OF NERVOUS SYSTEM EXCEPT VIRAL MENINGITIS'
#  'MALFUNCTION, REACTION, COMPLICATION OF CARDIAC OR VASCULAR DEVICE OR PROCEDURE'
#  'LOWER EXTREMITY ARTERIAL PROCEDURES'
#  'CARDIAC CATHETERIZATION FOR OTHER NON-CORONARY CONDITIONS'
#  'OTHER RESPIRATORY AND CHEST PROCEDURES'
#  'CHRONIC OBSTRUCTIVE PULMONARY DISEASE' 'OTHER CHEMOTHERAPY'
#  'OPEN CRANIOTOMY EXCEPT TRAUMA' 'MASTECTOMY PROCEDURES'
#  'INTRACRANIAL HEMORRHAGE' 'THYROID DISORDERS' 'KIDNEY TRANSPLANT'
#  'HEMORRHAGE OR HEMATOMA DUE TO COMPLICATION'
#  'PERCUTANEOUS CARDIAC INTERVENTION WITH AMI'
#  'FEVER AND INFLAMMATORY CONDITIONS'
#  'OTHER INFECTIOUS AND PARASITIC DISEASES'
#  'ELECTIVE HIP JOINT REPLACEMENT' 'CHEST PAIN'
#  'NON-EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS'
#  'CARDIAC VALVE PROCEDURES WITH AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'OTHER MAJOR HEAD AND NECK PROCEDURES'
#  'CARDIAC CATHETERIZATION FOR CORONARY ARTERY DISEASE'
#  'UTERINE AND ADNEXA PROCEDURES FOR NON-OVARIAN AND NON-ADNEXAL MALIGNANCY'
#  'OTHER SMALL AND LARGE BOWEL PROCEDURES'
#  'VERTIGO AND OTHER LABYRINTH DISORDERS'
#  'CYSTIC FIBROSIS - PULMONARY DISEASE'
#  'NON-ELECTIVE OR COMPLEX HIP JOINT REPLACEMENT'
#  'MALNUTRITION, FAILURE TO THRIVE AND OTHER NUTRITIONAL DISORDERS'
#  'HERNIA PROCEDURES EXCEPT INGUINAL, FEMORAL AND UMBILICAL'
#  'HAND AND WRIST PROCEDURES' 'MAJOR PANCREAS, LIVER AND SHUNT PROCEDURES'
#  'ELECTIVE KNEE JOINT REPLACEMENT'
#  'UTERINE AND ADNEXA PROCEDURES FOR NON-MALIGNANCY EXCEPT LEIOMYOMA'
#  'MAJOR CRANIAL OR FACIAL BONE PROCEDURES' 'VENTRICULAR SHUNT PROCEDURES'
#  'OTHER AFTERCARE AND CONVALESCENCE'
#  'OTHER PERIPHERAL VASCULAR AND RELATED PROCEDURES'
#  'MALIGNANCY OF HEPATOBILIARY SYSTEM AND PANCREAS'
#  'OTHER CARDIOTHORACIC AND THORACIC VASCULAR PROCEDURES'
#  'KIDNEY AND URINARY TRACT PROCEDURES FOR NON-MALIGNANCY'
#  'RESPIRATORY FAILURE' 'PERIPHERAL, CRANIAL AND AUTONOMIC NERVE DISORDERS'
#  'PERCUTANEOUS CARDIAC INTERVENTION WITHOUT AMI'
#  'VAGINAL DELIVERY WITH STERILIZATION AND/OR D&C'
#  'ACUTE ANXIETY AND DELIRIUM STATES' 'INFLAMMATORY BOWEL DISEASE'
#  'TRACHEOSTOMY WITH MV >96 HOURS WITHOUT EXTENSIVE PROCEDURE'
#  'OTHER NERVOUS SYSTEM AND RELATED PROCEDURES'
#  'MAJOR HEMATOLOGIC OR IMMUNOLOGIC DIAGNOSES EXCEPT SICKLE CELL CRISIS AND COAGULATION'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH MAJOR ANOMALY'
#  'RESPIRATORY SYSTEM DIAGNOSIS WITH VENTILATOR SUPPORT > 96 HOURS'
#  'PERCUTANEOUS STRUCTURAL CARDIAC PROCEDURES'
#  'OTHER COMPLICATIONS OF TREATMENT'
#  'OPEN EXTRACRANIAL VASCULAR PROCEDURES'
#  'LIVER TRANSPLANT AND/OR INTESTINAL TRANSPLANT'
#  'OTHER INJURY, POISONING AND TOXIC EFFECT DIAGNOSES'
#  'DEPRESSION EXCEPT MAJOR DEPRESSIVE DISORDER'
#  'HEART AND/OR LUNG TRANSPLANT'
#  'NON-EXTENSIVE O.R. PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT'
#  'HIV WITH ONE SIGNIFICANT HIV CONDITION OR WITHOUT SIGNIFICANT RELATED CONDITIONS'
#  'SPINAL FUSION AND OTHER BACK AND NECK PROCEDURES EXCEPT FOR DISC PROCEDURES'
#  'CESAREAN SECTION WITH STERILIZATION'
#  'PERCUTANEOUS INTRACRANIAL AND EXTRACRANIAL VASCULAR PROCEDURES'
#  'REHABILITATION'
#  'SIGNS, SYMPTOMS AND OTHER FACTORS INFLUENCING HEALTH STATUS'
#  'HIV WITH MULTIPLE SIGNIFICANT HIV RELATED CONDITIONS'
#  'RESPIRATORY MALIGNANCY' 'APPENDECTOMY WITH COMPLEX PRINCIPAL DIAGNOSIS'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH OTHER MAJOR PROCEDURE'
#  'CARDIAC ARREST AND SHOCK' 'DEFIBRILLATOR IMPLANTS' 'PANCREAS TRANSPLANT'
#  'MODERATELY EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS'
#  'CORONARY BYPASS WITHOUT AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'COCAINE ABUSE AND DEPENDENCE' 'MAJOR RESPIRATORY AND CHEST PROCEDURES'
#  'ALTERATION IN CONSCIOUSNESS' 'LYMPHOMA, MYELOMA AND NON-ACUTE LEUKEMIA'
#  'COAGULATION AND PLATELET DISORDERS'
#  'FACIAL BONE PROCEDURES EXCEPT MAJOR CRANIAL OR FACIAL BONE PROCEDURES'
#  'FEMALE REPRODUCTIVE SYSTEM RECONSTRUCTIVE PROCEDURES'
#  'ANGINA PECTORIS AND CORONARY ATHEROSCLEROSIS' 'SPINAL PROCEDURES'
#  'ABORTION WITH D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY'
#  'MAJOR SKIN DISORDERS' 'INBORN ERRORS OF METABOLISM' 'ACUTE LEUKEMIA'
#  'OTHER EAR, NOSE, MOUTH AND THROAT PROCEDURES'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CONDITION'
#  'NONSPECIFIC CVA AND PRECEREBRAL OCCLUSION WITHOUT INFARCTION'
#  'TRANSIENT ISCHEMIA'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH OTHER SIGNIFICANT CONDITION'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH CONGENITAL OR PERINATAL INFECTION'
#  'MODERATELY EXTENSIVE O.R. PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT'
#  'URETHRAL AND TRANSURETHRAL PROCEDURES' 'OTHER MENTAL HEALTH DISORDERS'
#  'OTHER DRUG ABUSE AND DEPENDENCE'
#  'OTHER DIGESTIVE SYSTEM AND ABDOMINAL PROCEDURES'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CONDITION'
#  'MAJOR CHEST AND RESPIRATORY TRAUMA'
#  'MUSCULOSKELETAL MALIGNANCY AND PATHOLOGICAL FRACTURE DUE TO MUSCULOSKELETAL MALIGNANCY'
#  'DORSAL AND LUMBAR FUSION PROCEDURE FOR CURVATURE OF BACK'
#  'OTHER PROCEDURES FOR ENDOCRINE, NUTRITIONAL AND METABOLIC DISORDERS'
#  'ALLERGIC REACTIONS'
#  'MALE REPRODUCTIVE SYSTEM DIAGNOSES EXCEPT MALIGNANCY'
#  'ORGANIC MENTAL HEALTH DISTURBANCES'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH CONGENITAL OR PERINATAL INFECTION'
#  'ANAL AND PERINEAL PROCEDURES'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CONDITION'
#  'NEONATE, TRANSFERRED < 5 DAYS OLD, BORN HERE'
#  'ADJUSTMENT DISORDERS AND NEUROSES EXCEPT DEPRESSIVE DIAGNOSES'
#  'TENDON, MUSCLE AND OTHER SOFT TISSUE PROCEDURES'
#  'MULTIPLE SCLEROSIS, OTHER DEMYELINATING DISEASE AND INFLAMMATORY NEUROPATHIES'
#  'NEPHRITIS AND NEPHROSIS'
#  'BACTERIAL AND TUBERCULOUS INFECTIONS OF NERVOUS SYSTEM'
#  'INTENTIONAL SELF-HARM AND ATTEMPTED SUICIDE'
#  'NEONATE BIRTH WEIGHT 1000-1249 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CONDITION OR MAJOR ANOMALY'
#  'CONTUSION, OPEN WOUND AND OTHER TRAUMA TO SKIN AND SUBCUTANEOUS TISSUE'
#  'FRACTURE OF PELVIS OR DISLOCATION OF HIP'
#  'DISORDERS OF PERSONALITY AND IMPULSE CONTROL'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH CONGENITAL OR PERINATAL INFECTION'
#  'NEONATE BIRTH WEIGHT 1250-1499 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CONDITION OR MAJOR ANOMALY'
#  'OTHER ENDOCRINE DISORDERS'
#  'OTHER FEMALE REPRODUCTIVE SYSTEM AND RELATED PROCEDURES'
#  'TRANSURETHRAL PROSTATECTOMY'
#  'EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS'
#  'FOOT AND TOE PROCEDURES' 'PERITONEAL ADHESIOLYSIS'
#  'NEONATE BIRTH WEIGHT 500-749 GRAMS WITHOUT MAJOR PROCEDURE'
#  'UTERINE AND ADNEXA PROCEDURES FOR LEIOMYOMA'
#  'MENSTRUAL AND OTHER FEMALE REPRODUCTIVE SYSTEM DISORDERS'
#  'GASTROINTESTINAL VASCULAR INSUFFICIENCY' 'SPINAL DISORDERS AND INJURIES'
#  'OTHER KIDNEY, URINARY TRACT AND RELATED PROCEDURES'
#  'MAJOR ABDOMINAL VASCULAR PROCEDURES'
#  'THYROID, PARATHYROID AND THYROGLOSSAL PROCEDURES'
#  'OTHER MALE REPRODUCTIVE SYSTEM AND RELATED PROCEDURES'
#  'PENIS, TESTES AND SCROTAL PROCEDURES'
#  'OTHER HEPATOBILIARY, PANCREAS AND ABDOMINAL PROCEDURES'
#  'CONCUSSION, CLOSED SKULL FRACTURE NOS, AND UNCOMPLICATED INTRACRANIAL INJURY, COMA < 1 HOUR OR NO COMA'
#  'OTHER CIRCULATORY SYSTEM PROCEDURES'
#  'EXTENSIVE THIRD DEGREE BURNS WITHOUT SKIN GRAFT'
#  'ABORTION WITHOUT D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY'
#  'POST-OPERATIVE, POST-TRAUMA, OTHER DEVICE INFECTIONS WITH O.R. PROCEDURE'
#  'PROCEDURE WITH DIAGNOSIS OF REHABILITATION, AFTERCARE OR OTHER CONTACT WITH HEALTH SERVICES'
#  'EXTENSIVE O.R. PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT'
#  'PARTIAL THICKNESS BURNS WITHOUT SKIN GRAFT'
#  'OTHER STOMACH, ESOPHAGEAL AND DUODENAL PROCEDURES'
#  'CORONARY BYPASS WITH AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'ADRENAL PROCEDURES' 'FEMALE REPRODUCTIVE SYSTEM MALIGNANCY'
#  'OPEN CRANIOTOMY FOR TRAUMA' 'MALIGNANT BREAST DISORDERS' 'SPLENECTOMY'
#  'BURNS WITH SKIN GRAFT EXCEPT EXTENSIVE THIRD DEGREE BURNS'
#  'EXTENSIVE ABDOMINAL OR THORACIC PROCEDURES FOR MULTIPLE SIGNIFICANT TRAUMA'
#  'KIDNEY AND URINARY TRACT PROCEDURES FOR MALIGNANCY' 'VIRAL MENINGITIS'
#  'MUSCULOSKELETAL AND OTHER PROCEDURES FOR MULTIPLE SIGNIFICANT TRAUMA'
#  'MAJOR MALE PELVIC PROCEDURES' 'ACUTE BRONCHITIS AND RELATED SYMPTOMS'
#  'AMPUTATION OF LOWER LIMB EXCEPT TOES'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH MAJOR ANOMALY'
#  'SKIN GRAFT FOR SKIN AND SUBCUTANEOUS TISSUE DIAGNOSES'
#  'OTHER OPEN CRANIOTOMY'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH OR WITHOUT OTHER SIGNIFICANT CONDITION'
#  'NEONATE BIRTH WEIGHT 1250-1499 GRAMS WITH OR WITHOUT SIGNIFICANT CONDITION'
#  'TONSIL AND ADENOID PROCEDURES' 'ANOXIC AND OTHER SEVERE BRAIN DAMAGE'
#  'ORBIT AND EYE PROCEDURES' 'EXTERNAL HEART ASSIST SYSTEMS'
#  'PRINCIPAL DIAGNOSIS INVALID AS DISCHARGE DIAGNOSIS'
#  'OTHER MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE PROCEDURES'
#  'OTHER O.R. PROCEDURES FOR LYMPHATIC, HEMATOPOIETIC OR OTHER NEOPLASMS'
#  'POSTPARTUM AND POST ABORTION DIAGNOSIS WITH O.R. PROCEDURE'
#  'BRAIN CONTUSION OR LACERATION AND COMPLICATED SKULL FRACTURE, COMA < 1 HOUR OR NO COMA'
#  'CARDIOMYOPATHY' 'FEMALE REPRODUCTIVE SYSTEM INFECTIONS'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH MAJOR ANOMALY'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH OTHER SIGNIFICANT CONDITION'
#  'OTHER PROCEDURES OF BLOOD AND BLOOD-FORMING ORGANS'
#  'MENTAL ILLNESS DIAGNOSIS WITH O.R. PROCEDURE'
#  'UTERINE AND ADNEXA PROCEDURES FOR OVARIAN AND ADNEXAL MALIGNANCY'
#  'FRACTURE OF FEMUR' 'EATING DISORDERS'
#  'NEONATE BIRTH WEIGHT < 1500 GRAMS WITH MAJOR PROCEDURE'
#  'PELVIC EVISCERATION, RADICAL HYSTERECTOMY AND OTHER RADICAL GYNECOLOGICAL PROCEDURES'
#  'OTHER BLADDER PROCEDURES'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH MAJOR CARDIOVASCULAR PROCEDURE'
#  'NON-ELECTIVE OR COMPLEX KNEE JOINT REPLACEMENT'
#  'ALLOGENEIC BONE MARROW TRANSPLANT'
#  'OTHER PERCUTANEOUS INTRACRANIAL PROCEDURES' 'MAJOR BLADDER PROCEDURES'
#  'NEONATE WITH ECMO' 'MAJOR CARDIOTHORACIC REPAIR OF HEART ANOMALY'
#  'KIDNEY AND URINARY TRACT MALIGNANCY' 'IMPLANTABLE HEART ASSIST SYSTEMS'
#  'ACUTE AND SUBACUTE ENDOCARDITIS'
#  'SKIN GRAFT, EXCEPT HAND, FOR MUSCULOSKELETAL AND CONNECTIVE TISSUE DIAGNOSES'
#  'SHOULDER AND ELBOW JOINT REPLACEMENT'
#  'PERMANENT CARDIAC PACEMAKER IMPLANT WITH AMI, HEART FAILURE OR SHOCK'
#  'DILATION AND CURETTAGE FOR NON-OBSTETRIC DIAGNOSES'
#  'CLEFT LIP AND PALATE REPAIR'
#  'NEONATE, TRANSFERRED < 5 DAYS OLD, NOT BORN HERE' 'UNGROUPABLE'
#  'NEONATE BIRTH WEIGHT < 500 GRAMS, OR BIRTH WEIGHT 500-999 GRAMS AND GESTATIONAL AGE <24 WEEKS, OR BIRTH WEIGHT 500-749 GRAMS WITH MAJOR ANOMALY OR WITHOUT LIFE SUSTAINING INTERVENTION'
#  'BREAST PROCEDURES EXCEPT MASTECTOMY'
#  'NEONATE BIRTH WEIGHT 1500-2499 GRAMS WITH MAJOR PROCEDURE'
#  'MAJOR BILIARY TRACT PROCEDURES'
#  'CRANIOTOMY FOR MULTIPLE SIGNIFICANT TRAUMA' 'RADIOTHERAPY'
#  'NEONATE BIRTH WEIGHT 1000-1249 GRAMS WITH OR WITHOUT SIGNIFICANT CONDITION'
#  'CARDIAC PACEMAKER AND DEFIBRILLATOR REVISION EXCEPT DEVICE REPLACEMENT'
#  'NEONATAL AFTERCARE' 'EXTENSIVE THIRD DEGREE BURNS WITH SKIN GRAFT']
#
# APR MDC Code:
# [ 4  9 14 19  2 11  6  1  5 20  7 18 15  8 16 10  3 25 17 24 12 21 13 23
#  22  0]
#
# APR MDC Description:
# ['DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM'
#  'DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEOUS TISSUE AND BREAST'
#  'PREGNANCY, CHILDBIRTH AND THE PUERPERIUM'
#  'MENTAL DISEASES AND DISORDERS' 'DISEASES AND DISORDERS OF THE EYE'
#  'DISEASES AND DISORDERS OF THE KIDNEY AND URINARY TRACT'
#  'DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM'
#  'DISEASES AND DISORDERS OF THE NERVOUS SYSTEM'
#  'DISEASES AND DISORDERS OF THE CIRCULATORY SYSTEM'
#  'ALCOHOL/DRUG USE AND ALCOHOL/DRUG INDUCED ORGANIC MENTAL DISORDERS'
#  'DISEASES AND DISORDERS OF THE HEPATOBILIARY SYSTEM AND PANCREAS'
#  'INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR UNSPECIFIED SITES)'
#  'NEWBORNS AND OTHER NEONATES WITH CONDITIONS ORIGINATING IN THE PERINATAL PERIOD'
#  'DISEASES AND DISORDERS OF THE MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE'
#  'DISEASES AND DISORDERS OF THE BLOOD AND BLOOD FORMING ORGANS AND IMMUNOLOGICAL DISORDERS'
#  'ENDOCRINE, NUTRITIONAL AND METABOLIC DISEASES AND DISORDERS'
#  'DISEASES AND DISORDERS OF THE EAR, NOSE, MOUTH AND THROAT'
#  'MULTIPLE SIGNIFICANT TRAUMA'
#  'MYELOPROLIFERATIVE DISEASES AND DISORDERS, AND POORLY DIFFERENTIATED NEOPLASM'
#  'HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS'
#  'DISEASES AND DISORDERS OF THE MALE REPRODUCTIVE SYSTEM'
#  'INJURIES, POISONINGS AND TOXIC EFFECTS OF DRUGS'
#  'DISEASES AND DISORDERS OF THE FEMALE REPRODUCTIVE SYSTEM'
#  'FACTORS INFLUENCING HEALTH STATUS AND OTHER CONTACTS WITH HEALTH SERVICES'
#  'BURNS' 'PRE MDC']
#
# APR Severity of Illness Code:
# [3 2 1 4 0]
#
# APR Severity of Illness Description:
# ['Major' 'Moderate' 'Minor' 'Extreme' nan]
#
# APR Risk of Mortality:
# ['Major' 'Minor' 'Moderate' 'Extreme' nan]
#
# APR Medical Surgical Description:
# ['Medical' 'Surgical' 'Not Applicable']
#
# Payment Typology 1:
# ['Medicaid' 'Medicare' 'Blue Cross/Blue Shield' 'Private Health Insurance'
#  'Self-Pay' 'Managed Care, Unspecified' 'Miscellaneous/Other'
#  'Department of Corrections' 'Federal/State/Local/VA']
#
# Payment Typology 2:
# [nan 'Medicaid' 'Private Health Insurance' 'Blue Cross/Blue Shield'
#  'Medicare' 'Self-Pay' 'Federal/State/Local/VA' 'Miscellaneous/Other'
#  'Managed Care, Unspecified' 'Department of Corrections']
#
# Payment Typology 3:
# [nan 'Medicaid' 'Self-Pay' 'Blue Cross/Blue Shield'
#  'Private Health Insurance' 'Medicare' 'Federal/State/Local/VA'
#  'Managed Care, Unspecified' 'Miscellaneous/Other'
#  'Department of Corrections']
#
# Birth Weight:
# [nan '03000' '00800' '02900' '03400' '02200' '03300' '03600' '03200'
#  '02600' '04500' '02700' '06000' '03500' '03700' '02100' '03100' '02300'
#  '03900' '03800' '02500' '02400' '02800' '01600' '01700' '04100' '01000'
#  '01300' '00900' '04000' '00600' '04900' '01800' '01400' '01500' '02000'
#  '01900' '04300' '05300' '04200' '04600' '01100' '00700' '00400' '04400'
#  '07000' '01200' '00500' 'UNKN' '04700' '05100' '05000' '06800' '08000'
#  '04800' '09000' '05900' '05200' '08600' '08200' '05400' '05700' '08300'
#  '07100' '06100' '06300' '07900' '05500' '06400' '05600' '05800' '10800'
#  '06200' '09800']
#
# Emergency Department Indicator:
# ['Y' 'N']
#
# Total Charges:
# ['51,514.62' '25,370.86' '23,876.78' ... '25,573.54' '24,364.49'
#  '58,813.36']
#
# Total Costs:
# ['7,552.54' '3,469.55' '6,180.33' ... '17,519.24' '10,925.53' '31,181.59']

# %% [markdown]
# Checking for exact duplicate records and removing them

# %%
print(f"Duplicate records: {health_data.duplicated().sum()}")
health_data = health_data.drop_duplicates()
# Out:
# Duplicate records: 3844

# %% [markdown]
# Treating missing values

# %% [markdown]
# Dropping columns having more than 50% missing values

# %%
missing_values_percentage = (health_data.isnull().mean() * 100)
print(missing_values_percentage.sort_values(ascending=False))

columns_to_drop = missing_values_percentage[missing_values_percentage > 50].index

health_data = health_data.drop(columns_to_drop, axis=1)
# Out:
# Birth Weight                           90.185636
# Payment Typology 3                     86.008679
# Payment Typology 2                     52.958757
# CCSR Procedure Code                    27.484243
# CCSR Procedure Description             27.484243
# Zip Code - 3 digits                     1.957100
# Operating Certificate Number            0.282876
# Hospital County                         0.255128
# Hospital Service Area                   0.255128
# Permanent Facility Id                   0.255128
# Total Costs                             0.206435
# APR Risk of Mortality                   0.030761
# APR Severity of Illness Description     0.030761
# Length of Stay                          0.000000
# Total Charges                           0.000000
# Emergency Department Indicator          0.000000
# Facility Name                           0.000000
# Age Group                               0.000000
# Payment Typology 1                      0.000000
# APR Medical Surgical Description        0.000000
# APR Severity of Illness Code            0.000000
# Ethnicity                               0.000000
# APR MDC Code                            0.000000
# APR DRG Description                     0.000000
# APR DRG Code                            0.000000
# Gender                                  0.000000
# Race                                    0.000000
# CCSR Diagnosis Description              0.000000
# CCSR Diagnosis Code                     0.000000
# Discharge Year                          0.000000
# Patient Disposition                     0.000000
# Type of Admission                       0.000000
# APR MDC Description                     0.000000
# dtype: float64

# %% [markdown]
# Dropping ['Operating Certificate Number','Discharge Year'] since they don't have any significant importance in the prediction and analysis

# %%
health_data = health_data.drop(['Operating Certificate Number','Discharge Year'], axis = 1)

# %% [markdown]
# Imputing missing values in
# - CCSR Procedure Code on the basis of mode of its grouped CCSR Diagnosis Code
# - CCSR Procedure Description on the basis of mode of its grouped CCSR Procedure Code

# %%
def map_and_fill_missing_values(dataframe, from_col, to_col):
   temp_df = dataframe.copy()

   map = temp_df.groupby(from_col)[to_col].agg(
      lambda x: x.value_counts().idxmax() if x.count() > 0 else None
   ).to_dict()
    
   temp_df[to_col] = temp_df[to_col].fillna(temp_df[from_col].map(map))
   
   return temp_df

# %%
health_data = map_and_fill_missing_values(health_data, "CCSR Diagnosis Code", "CCSR Procedure Code")

# %%
health_data = map_and_fill_missing_values(health_data, "CCSR Procedure Code", "CCSR Procedure Description")

# %% [markdown]
# Checking for missing values

# %%
health_data.isna().sum()
# Out:
# Hospital Service Area                   5250
# Hospital County                         5250
# Permanent Facility Id                   5250
# Facility Name                              0
# Age Group                                  0
# Zip Code - 3 digits                    40273
# Gender                                     0
# Race                                       0
# Ethnicity                                  0
# Length of Stay                             0
# Type of Admission                          0
# Patient Disposition                        0
# CCSR Diagnosis Code                        0
# CCSR Diagnosis Description                 0
# CCSR Procedure Code                        2
# CCSR Procedure Description                 2
# APR DRG Code                               0
# APR DRG Description                        0
# APR MDC Code                               0
# APR MDC Description                        0
# APR Severity of Illness Code               0
# APR Severity of Illness Description      633
# APR Risk of Mortality                    633
# APR Medical Surgical Description           0
# Payment Typology 1                         0
# Emergency Department Indicator             0
# Total Charges                              0
# Total Costs                             4248
# dtype: int64

# %% [markdown]
# Dropping records having missing values since the count is negligible

# %%
health_data = health_data.dropna(axis=0)

health_data.isna().sum()
# Out:
# Hospital Service Area                  0
# Hospital County                        0
# Permanent Facility Id                  0
# Facility Name                          0
# Age Group                              0
# Zip Code - 3 digits                    0
# Gender                                 0
# Race                                   0
# Ethnicity                              0
# Length of Stay                         0
# Type of Admission                      0
# Patient Disposition                    0
# CCSR Diagnosis Code                    0
# CCSR Diagnosis Description             0
# CCSR Procedure Code                    0
# CCSR Procedure Description             0
# APR DRG Code                           0
# APR DRG Description                    0
# APR MDC Code                           0
# APR MDC Description                    0
# APR Severity of Illness Code           0
# APR Severity of Illness Description    0
# APR Risk of Mortality                  0
# APR Medical Surgical Description       0
# Payment Typology 1                     0
# Emergency Department Indicator         0
# Total Charges                          0
# Total Costs                            0
# dtype: int64

# %% [markdown]
# Imputing missing/unknown values of ["Gender", "Type of Admission"] columns with corresponding mode value

# %%
def impute_missing_values_with_mode(dataframe, column, missing_value=None):
    temp_df = dataframe.copy()
    mode_value = temp_df[column].mode()[0]
    temp_df[column] = temp_df[column].replace(missing_value, mode_value)
    return temp_df

# %%
health_data = impute_missing_values_with_mode(health_data, "Gender", missing_value="U")

# %%
health_data = impute_missing_values_with_mode(health_data, "Type of Admission", missing_value="Not Available")

# %% [markdown]
# Treating unknown ethinicity using race

# %%
mode_race_for_unknown_ethinicity = health_data[health_data["Ethnicity"] == "Unknown"]["Race"].mode()[0]
mode_ethinicity_for_selection = health_data[health_data["Race"] == mode_race_for_unknown_ethinicity]["Ethnicity"].mode()[0]
health_data["Ethnicity"] = health_data["Ethnicity"].replace("Unknown", mode_ethinicity_for_selection)

# %% [markdown]
# Converting to different data types:
# - Limiting "120 +" stay duration to 120 and converting column to integer type
# - Replacing "OOS" zip code with largest 3 digit integer and converting values to int type
# - Converting Permanent Facility Id to type int

# %%
health_data["Length of Stay"] = health_data["Length of Stay"].replace("120 +", "120").astype(int)

# %%
health_data["Zip Code - 3 digits"] = health_data["Zip Code - 3 digits"].replace("OOS", "999").astype(int)

# %%
health_data["Permanent Facility Id"] = health_data["Permanent Facility Id"].astype(int)

# %%
health_data["Total Charges"] = health_data["Total Charges"].replace(",", "", regex=True).astype(float)

# %%
health_data["Total Costs"] = health_data["Total Costs"].replace(",", "", regex=True).astype(float)

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2012747 entries, 0 to 2061633
# Data columns (total 28 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   Hospital Service Area                object
#  1   Hospital County                      object
#  2   Permanent Facility Id                int32
#  3   Facility Name                        object
#  4   Age Group                            object
#  5   Zip Code - 3 digits                  int32
#  6   Gender                               object
#  7   Race                                 object
#  8   Ethnicity                            object
#  9   Length of Stay                       int32
#  10  Type of Admission                    object
#  11  Patient Disposition                  object
#  12  CCSR Diagnosis Code                  object
#  13  CCSR Diagnosis Description           object
#  14  CCSR Procedure Code                  object
#  15  CCSR Procedure Description           object
#  16  APR DRG Code                         int64
#  17  APR DRG Description                  object
#  18  APR MDC Code                         int64
#  19  APR MDC Description                  object
#  20  APR Severity of Illness Code         int64
#  21  APR Severity of Illness Description  object
#  22  APR Risk of Mortality                object
#  23  APR Medical Surgical Description     object
#  24  Payment Typology 1                   object
#  25  Emergency Department Indicator       object
#  26  Total Charges                        float64
#  27  Total Costs                          float64
# dtypes: float64(2), int32(3), int64(3), object(20)
# memory usage: 422.3+ MB

# %% [markdown]
# Dealing with Outliers

# %%
def detect_and_impute_outliers(dataframe, column):
    temp_df = dataframe.copy()

    q1 = dataframe[column].quantile(0.25)
    q3 = dataframe[column].quantile(0.75)
    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    outlier_count = temp_df[(temp_df[column] < lower_bound) | (temp_df[column] > upper_bound)].shape[0]
    print(f"Number of outliers in {column}: {outlier_count}")

    temp_df[column] = temp_df[column].mask(temp_df[column] < lower_bound, lower_bound, axis=0)
    temp_df[column] = temp_df[column].mask(temp_df[column] > upper_bound, upper_bound, axis=0)
    return temp_df

# %%
health_data = detect_and_impute_outliers(health_data, "Total Charges")
# Out:
# Number of outliers in Total Charges: 180447

# %%
health_data = detect_and_impute_outliers(health_data, "Total Costs")
# Out:
# Number of outliers in Total Costs: 176491

# %%
health_data.head()
# Out:
#   Hospital Service Area Hospital County  Permanent Facility Id  \
# 0         New York City           Bronx                   3058
# 1         New York City           Bronx                   3058
# 2         New York City           Bronx                   3058
# 3         New York City           Bronx                   3058
# 4         New York City           Bronx                   1168
#
#                                        Facility Name Age Group  \
# 0  Montefiore Med Center - Jack D Weiler Hosp of ...  50 to 69
# 1  Montefiore Med Center - Jack D Weiler Hosp of ...  18 to 29
# 2  Montefiore Med Center - Jack D Weiler Hosp of ...  18 to 29
# 3  Montefiore Med Center - Jack D Weiler Hosp of ...  18 to 29
# 4       Montefiore Medical Center-Wakefield Hospital  18 to 29
#
#    Zip Code - 3 digits Gender                    Race          Ethnicity  \
# 0                  107      F                   White  Not Span/Hispanic
# 1                  104      M  Black/African American   Spanish/Hispanic
# 2                  104      F              Other Race   Spanish/Hispanic
# 3                  100      F  Black/African American  Not Span/Hispanic
# 4                  104      M              Other Race   Spanish/Hispanic
#
#    Length of Stay  ... APR MDC Code  \
# 0               3  ...            4
# 1               1  ...            9
# 2               2  ...           14
# 3               2  ...           14
# 4               4  ...           19
#
#                                  APR MDC Description  \
# 0   DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 1  DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEO...
# 2           PREGNANCY, CHILDBIRTH AND THE PUERPERIUM
# 3           PREGNANCY, CHILDBIRTH AND THE PUERPERIUM
# 4                      MENTAL DISEASES AND DISORDERS
#
#   APR Severity of Illness Code APR Severity of Illness Description  \
# 0                            3                               Major
# 1                            2                            Moderate
# 2                            1                               Minor
# 3                            2                            Moderate
# 4                            2                            Moderate
#
#   APR Risk of Mortality APR Medical Surgical Description  Payment Typology 1  \
# 0                 Major                          Medical            Medicaid
# 1                 Minor                          Medical            Medicaid
# 2                 Minor                          Medical            Medicaid
# 3                 Minor                          Medical            Medicaid
# 4              Moderate                          Medical            Medicaid
#
#   Emergency Department Indicator  Total Charges Total Costs
# 0                              Y       51514.62     7552.54
# 1                              Y       25370.86     3469.55
# 2                              N       23876.78     6180.33
# 3                              Y       43319.05    12588.93
# 4                              Y       40266.23    10355.99
#
# [5 rows x 28 columns]

# %% [markdown]
# Dropping redundant columns

# %%
for col in health_data.columns:
    print(f"{col}: {health_data[col].nunique()}")
# Out:
# Hospital Service Area: 8
# Hospital County: 56
# Permanent Facility Id: 200
# Facility Name: 199
# Age Group: 5
# Zip Code - 3 digits: 50
# Gender: 2
# Race: 4
# Ethnicity: 3
# Length of Stay: 120
# Type of Admission: 5
# Patient Disposition: 19
# CCSR Diagnosis Code: 472
# CCSR Diagnosis Description: 472
# CCSR Procedure Code: 319
# CCSR Procedure Description: 319
# APR DRG Code: 326
# APR DRG Description: 326
# APR MDC Code: 24
# APR MDC Description: 24
# APR Severity of Illness Code: 4
# APR Severity of Illness Description: 4
# APR Risk of Mortality: 4
# APR Medical Surgical Description: 2
# Payment Typology 1: 9
# Emergency Department Indicator: 2
# Total Charges: 1589990
# Total Costs: 1355856

# %%
redundant_columns = ["Facility Name", "CCSR Diagnosis Description", "CCSR Procedure Description", "APR DRG Description", "APR MDC Description", "APR Severity of Illness Description"]
health_data = health_data.drop(redundant_columns, axis=1)

# %%
for col in health_data.columns:
    if health_data[col].dtype == "object":
        print(f"{col}: {health_data[col].nunique()}")
# Out:
# Hospital Service Area: 8
# Hospital County: 56
# Age Group: 5
# Gender: 2
# Race: 4
# Ethnicity: 3
# Type of Admission: 5
# Patient Disposition: 19
# CCSR Diagnosis Code: 472
# CCSR Procedure Code: 319
# APR Risk of Mortality: 4
# APR Medical Surgical Description: 2
# Payment Typology 1: 9
# Emergency Department Indicator: 2

# %% [markdown]
# Encoding categorical data:
# - Target Encoding: ["Hospital Service Area", "Hospital County", "Patient Disposition", "CCSR Diagnosis Code", "CCSR Procedure Code"]
# - Label Encoding: ['Age Group']
# - Direct mapping: ['APR Risk of Mortality', 'Payment Typology 1']
# - One Hot Encoding: ["Gender", "Race", "Ethnicity", "Type of Admission", "APR Medical Surgical Description", "Emergency Department Indicator"]

# %%
target_encoding_columns = ["Hospital Service Area", "Hospital County", "Patient Disposition", "CCSR Diagnosis Code", "CCSR Procedure Code"]
for col in target_encoding_columns:
    health_data[col] = health_data[col].map(dict(health_data.groupby(col)["Length of Stay"].mean()))

# %%
health_data['Age Group'] = LabelEncoder().fit_transform(health_data['Age Group'])

# %%
health_data['APR Risk of Mortality'] = health_data['APR Risk of Mortality'].map({'Minor': 0, 'Moderate': 1, 'Major': 2, 'Extreme': 3})

# %%
temp_dict = dict(health_data['Payment Typology 1'].value_counts() / len(health_data))
health_data['Payment Typology 1'] = health_data['Payment Typology 1'].map(temp_dict)

# %%
for col in health_data.columns:
    if health_data[col].dtype == "object":
        print(f"{col}: {health_data[col].nunique()}")
# Out:
# Gender: 2
# Race: 4
# Ethnicity: 3
# Type of Admission: 5
# APR Medical Surgical Description: 2
# Emergency Department Indicator: 2

# %%
def one_hot_encoding(dataframe, columns):
    encoded_df = pd.get_dummies(dataframe, columns=columns)
    return encoded_df

# %%
one_hot_encoding_columns = ["Gender", "Race", "Ethnicity", "Type of Admission", "APR Medical Surgical Description", "Emergency Department Indicator"]

health_data = one_hot_encoding(health_data, one_hot_encoding_columns)

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2012747 entries, 0 to 2061633
# Data columns (total 34 columns):
#  #   Column                                     Dtype
# ---  ------                                     -----
#  0   Hospital Service Area                      float64
#  1   Hospital County                            float64
#  2   Permanent Facility Id                      int32
#  3   Age Group                                  int32
#  4   Zip Code - 3 digits                        int32
#  5   Length of Stay                             int32
#  6   Patient Disposition                        float64
#  7   CCSR Diagnosis Code                        float64
#  8   CCSR Procedure Code                        float64
#  9   APR DRG Code                               int64
#  10  APR MDC Code                               int64
#  11  APR Severity of Illness Code               int64
#  12  APR Risk of Mortality                      int64
#  13  Payment Typology 1                         float64
#  14  Total Charges                              float64
#  15  Total Costs                                float64
#  16  Gender_F                                   bool
#  17  Gender_M                                   bool
#  18  Race_Black/African American                bool
#  19  Race_Multi-racial                          bool
#  20  Race_Other Race                            bool
#  21  Race_White                                 bool
#  22  Ethnicity_Multi-ethnic                     bool
#  23  Ethnicity_Not Span/Hispanic                bool
#  24  Ethnicity_Spanish/Hispanic                 bool
#  25  Type of Admission_Elective                 bool
#  26  Type of Admission_Emergency                bool
#  27  Type of Admission_Newborn                  bool
#  28  Type of Admission_Trauma                   bool
#  29  Type of Admission_Urgent                   bool
#  30  APR Medical Surgical Description_Medical   bool
#  31  APR Medical Surgical Description_Surgical  bool
#  32  Emergency Department Indicator_N           bool
#  33  Emergency Department Indicator_Y           bool
# dtypes: bool(18), float64(8), int32(4), int64(4)
# memory usage: 264.9 MB

# %%
health_data.to_csv('../../datasets/electronic-health-record/output/transformed_electronic_health_record_dataset.csv', index=False)
