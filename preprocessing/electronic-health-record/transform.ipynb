# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from scipy import stats

# %% [markdown]
# Reading data from the SPARCS dataset into a dataframe

# %%
data = pd.read_csv("../../datasets/electronic-health-record/input/electronic_health_record_dataset.csv", low_memory=False)

# %%
health_data = data.copy()

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Hospital Service Area                24920 non-null  object
#  1   Hospital County                      24920 non-null  object
#  2   Operating Certificate Number         24915 non-null  float64
#  3   Permanent Facility Id                24920 non-null  float64
#  4   Facility Name                        25000 non-null  object
#  5   Age Group                            25000 non-null  object
#  6   Zip Code - 3 digits                  24460 non-null  object
#  7   Gender                               25000 non-null  object
#  8   Race                                 25000 non-null  object
#  9   Ethnicity                            25000 non-null  object
#  10  Length of Stay                       25000 non-null  object
#  11  Type of Admission                    25000 non-null  object
#  12  Patient Disposition                  25000 non-null  object
#  13  Discharge Year                       25000 non-null  int64
#  14  CCSR Diagnosis Code                  25000 non-null  object
#  15  CCSR Diagnosis Description           25000 non-null  object
#  16  CCSR Procedure Code                  18429 non-null  object
#  17  CCSR Procedure Description           18429 non-null  object
#  18  APR DRG Code                         25000 non-null  int64
#  19  APR DRG Description                  25000 non-null  object
#  20  APR MDC Code                         25000 non-null  int64
#  21  APR MDC Description                  25000 non-null  object
#  22  APR Severity of Illness Code         25000 non-null  int64
#  23  APR Severity of Illness Description  24991 non-null  object
#  24  APR Risk of Mortality                24991 non-null  object
#  25  APR Medical Surgical Description     25000 non-null  object
#  26  Payment Typology 1                   25000 non-null  object
#  27  Payment Typology 2                   10573 non-null  object
#  28  Payment Typology 3                   3246 non-null   object
#  29  Birth Weight                         3472 non-null   object
#  30  Emergency Department Indicator       25000 non-null  object
#  31  Total Charges                        25000 non-null  object
#  32  Total Costs                          24953 non-null  object
# dtypes: float64(2), int64(4), object(27)
# memory usage: 6.3+ MB

# %% [markdown]
# Attributes and unique value present in them

# %%
def print_unique_values(dataframe):
    for col in dataframe.columns:
        print(f"{col}:\n{dataframe[col].unique()}", end="\n\n")

# %%
print_unique_values(health_data)
# Out:
# Hospital Service Area:
# ['New York City' 'Central NY' 'Finger Lakes' 'Western NY' 'Long Island'
#  'Hudson Valley' 'Capital/Adirond' 'Southern Tier' nan]
#
# Hospital County:
# ['Manhattan' 'Tompkins' 'Kings' 'Chemung' 'Erie' 'Onondaga' 'Wayne'
#  'Nassau' 'Westchester' 'Suffolk' 'Richmond' 'Bronx' 'Monroe' 'Albany'
#  'Broome' 'Queens' 'Genesee' 'Orange' 'Rockland' 'Sullivan' 'Chautauqua'
#  'Otsego' nan 'Oneida' 'Clinton' 'Warren' 'Dutchess' 'Schenectady'
#  'Madison' 'Niagara' 'Cayuga' 'Jefferson' 'Steuben' 'St Lawrence' 'Fulton'
#  'Saratoga' 'Livingston' 'Ontario' 'Putnam' 'Cattaraugus' 'Franklin'
#  'Cortland' 'Oswego' 'Allegany' 'Chenango' 'Wyoming' 'Montgomery' 'Ulster'
#  'Columbia' 'Orleans' 'Lewis' 'Schoharie' 'Yates' 'Schuyler' 'Herkimer'
#  'Essex' 'Delaware']
#
# Operating Certificate Number:
# [7002054. 5401001. 7001021.  701000. 7002053. 1401013. 3301008. 7001020.
#  1401014. 5820000. 2908000. 5907002. 5154001. 5154000. 7004003. 7000006.
#  2951001. 5151001. 2701005. 5153000. 3301007. 7002024. 7002032. 5957001.
#  2754001.  101000. 5155000.  303001. 7003004. 7001002. 7001016. 5907001.
#  2950001. 1801000. 7000001. 2701001. 7003007. 3529000. 7003000. 7003001.
#  4329000. 7002001. 5263000. 7003010. 7000002. 3523000. 5149001. 7000014.
#  2950002.  602001. 3824000. 7003003. 5920000.      nan 7002020. 3201002.
#   901001. 5601000. 7000024. 1302001. 4324000. 5922000. 7004010. 3202003.
#  4601001. 7001035. 2601001. 2701003. 3102000. 5902001. 2909000. 7002009.
#   501000. 7002017. 7002012. 7002021. 7001003. 2238700. 5901000. 5957000.
#  1401008. 7000008. 5001000. 7001009. 2201000. 4401000. 3121001. 1701000.
#  4501000. 3522000. 2527000. 4429000. 3301003. 5904001. 1401005. 7001045.
#  5932000. 3429000. 3950000. 7001037.  401001. 7001024. 1327000.  301001.
#  1623001. 4322000. 1101000. 5149000. 3702000.  228000.  824000. 5157003.
#  6027000. 2801001. 5501001. 5501000. 7002002. 3202002. 5902002. 7002026.
#  2952005. 4423701. 7001008. 2953000. 3535001. 3101000. 5123000.  601000.
#  3801000. 5127000. 3421000. 1401010. 5903001. 1001000. 1404000. 7001046.
#  2901000. 4402001. 2625700. 2952006.  701001. 3402000. 3622700. 1427000.
#  2424700. 5002001. 1624000. 7002050. 7000011. 4720700. 6120700. 4402000.
#  4823700. 2129700. 2221700. 5022000. 1552701. 1254700.]
#
# Permanent Facility Id:
# [1.4580e+03 1.4640e+03 9.7700e+02 1.3060e+03 1.1600e+02 1.4630e+03
#  2.1800e+02 6.3600e+02 1.3050e+03 2.0800e+02 1.0280e+03 5.1100e+02
#  1.1330e+03 9.2500e+02 9.2400e+02 1.7400e+03 3.0580e+03 5.4100e+02
#  2.4500e+02 1.1690e+03 4.1300e+02 9.1300e+02 6.3500e+02 1.4560e+03
#  1.4690e+03 1.1390e+03 4.7100e+02 1.0000e+00 9.3800e+02 5.8000e+01
#  3.3760e+03 1.2860e+03 3.0670e+03 1.3010e+03 1.0970e+03 5.2700e+02
#  3.3900e+02 1.1780e+03 4.0900e+02 1.6330e+03 7.0400e+02 1.6260e+03
#  1.6280e+03 7.7900e+02 1.4380e+03 9.7100e+02 1.6370e+03 1.1650e+03
#  1.4370e+03 6.9900e+02 8.9600e+02 1.1760e+03 3.9750e+03 5.2800e+02
#  1.0300e+02 1.3040e+03 1.1680e+03 1.6380e+03 7.4600e+02 1.6290e+03
#  1.1170e+03        nan 1.4530e+03 5.8900e+02 1.3500e+02 1.0050e+03
#  1.1860e+03 1.8100e+02 7.7600e+02 1.1220e+03 1.8000e+02 1.7380e+03
#  5.9900e+02 8.4800e+02 1.4660e+03 1.3180e+03 3.9700e+02 4.1100e+02
#  5.7400e+02 1.0450e+03 5.1300e+02 1.4450e+03 8.5000e+01 1.4500e+03
#  1.4470e+03 1.4540e+03 1.2880e+03 3.7900e+02 8.8900e+02 1.0390e+03
#  1.1380e+03 2.1300e+02 1.1720e+03 8.6600e+02 1.2940e+03 3.6700e+02
#  7.9800e+02 5.8300e+02 3.3000e+02 8.1800e+02 6.9400e+02 3.9300e+02
#  8.1500e+02 6.3000e+02 1.0720e+03 1.6300e+03 2.1000e+02 1.6920e+03
#  1.1290e+03 6.7800e+02 1.0470e+03 7.5200e+02 1.3200e+03 6.2800e+02
#  6.6000e+01 1.6350e+03 1.9200e+02 1.1640e+03 4.3000e+01 3.2400e+02
#  7.7500e+02 1.5800e+02 8.9500e+02 7.2700e+02 3.9000e+01 1.2800e+02
#  9.4300e+02 1.1530e+03 4.8400e+02 9.9000e+02 8.2900e+02 1.4390e+03
#  1.3240e+03 5.9800e+02 1.6390e+03 5.5000e+02 1.0460e+03 4.2000e+01
#  1.4600e+03 1.2000e+01 1.0980e+03 5.5200e+02 1.3090e+03 5.1800e+02
#  8.1200e+02 3.4000e+02 2.0700e+02 1.1800e+02 1.2930e+03 1.7370e+03
#  5.6300e+02 1.4460e+03 7.0800e+02 5.6500e+02 8.8500e+02 9.8000e+01
#  1.3150e+03 7.3900e+02 1.0990e+03 8.9100e+02 6.7600e+02 2.1600e+02
#  4.1200e+02 1.0610e+03 1.4600e+02 2.6700e+02 4.9000e+02 8.0400e+02
#  4.0100e+02 5.5100e+02 6.7100e+02 7.1800e+02 2.8000e+02 9.0590e+03
#  1.0355e+04 3.8300e+02 8.7000e+02 3.2500e+02 1.4860e+03 1.0223e+04
#  1.1240e+03 9.8900e+02 1.1750e+03 2.9200e+02 1.0216e+04 1.1580e+03
#  8.5800e+02 3.6200e+02 3.7700e+02 8.7300e+02 3.0300e+02 1.6500e+02]
#
# Facility Name:
# ['New York-Presbyterian Hospital - New York Weill Cornell Center'
#  'New York-Presbyterian Hospital - Columbia Presbyterian Center'
#  'Cayuga Medical Center at Ithaca'
#  'New York - Presbyterian Brooklyn Methodist Hospital'
#  'Arnot Ogden Medical Center' 'NYU Langone Hospitals'
#  'Sisters of Charity Hospital' 'Crouse Hospital'
#  'Maimonides Medical Center' "John R. Oishei Children's Hospital"
#  'Newark-Wayne Community Hospital' 'NYU Langone Hospital-Long Island'
#  "St. Joseph's MC-St. Vincent's Westchester Division"
#  'Good Samaritan Hospital Medical Center'
#  'South Shore University Hospital' 'Staten Island University Hosp-North'
#  'Montefiore Med Center - Jack D Weiler Hosp of A Einstein College Div'
#  'North Shore University Hospital' 'Stony Brook University Hospital'
#  'Montefiore Medical Center - Henry & Lucy Moses Div'
#  'Strong Memorial Hospital' 'Huntington Hospital'
#  'University Hospital SUNY Health Science Center' 'Mount Sinai Hospital'
#  'Mount Sinai Morningside' 'Westchester Medical Center'
#  'The Unity Hospital of Rochester' 'Albany Medical Center Hospital'
#  'Peconic Bay Medical Center'
#  'United Health Services Hospitals Inc. - Wilson Medical Center'
#  "Cohen Children's Medical Center" 'Brookdale Hospital Medical Center'
#  'Millard Fillmore Suburban Hospital' 'Kings County Hospital Center'
#  'SJRH - St Johns Division' 'Mount Sinai South Nassau'
#  'United Memorial Medical Center North Street Campus'
#  'BronxCare Hospital Center' 'Highland Hospital' 'Queens Hospital Center'
#  'St Anthony Community Hospital' 'Elmhurst Hospital Center'
#  'Flushing Hospital Medical Center' 'Good Samaritan Hospital of Suffern'
#  'Bellevue Hospital Center' 'Garnet Health Medical Center - Catskills'
#  'New York - Presbyterian/Queens' 'Jacobi Medical Center'
#  'New York-Presbyterian/Lower Manhattan Hospital'
#  'Garnet Health Medical Center' 'St. Charles Hospital' 'SBH Health System'
#  'New York Presbyterian Hospital - Allen Hospital'
#  'Nassau University Medical Center' 'UPMC Chautauqua at WCA'
#  'NYU Langone Hospital-Brooklyn'
#  'Montefiore Medical Center-Wakefield Hospital'
#  'Long Island Jewish Forest Hills' 'Mary Imogene Bassett Hospital'
#  'Jamaica Hospital Medical Center' 'Northern Westchester Hospital'
#  'Redacted for Confidentiality'
#  'Memorial Hospital for Cancer and Allied Diseases'
#  'Rome Memorial Hospital, Inc'
#  'The University of Vermont Health Network - Champlain Valley Physicians Hospital'
#  'Glens Falls Hospital' 'North Central Bronx Hospital'
#  'Vassar Brothers Medical Center' 'Montefiore Nyack'
#  'New York - Presbyterian Hospital'
#  'Mid-Hudson Valley Division of Westchester Medical Center'
#  'Richmond University Medical Center'
#  'Faxton-St Lukes Healthcare St Lukes Division'
#  "Ellis Hospital - Bellevue Woman's Care Center Division"
#  'Mount Sinai West' 'Wyckoff Heights Medical Center'
#  'Oneida Health Hospital' 'Rochester General Hospital'
#  'Niagara Falls Memorial Medical Center' 'White Plains Hospital Center'
#  'Mercy Hospital' 'Harlem Hospital Center' 'Auburn Community Hospital'
#  'Lenox Hill Hospital' 'Hospital for Special Surgery'
#  'Metropolitan Hospital Center'
#  'Brooklyn Hospital Center - Downtown Campus' 'Carthage Area Hospital Inc'
#  'Stony Brook Southampton Hospital'
#  'NewYork-Presbyterian/Hudson Valley Hospital'
#  "Blythedale Children's Hospital" 'Mercy Hospital of Buffalo'
#  'Lincoln Medical & Mental Health Center' 'Corning Hospital'
#  'Coney Island Hospital' 'Samaritan Medical Center'
#  'Claxton-Hepburn Medical Center'
#  "Mount St. Mary's Hospital and Health Center" 'Nathan Littauer Hospital'
#  'Saratoga Hospital' "St Luke's Cornwall Hospital/Newburgh"
#  'Nicholas H. Noyes Memorial Hospital' 'Canton-Potsdam Hospital'
#  "St. Joseph's Hospital Health Center" 'Montefiore New Rochelle Hospital'
#  'Long Island Jewish Medical Center' 'Erie County Medical Center'
#  'Woodhull Medical & Mental Health Center' 'Phelps Hospital'
#  'F.F. Thompson Hospital'
#  'New York-Presbyterian Westchester Behavioral Health Center'
#  'Putnam Hospital' 'University Hospital of Brooklyn'
#  'UPSTATE University Hospital at Community General'
#  'Olean General Hospital' 'St Johns Episcopal Hospital So Shore'
#  'Northern Dutchess Hospital' 'Our Lady of Lourdes Memorial Hospital'
#  'Adirondack Medical Center-Saranac Lake Site' 'Helen Hayes Hospital'
#  'Guthrie Cortland Medical Center'
#  'John T Mather Memorial Hospital of Port Jefferson New York Inc'
#  'Oswego Hospital'
#  'Memorial Hosp of Wm F & Gertrude F Jones A/K/A Jones Memorial Hosp'
#  'Chenango Memorial Hospital Inc' 'St Catherine of Siena Hospital'
#  'Wyoming County Community Hospital' "St. Mary's Healthcare"
#  'HealthAlliance Hospital Broadway Campus' 'Ellis Hospital'
#  'Mount Sinai Beth Israel' 'Mount Sinai Brooklyn'
#  'St Elizabeth Medical Center'
#  'Mount Sinai Hospital - Mount Sinai Hospital of Queens'
#  'Syosset Hospital' 'Winifred Masterson Burke Rehabilitation Hospital'
#  'United Health Services Hospitals Inc. - Binghamton General Hospital'
#  'New York Eye and Ear Infirmary of Mount Sinai'
#  'Lakeview Center for Mental Health and Wellness'
#  "St. Joseph's Medical Center" 'Plainview Hospital'
#  'Interfaith Medical Center' 'Long Island Jewish Valley Stream'
#  'Gouverneur Hospital' 'United Memorial Medical Center Bank Street Campus'
#  'Buffalo General Medical Center' "St. Joseph's Hospital"
#  'New York Community Hospital of Brooklyn, Inc'
#  "Staten Island University Hospital Prince's Bay"
#  'St. Francis Hospital & Heart Center' 'NYU Langone Orthopedic Hospital'
#  'Bon Secours Community Hospital'
#  'Eastern Niagara Hospital - Lockport Division'
#  'Long Island Community Hospital' 'Brooks-TLC Hospital System, Inc.'
#  'Kingsbrook Jewish Medical Center' 'A.O. Fox Memorial Hospital'
#  'SJRH - Park Care Pavilion' 'Stony Brook Eastern Long Island Hospital'
#  'Clifton Springs Hospital and Clinic' 'Roswell Park Cancer Institute'
#  'Unity Specialty Hospital' 'Montefiore Mount Vernon Hospital'
#  'Columbia Memorial Hospital' 'Kenmore Mercy Hospital'
#  'Glen Cove Hospital' 'Massena Hospital' 'Community Memorial Hospital Inc'
#  'St. Joseph Hospital' 'Geneva General Hospital'
#  'Medina Memorial Hospital' 'Bertrand Chaffee Hospital'
#  'Crouse Hospital - Commonwealth Division'
#  'David H. Koch Center For Cancer Care' 'Lewis County General Hospital'
#  'St. James Hospital'
#  'The University of Vermont Health Network - Alice Hyde Medical Center'
#  'Henry J. Carter Specialty Hospital' 'Calvary Hospital'
#  'SJRH - Dobbs Ferry Pavillion'
#  "HealthAlliance Hospital Mary's Avenue Campus" 'Calvary Hospital Inc'
#  'Sisters of Charity Hospital - St. Joseph Campus'
#  'Cobleskill Regional Hospital'
#  'Soldiers and Sailors Memorial Hospital of Yates County'
#  'Schuyler Hospital' 'Little Falls Hospital' 'River Hospital, Inc.'
#  'Ira Davenport Memorial Hospital'
#  'The University of Vermont Health Network - Elizabethtown Community Hospital'
#  "O'Connor Hospital"]
#
# Age Group:
# ['0 to 17' '18 to 29' '30 to 49' '50 to 69' '70 or Older']
#
# Zip Code - 3 digits:
# ['104' '109' '148' '112' '142' '132' '149' '145' '147' '130' '118' '108'
#  '117' '111' '110' '146' '134' '143' '100' '105' '144' '124' '119' '138'
#  '140' 'OOS' '120' '137' nan '103' '107' '141' '114' '113' '123' '131'
#  '127' '125' '115' '135' '133' '122' '129' '128' '139' '126' '121' '136'
#  '106' '101' '116']
#
# Gender:
# ['F' 'M' 'U']
#
# Race:
# ['Other Race' 'White' 'Black/African American' 'Multi-racial']
#
# Ethnicity:
# ['Unknown' 'Not Span/Hispanic' 'Spanish/Hispanic' 'Multi-ethnic']
#
# Length of Stay:
# ['10' '4' '3' '1' '2' '6' '13' '81' '34' '35' '9' '5' '51' '21' '22' '11'
#  '31' '59' '36' '62' '8' '7' '20' '92' '16' '80' '18' '53' '74' '26' '37'
#  '14' '12' '114' '17' '27' '19' '70' '24' '78' '15' '30' '88' '50' '49'
#  '120 +' '43' '119' '33' '46' '90' '45' '44' '84' '25' '77' '32' '52' '41'
#  '66' '87' '75' '40' '29' '28' '38' '105' '54' '58' '91' '102' '85' '39'
#  '72' '93' '42' '107' '65' '73' '79' '68' '23' '71' '47' '89' '56' '60'
#  '64' '55' '63' '103' '57' '108' '48' '113' '61' '67' '86' '109' '98' '69'
#  '106' '82' '96' '99' '115']
#
# Type of Admission:
# ['Newborn' 'Emergency' 'Elective' 'Urgent' 'Trauma' 'Not Available']
#
# Patient Disposition:
# ['Home or Self Care' 'Left Against Medical Advice'
#  'Home w/ Home Health Services' 'Skilled Nursing Home'
#  "Cancer Center or Children's Hospital" 'Short-term Hospital'
#  'Psychiatric Hospital or Unit of Hosp' 'Expired' 'Hospice - Home'
#  'Another Type Not Listed' 'Facility w/ Custodial/Supportive Care'
#  'Medicare Cert Long Term Care Hospital'
#  'Inpatient Rehabilitation Facility' 'Federal Health Care Facility'
#  'Hospice - Medical Facility' 'Court/Law Enforcement'
#  'Hosp Basd Medicare Approved Swing Bed' 'Medicaid Cert Nursing Facility'
#  'Critical Access Hospital']
#
# Discharge Year:
# [2022]
#
# CCSR Diagnosis Code:
# ['PNL001' 'RSP005' 'SKN001' 'FAC006' 'MAL002' 'MBD002' 'END011' 'INF012'
#  'MBD001' 'MBD007' 'PRG026' 'INF002' 'NVS009' 'INJ004' 'MUS026' 'NVS020'
#  'RSP014' 'GEN003' 'END003' 'MBD004' 'PRG020' 'BLD007' 'MUS002' 'DIG009'
#  'RSP009' 'DIG001' 'INJ018' 'INJ001' 'PNL007' 'RSP002' 'RSP012' 'MAL008'
#  'GEN026' 'RSP004' 'NEO072' 'NEO048' 'FAC003' 'DIG025' 'INJ036' 'INJ022'
#  'MUS024' 'MAL007' 'MBD014' 'RSP003' 'DIG022' 'INF008' 'INJ005' 'NEO073'
#  'NEO057' 'GEN016' 'MAL001' 'BLD005' 'DIG010' 'SYM004' 'NEO024' 'INF009'
#  'MUS021' 'DIG003' 'INJ037' 'GEN004' 'GEN018' 'SYM002' 'INF001' 'MBD012'
#  'DIG004' 'INJ008' 'RSP011' 'INJ035' 'INJ019' 'RSP006' 'EAR001' 'BLD006'
#  'INJ024' 'NEO020' 'PNL013' 'BLD003' 'MBD003' 'NEO023' 'DIG012' 'INJ020'
#  'INJ033' 'DIG002' 'SYM010' 'INJ032' 'END008' 'PNL004' 'NEO059' 'NEO033'
#  'CIR031' 'SYM012' 'EAR002' 'EYE005' 'PNL006' 'SYM006' 'MAL010' 'DIG024'
#  'INJ011' 'RSP001' 'PNL009' 'NVS015' 'SYM017' 'PRG023' 'GEN022' 'MUS028'
#  'END016' 'CIR003' 'MAL006' 'CIR039' 'NVS001' 'DIG011' 'MUS001' 'PNL002'
#  'SYM016' 'MAL004' 'END013' 'SYM008' 'INJ023' 'DIG020' 'PNL012' 'MUS022'
#  'PRG013' 'DIG017' 'GEN006' 'MUS007' 'SYM001' 'END002' 'INJ031' 'CIR016'
#  'INF005' 'INJ002' 'MBD008' 'CIR005' 'DIG018' 'EYE007' 'EYE011' 'FAC010'
#  'NVS006' 'END015' 'DIG007' 'MUS023' 'MBD018' 'INJ045' 'NEO017' 'NEO001'
#  'INJ013' 'INJ026' 'INJ006' 'NEO056' 'INJ003' 'DIG021' 'MUS030' 'MUS029'
#  'INJ012' 'GEN005' 'NVS017' 'NVS002' 'MUS010' 'MBD010' 'MBD025' 'SKN002'
#  'NVS014' 'BLD001' 'EAR006' 'PNL005' 'SYM005' 'DIG019' 'INJ010' 'MBD019'
#  'DIG015' 'INJ017' 'NEO074' 'GEN001' 'SYM011' 'NVS016' 'INJ007' 'SYM013'
#  'MAL005' 'RSP007' 'PNL011' 'PRG022' 'MUS014' 'CIR013' 'SYM014' 'BLD002'
#  'PRG028' 'EYE008' 'MAL003' 'NVS021' 'DIG008' 'PRG024' 'GEN002' 'NVS010'
#  'NVS007' 'FAC008' 'CIR019' 'GEN025' 'PRG014' 'CIR014' 'RSP010' 'CIR017'
#  'RSP016' 'CIR024' 'PRG029' 'NEO010' 'NEO031' 'END007' 'MUS011' 'CIR033'
#  'MBD017' 'PRG016' 'INF006' 'PRG011' 'PRG019' 'END009' 'MBD021' 'EYE003'
#  'PRG012' 'NEO070' 'CIR012' 'MBD009' 'CIR008' 'NVS012' 'PRG027' 'FAC025'
#  'INF007' 'PRG018' 'CIR006' 'MBD013' 'DIG013' 'CIR020' 'INJ021' 'DIG016'
#  'GEN017' 'INJ009' 'PRG005' 'INJ014' 'INJ049' 'NEO058' 'CIR021' 'MBD020'
#  'CIR004' 'INJ034' 'BLD010' 'INJ046' 'NVS005' 'NEO049' 'RSP017' 'PRG003'
#  'NEO002' 'MBD022' 'NEO062' 'INJ038' 'SYM007' 'END001' 'NVS008' 'PRG021'
#  'RSP008' 'PRG017' 'SYM015' 'GEN019' 'DIG014' 'INJ030' 'EYE006' 'NEO015'
#  'INF003' 'PRG004' 'GEN021' 'MUS038' 'NEO050' 'INF010' 'CIR029' 'PRG009'
#  'SKN003' 'INJ043' 'GEN014' 'PRG010' 'INJ040' 'GEN013' 'SKN007' 'MUS006'
#  'CIR009' 'MUS025' 'DIG006' 'BLD004' 'NEO060' 'CIR011' 'EYE004' 'MBD006'
#  'DIG005' 'MBD005' 'INJ039' 'MBD011' 'CIR038' 'DIG023' 'NEO011' 'INJ042'
#  'MUS003' 'PRG006' 'NVS013' 'NVS004' 'INJ025' 'NEO029' 'NVS018' 'EAR003'
#  'MUS013' 'MUS033' 'NEO045' 'NEO032' 'GEN009' 'INJ016' 'NVS019' 'FAC004'
#  'NEO030' 'NEO064' 'MUS037' 'SKN006' 'NEO052' 'NEO039' 'CIR007' 'SYM003'
#  'SKN004' 'CIR027' 'NEO022' 'CIR030' 'MUS009' 'NEO065' 'CIR018' 'NEO004'
#  'CIR025' 'NEO025' 'NEO035' 'EYE010' 'NEO018' 'INJ056' 'END010' 'CIR022'
#  'CIR001' 'INJ041' 'NEO012' 'GEN007' 'NEO016' 'CIR026' 'NEO013' 'BLD008'
#  'NEO066' 'CIR032' 'EYE001' 'MUS031' 'NEO051' 'MUS016' 'NEO021' 'CIR028'
#  'CIR036' 'NEO043' 'NEO044' 'GEN012' 'NEO068' 'NEO061' 'NVS011' 'CIR034'
#  'MUS015' 'CIR015' 'CIR023' 'GEN023' 'INF004' 'NEO071' 'MUS018' 'NEO014'
#  'NEO008' 'NEO034' 'INJ076' 'EYE012' 'CIR035' 'NEO009' 'INJ027' 'MUS034'
#  'MBD026' 'GEN020' 'NEO003' 'FAC014' 'INJ069' 'NEO041' 'NEO005' 'INJ073'
#  'NEO037' 'NEO019' 'NEO027' 'NEO036' 'RSP015' 'END014' 'RSP013' 'NEO038'
#  'NEO026']
#
# CCSR Diagnosis Description:
# ['Liveborn' 'Acute bronchitis' 'Skin and subcutaneous tissue infections'
#  'Encounter for antineoplastic therapies' 'Digestive congenital anomalies'
#  'Depressive disorders' 'Fluid and electrolyte disorders' 'COVID-19'
#  'Schizophrenia spectrum and other psychotic disorders'
#  'Trauma- and stressor-related disorders'
#  'OB-related trauma to perineum and vulva' 'Septicemia'
#  'Epilepsy; convulsions' 'Fracture of the upper limb, initial encounter'
#  'Muscle disorders'
#  'Other nervous system disorders (neither hereditary nor degenerative)'
#  'Pneumothorax' 'Chronic kidney disease'
#  'Diabetes mellitus with complication'
#  'Other specified and unspecified mood disorders'
#  'Hypertension and hypertensive-related conditions complicating pregnancy; childbirth; and the puerperium'
#  'Diseases of white blood cells' 'Osteomyelitis'
#  'Appendicitis and other appendiceal conditions' 'Asthma'
#  'Intestinal infection' 'Crushing injury, initial encounter'
#  'Fracture of head and neck, initial encounter'
#  'Hemolytic jaundice and perinatal jaundice'
#  'Pneumonia (except that caused by tuberculosis)'
#  'Respiratory failure; insufficiency; arrest'
#  'Musculoskeletal congenital conditions'
#  'Postprocedural or postoperative genitourinary system complication'
#  'Acute and chronic tonsillitis'
#  'Neoplasms of unspecified nature or uncertain behavior'
#  'Nervous system cancers - brain'
#  'Encounter for observation and examination for conditions ruled out (excludes infectious disease, neoplasm, mental disorders)'
#  'Other specified and unspecified gastrointestinal disorders'
#  'Complication of transplanted organs or tissue, initial encounter'
#  'Poisoning by drugs, initial encounter'
#  'Systemic lupus erythematosus and connective tissue disorders'
#  'Respiratory congenital malformations' 'Neurodevelopmental disorders'
#  'Influenza' 'Noninfectious gastroenteritis' 'Viral infection'
#  'Fracture of the lower limb (except hip), initial encounter'
#  'Benign neoplasms' 'Hodgkin lymphoma'
#  'Other specified male genital disorders'
#  'Cardiac and circulatory congenital anomalies' 'Sickle cell trait/anemia'
#  'Abdominal hernia' 'Nausea and vomiting' 'Sarcoma'
#  'Parasitic, other specified and unspecified infections'
#  'Acquired foot deformities' 'Diseases of mouth; excluding dental'
#  'Complication of other surgical or medical care, injury, initial encounter'
#  'Urinary tract infections'
#  'Inflammatory diseases of female pelvic organs' 'Fever' 'Tuberculosis'
#  'Suicidal ideation/attempt/intentional self-harm' 'Esophageal disorders'
#  'Traumatic brain injury (TBI); concussion, initial encounter'
#  'Pleurisy, pleural effusion and pulmonary collapse'
#  'Complication of internal orthopedic device or implant, initial encounter'
#  'Burn and corrosion, initial encounter'
#  'Other specified upper respiratory infections' 'Otitis media'
#  'Coagulation and hemorrhagic disorders'
#  'Sprains and strains, initial encounter'
#  'Gastrointestinal cancers - peritoneum'
#  'Other specified and unspecified perinatal conditions' 'Aplastic anemia'
#  'Bipolar and related disorders' 'Bone cancer'
#  'Intestinal obstruction and ileus'
#  'Effect of foreign body entering opening, initial encounter'
#  'Complication of cardiovascular device, implant or graft, initial encounter'
#  'Disorders of teeth and gingiva' 'Nervous system signs and symptoms'
#  'Maltreatment/abuse' 'Malnutrition' 'Neonatal cerebral disorders'
#  'Leukemia - acute lymphoblastic leukemia (ALL)'
#  'Female reproductive system cancers - ovary' 'Hypotension'
#  'Circulatory signs and symptoms'
#  'Diseases of middle ear and mastoid (except otitis media)'
#  'Retinal and vitreous conditions' 'Respiratory perinatal condition'
#  'Abdominal pain and other digestive/abdomen signs and symptoms'
#  'Other specified and unspecified congenital anomalies'
#  'Postprocedural or postoperative digestive system complication'
#  'Open wounds of head and neck, initial encounter' 'Sinusitis'
#  'Perinatal infections' 'Polyneuropathies'
#  'Abnormal findings without diagnosis'
#  'Complications specified during childbirth' 'Benign ovarian cyst'
#  'Other specified bone disease and musculoskeletal deformities'
#  'Other specified and unspecified nutritional and metabolic disorders'
#  'Nonrheumatic and unspecified valve disorders' 'Cleft lip or palate'
#  'Other specified diseases of veins and lymphatics' 'Meningitis'
#  'Regional enteritis and ulcerative colitis' 'Infective arthritis'
#  'Short gestation; low birth weight; and fetal growth retardation'
#  'Other general signs and symptoms' 'Nervous system congenital anomalies'
#  'Pituitary disorders' 'Symptoms of mental and substance use conditions'
#  'Toxic effects, initial encounter'
#  'Pancreatic disorders (excluding diabetes)'
#  'Neonatal digestive and feeding disorders'
#  'Scoliosis and other postural dorsopathic deformities'
#  'Maternal care related to fetal conditions' 'Biliary tract disease'
#  'Other specified and unspecified diseases of kidney and ureters'
#  'Other specified joint disorders' 'Syncope'
#  'Diabetes mellitus without complication' 'Allergic reactions'
#  'Conduction disorders' 'Foodborne intoxications'
#  'Fracture of the spine and back, initial encounter'
#  'Disruptive, impulse-control and conduct disorders'
#  'Myocarditis and cardiomyopathy' 'Hepatic failure' 'Strabismus'
#  'Postprocedural or postoperative eye complication'
#  'Other aftercare encounter'
#  'Other nervous system disorders (often hereditary or degenerative)'
#  'Other specified and unspecified endocrine disorders'
#  'Gastritis and duodenitis' 'Acquired deformities (excluding foot)'
#  'Opioid-related disorders'
#  'Traumatic brain injury (TBI); concussion, subsequent encounter'
#  'Gastrointestinal cancers - liver' 'Head and neck cancers - eye'
#  'Open wounds of trunk, initial encounter' 'Other specified injury'
#  'Fracture of the neck of the femur (hip), initial encounter'
#  'Endocrine system cancers - all other types'
#  'Fracture of torso, initial encounter' 'Gastrointestinal hemorrhage'
#  'Aseptic necrosis and osteonecrosis' 'Disorders of jaw'
#  'Open wounds to limbs, initial encounter' 'Calculus of urinary tract'
#  'Nerve and nerve root disorders' 'Encephalitis'
#  'Musculoskeletal pain, not low back pain' 'Feeding and eating disorders'
#  'Other specified substance-related disorders'
#  'Other specified inflammatory condition of skin' 'CNS abscess'
#  'Nutritional anemia'
#  'Other specified and unspecified disorders of the ear'
#  'Respiratory distress syndrome' 'Dysphagia'
#  'Other specified and unspecified liver disease'
#  'Internal organ injury, initial encounter' 'Cannabis-related disorders'
#  'Anal and rectal conditions'
#  'Superficial injury; contusion, initial encounter'
#  'Conditions due to neoplasm or the treatment of neoplasm'
#  'Nephritis; nephrosis; renal sclerosis'
#  'Genitourinary signs and symptoms' 'Sleep wake disorders'
#  'Dislocations, initial encounter' 'Respiratory signs and symptoms'
#  'Congenital malformations of eye, ear, face, neck'
#  'Other specified and unspecified upper respiratory disease'
#  'Hemorrhagic and hematologic disorders of newborn' 'Prolonged pregnancy'
#  'Pathological fracture, initial encounter' 'Acute pulmonary embolism'
#  'Skin/Subcutaneous signs and symptoms' 'Hemolytic anemia'
#  'Other specified complications in pregnancy'
#  'Oculofacial plastics and orbital conditions'
#  'Genitourinary congenital anomalies'
#  'Postprocedural or postoperative nervous system complication'
#  'Other specified and unspecified disorders of stomach and duodenum'
#  'Malposition, disproportion or other labor complications'
#  'Acute and unspecified renal failure' 'Headache; including migraine'
#  'Cerebral palsy' 'Neoplasm-related encounters' 'Heart failure'
#  'Other specified female genital disorders'
#  'Polyhydramnios and other problems of amniotic cavity'
#  'Pulmonary heart disease' 'Aspiration pneumonitis' 'Cardiac dysrhythmias'
#  'Other specified and unspecified lower respiratory disease'
#  'Other and ill-defined cerebrovascular disease'
#  'Uncomplicated pregnancy, delivery or puerperium'
#  'Head and neck cancers - all other types'
#  'Female reproductive system cancers - uterus' 'Nutritional deficiencies'
#  'Spondylopathies/spondyloarthropathy (including infective)'
#  'Acute phlebitis; thrombophlebitis and thromboembolism'
#  'Alcohol-related disorders' 'Previous C-section' 'HIV infection'
#  'Early or threatened labor'
#  'Diabetes or abnormal glucose tolerance complicating pregnancy; childbirth; or the puerperium'
#  'Obesity' 'Stimulant-related disorders' 'Glaucoma' 'Multiple gestation'
#  'Secondary malignancies' 'Nonspecific chest pain' 'Personality disorders'
#  'Hypertension with complications and secondary hypertension'
#  'Transient cerebral ischemia'
#  'Complications specified during the puerperium' 'Other specified status'
#  'Hepatitis'
#  'Maternal care related to disorders of the placenta and placental implantation'
#  'Pericarditis and pericardial disease'
#  'Miscellaneous mental and behavioral disorders/conditions'
#  'Diverticulosis and diverticulitis' 'Cerebral infarction'
#  'Effect of other external causes, initial encounter'
#  'Peritonitis and intra-abdominal abscess'
#  'Nonmalignant breast conditions'
#  'Spinal cord injury (SCI), initial encounter'
#  'Ectopic pregnancy and complications of ectopic pregnancy'
#  'Amputation of a limb, initial encounter'
#  'Open wounds to limbs, subsequent encounter' 'Non-Hodgkin lymphoma'
#  'Acute hemorrhagic cerebrovascular disease' 'Sedative-related disorders'
#  'Endocarditis and endocardial disease'
#  'Complication of genitourinary device, implant or graft, initial encounter'
#  'Other specified and unspecified hematologic conditions'
#  'Spinal cord injury (SCI), subsequent encounter' 'Multiple sclerosis'
#  'Nervous system cancers - all other types'
#  'Postprocedural or postoperative respiratory system complication'
#  'Spontaneous abortion and complications of spontaneous abortion'
#  'Head and neck cancers - lip and oral cavity'
#  'Hallucinogen-related disorders'
#  'Leukemia - chronic myeloid leukemia (CML)'
#  'Fracture of head and neck, subsequent encounter' 'Malaise and fatigue'
#  'Thyroid disorders' 'Paralysis (other than cerebral palsy)'
#  'Maternal intrauterine infection'
#  'Chronic obstructive pulmonary disease and bronchiectasis'
#  'Maternal care for abnormality of pelvic organs'
#  'General sensation/perception signs and symptoms' 'Endometriosis'
#  'Hemorrhoids' 'Drug induced or toxic related condition'
#  'Neuro-ophthalmology' 'Gastrointestinal cancers - colorectal'
#  'Bacterial infections'
#  'Induced abortion and complications of termination of pregnancy'
#  'Menstrual disorders' 'Low back pain'
#  'Endocrine system cancers - thyroid'
#  'Sexually transmitted infections (excluding HIV and hepatitis)'
#  'Aortic; peripheral; and visceral artery aneurysms'
#  'Early, first or unspecified trimester hemorrhage'
#  'Pressure ulcer of skin'
#  'Fracture of the neck of the femur (hip), subsequent encounter'
#  'Erectile dysfunction' 'Hemorrhage after first trimester'
#  'Fracture of torso, subsequent encounter'
#  'Inflammatory conditions of male genital organs'
#  'Other specified and unspecified skin disorders' 'Osteoarthritis'
#  'Acute myocardial infarction' 'Other specified connective tissue disease'
#  'Gastrointestinal and biliary perforation' 'Acute posthemorrhagic anemia'
#  'Leukemia - acute myeloid leukemia (AML)'
#  'Coronary atherosclerosis and other heart disease'
#  'Uveitis and ocular inflammation'
#  'Obsessive-compulsive and related disorders' 'Gastroduodenal ulcer'
#  'Anxiety and fear-related disorders'
#  'Fracture of the spine and back, subsequent encounter'
#  'Somatic disorders'
#  'Postprocedural or postoperative circulatory system complication'
#  'Noninfectious hepatitis' 'Cardiac cancers'
#  'Fracture of lower limb (except hip), subsequent encounter'
#  'Rheumatoid arthritis and related disease'
#  'Molar pregnancy and other abnormal products of conception'
#  'Coma; stupor; and brain damage' 'Parkinson`s disease'
#  'Injury to nerves, muscles and tendons, initial encounter'
#  'Breast cancer - ductal carcinoma in situ (DCIS)' 'Myopathies'
#  'Diseases of inner ear and related conditions' 'Osteoporosis' 'Gout'
#  'Urinary system cancers - kidney'
#  'Female reproductive system cancers - cervix' 'Hematuria'
#  'Injury to blood vessels, initial encounter'
#  'Nervous system pain and pain syndromes'
#  'Encounter for prophylactic or other procedures'
#  'Breast cancer - all other types' 'Leukemia - all other types'
#  'Postprocedural or postoperative musculoskeletal system complication'
#  'Postprocedural or postoperative skin complication'
#  'Endocrine system cancers - thymus'
#  'Male reproductive system cancers - prostate' 'Essential hypertension'
#  'Shock' 'Non-pressure ulcer of skin' 'Arterial dissections'
#  'Respiratory cancers'
#  'Aortic and peripheral arterial embolism or thrombosis'
#  'Tendon and synovial disorders' 'Multiple myeloma'
#  'Cardiac arrest and ventricular fibrillation'
#  'Head and neck cancers - salivary gland'
#  'Sequela of cerebral infarction and other cerebrovascular disease'
#  'Skin cancers - melanoma'
#  'Female reproductive system cancers - endometrium'
#  'Blindness and vision defects' 'Gastrointestinal cancers - bile duct'
#  'Burns and corrosion, subsequent encounter'
#  'Disorders of lipid metabolism'
#  'Sequela of hemorrhagic cerebrovascular disease'
#  'Chronic rheumatic heart disease'
#  'Fracture of the upper limb, subsequent encounter'
#  'Gastrointestinal cancers - esophagus'
#  'Other specified and unspecified diseases of bladder and urethra'
#  'Gastrointestinal cancers - anus'
#  'Peripheral and visceral vascular disease'
#  'Gastrointestinal cancers - stomach' 'Immunity disorders'
#  'Malignant neuroendocrine tumors'
#  'Other specified and unspecified circulatory disease'
#  'Cornea and external disease' 'Traumatic arthropathy'
#  'Endocrine system cancers - pancreas'
#  'Stress fracture, initial encounter'
#  'Gastrointestinal cancers - all other types' 'Gangrene'
#  'Postthrombotic syndrome and venous insufficiency/hypertension'
#  'Urinary system cancers - bladder'
#  'Urinary system cancers - ureter and renal pelvis'
#  'Hyperplasia of prostate' 'Myelodysplastic syndrome (MDS)'
#  'Leukemia - chronic lymphocytic leukemia (CLL)'
#  'Neurocognitive disorders'
#  'Chronic phlebitis; thrombophlebitis and thromboembolism'
#  'Pathological fracture, subsequent encounter'
#  'Other and ill-defined heart disease'
#  'Occlusion or stenosis of precerebral or cerebral arteries without infarction'
#  'Menopausal disorders' 'Fungal infections'
#  'Malignant neoplasm, unspecified' 'Atypical fracture, initial encounter'
#  'Gastrointestinal cancers - small intestine'
#  'Head and neck cancers - laryngeal'
#  'Female reproductive system cancers - fallopian tube'
#  'Complication, sequela' 'Other specified eye disorders'
#  'Varicose veins of lower extremity' 'Head and neck cancers - tonsils'
#  'Other unspecified injury' 'Crystal arthropathies (excluding gout)'
#  'Mental and substance use disorders in remission'
#  'Prolapse of female genital organs' 'Head and neck cancers - throat'
#  'Medical examination/evaluation'
#  'Complication of cardiovascular device, implant or graft, subsequent encounter'
#  'Male reproductive system cancers - penis'
#  'Head and neck cancers - nasopharyngeal' 'Injury, sequela'
#  'Female reproductive system cancers - vagina'
#  'Gastrointestinal cancers - gallbladder'
#  'Skin cancers - squamous cell carcinoma'
#  'Female reproductive system cancers - vulva' 'Mediastinal disorders'
#  'Postprocedural or postoperative endocrine or metabolic complication'
#  'Lung disease due to external agents'
#  'Female reproductive system cancers - all other types'
#  'Skin cancers - basal cell carcinoma']
#
# CCSR Procedure Code:
# ['ADM015' 'ADM017' nan 'ADM010' 'MRS001' 'ESA004' 'ADM012' 'GIS026'
#  'CAR024' 'GIS017' 'MHT002' 'GIS001' 'PGN002' 'ESA003' 'EST002' 'MAM011'
#  'MST009' 'CNS014' 'RES008' 'ENT004' 'ESA001' 'MHT001' 'OTR004' 'EST003'
#  'RES007' 'GIS008' 'ADM021' 'MST018' 'MST012' 'MST014' 'ADM001' 'ENT007'
#  'CNS007' 'CAR021' 'ADM003' 'ENT011' 'MST011' 'RES005' 'FRS002' 'IMG008'
#  'ADM002' 'MRS007' 'CAR010' 'CAR013' 'ENT001' 'GNR002' 'CAR019' 'CAR025'
#  'GIS024' 'GIS011' 'MST013' 'GIS006' 'MHT005' 'MAM001' 'MST029' 'CNS002'
#  'GIS007' 'ADM016' 'MAM010' 'IMG005' 'GIS002' 'ENP004' 'ENP005' 'GIS009'
#  'MST010' 'CAR029' 'IMG009' 'MAM005' 'GIS027' 'IMG006' 'SKB008' 'LYM007'
#  'FRS003' 'MST005' 'EYP001' 'ENT014' 'ADM006' 'ADM019' 'ENT012' 'GIS025'
#  'SKB006' 'ADM011' 'EYP002' 'ADM014' 'CAR022' 'ENT013' 'PLC002' 'MST001'
#  'CAR012' 'RAD001' 'CNS008' 'HEP006' 'GIS021' 'RES001' 'MST030' 'CAR018'
#  'MST004' 'FRS011' 'RES010' 'HEP004' 'SUD001' 'GNR008' 'MST002' 'FRS007'
#  'IMG007' 'SKB007' 'GNR009' 'ESA002' 'MST007' 'GIS029' 'SKB002' 'MST006'
#  'URN003' 'ENT006' 'CAR011' 'CNS010' 'MST021' 'CNS001' 'ADM009' 'IMG004'
#  'LYM005' 'CNS005' 'GIS018' 'GIS003' 'GIS022' 'ENT017' 'ENT005' 'GIS004'
#  'ENT003' 'ADM018' 'FRS010' 'MAM008' 'CNS009' 'ADM005' 'GIS028' 'PGN001'
#  'URN001' 'CAR005' 'CNS004' 'URN008' 'CAR023' 'MST020' 'MST015' 'MST028'
#  'HEP001' 'GIS005' 'PNS005' 'RHB002' 'URN006' 'ENT015' 'MAM015' 'PGN003'
#  'SKB009' 'GNR003' 'ADM007' 'FRS015' 'MST017' 'LYM011' 'ENT002' 'HEP007'
#  'PLC001' 'CNS012' 'MST022' 'CAR008' 'SUD004' 'SKB005' 'URN005' 'GIS010'
#  'MST023' 'URN011' 'ADM008' 'PNS001' 'GIS019' 'PGN004' 'MRS005' 'LYM003'
#  'RES002' 'MST016' 'SKB001' 'PGN007' 'PGN006' 'MAM007' 'MST026' 'URN004'
#  'HEP010' 'FRS009' 'EST001' 'FRS012' 'GIS020' 'MST003' 'GNR005' 'URN002'
#  'PGN005' 'CAR017' 'CAR002' 'MHT003' 'SUD002' 'RES011' 'URN007' 'HEP003'
#  'RES006' 'FRS008' 'MRS002' 'ENP002' 'MAM009' 'GNR004' 'GIS013' 'PGN008'
#  'RES014' 'HEP008' 'FRS006' 'ESA006' 'MST008' 'CAR026' 'GNR007' 'MST019'
#  'IMG002' 'RES004' 'IMG003' 'FRS005' 'URN012' 'HEP013' 'CAR027' 'ADM013'
#  'SKB003' 'CAR014' 'PNS003' 'ADM022' 'ESA011' 'CAR003' 'LYM001' 'CNS011'
#  'FRS013' 'ESA005' 'GNR006' 'CNS006' 'FRS001' 'MAM006' 'RES012' 'SUD003'
#  'CAR028' 'PNS004' 'GIS015' 'CAR004' 'SKB010' 'MAM004' 'MST024' 'CAR001'
#  'RAD002' 'SKB004' 'LYM004' 'MRS003' 'IMG001' 'ESA009' 'CNS003' 'LYM008'
#  'CAR007' 'PGN009' 'OTR001' 'HEP009' 'CAR016' 'RHB001' 'RES003' 'ENP003'
#  'LYM002' 'HEP011' 'ADM020' 'CAR020' 'GNR001' 'RES013' 'CAR015' 'ENT008'
#  'HEP005' 'URN009' 'CAR009' 'GIS016' 'ENT010' 'NCM001' 'CAR006' 'MRS004'
#  'ESA007' 'URN010' 'MST025' 'NCM004' 'RHB003' 'RHB004' 'MAM014' 'HEP002'
#  'ESA010' 'GIS012' 'ADM004' 'LYM006' 'ENT009']
#
# CCSR Procedure Description:
# ['ADMINISTRATION OF ANTIBIOTICS'
#  'ADMINISTRATION OF NUTRITIONAL AND ELECTROLYTIC SUBSTANCES' nan
#  'VACCINATIONS' 'CIRCUMCISION' 'NON-INVASIVE VENTILATION' 'CHEMOTHERAPY'
#  'UPPER GI THERAPEUTIC PROCEDURES, NEC (OPEN AND LAPAROSCOPIC)'
#  'VENOUS AND ARTERIAL CATHETER PLACEMENT' 'GASTROSTOMY'
#  'PSYCHOTHERAPY FOR MENTAL HEALTH (EXCLUDING SUBSTANCE USE)'
#  'ESOPHAGOGASTRODUODENOSCOPY (EGD) WITH BIOPSY'
#  'SPONTANEOUS VAGINAL DELIVERY' 'MECHANICAL VENTILATION' 'PHOTOTHERAPY'
#  'ELECTROENCEPHALOGRAM (EEG)' 'FIXATION OF UPPER EXTREMITY BONES'
#  'CNS PROCEDURES, NEC'
#  'LUNG, PLEURA, OR DIAPHRAGM RESECTION (OPEN AND THORACOSCOPIC)'
#  'DIAGNOSTIC AUDIOLOGY' 'HEMODIALYSIS'
#  'PHARMACOTHERAPY FOR MENTAL HEALTH (EXCLUDING SUBSTANCE USE)'
#  'ISOLATION PROCEDURES' 'ULTRAVIOLET LIGHT THERAPY' 'AIRWAY INTUBATION'
#  'APPENDECTOMY' 'ADMINISTRATION OF THERAPEUTIC SUBSTANCES, NEC'
#  'BONE EXCISION' 'BONE FIXATION (EXCLUDING EXTREMITIES)'
#  'JOINT FUSION (EXCLUDING SPINE)'
#  'TRANSFUSION OF BLOOD AND BLOOD PRODUCTS'
#  'TONSILECTOMY AND ADENOIDECTOMY' 'CNS EXCISION PROCEDURES'
#  'ARTERY, VEIN, AND GREAT VESSEL PROCEDURES, NEC'
#  'ADMINISTRATION OF ALBUMIN AND GLOBULIN' 'LARYNGECTOMY'
#  'FIXATION OF LEG AND FOOT BONES'
#  'CHEST TUBE PLACEMENT AND THERAPEUTIC THORACENTESIS' 'OOPHORECTOMY'
#  'ULTRASONOGRAPHY' 'TRANSFUSION OF PLASMA'
#  'MALE REPRODUCTIVE SYSTEM PROCEDURES, NEC'
#  'LIGATION AND EMBOLIZATION OF VESSELS'
#  'HEART AND GREAT VESSEL BYPASS PROCEDURES' 'LARYNGOSCOPY (DIAGNOSTIC)'
#  'ABDOMINAL WALL REPAIR (INCLUDING HERNIA)'
#  'SEPTAL REPAIR AND OTHER THERAPEUTIC HEART PROCEDURES'
#  'PLACEMENT OF TUNNELED OR IMPLANTABLE PORTION OF A VASCULAR ACCESS DEVICE'
#  'OTHER PERITONEAL CAVITY PROCEDURES' 'SMALL BOWEL RESECTION'
#  'SPINE FUSION' 'PARACENTESIS' 'MENTAL HEALTH PROCEDURES, NEC'
#  'ARTERIAL OXYGEN SATURATION MONITORING'
#  'MUSCULOSKELETAL DEVICE PROCEDURES, NEC' 'LUMBAR PUNCTURE'
#  'GI SYSTEM DRAINAGE (EXCLUDING PARACENTESIS)'
#  'ADMINISTRATION OF ANTI-INFLAMMATORY AGENTS'
#  'OTHER CARDIOVASCULAR SYSTEM MEASUREMENT AND MONITORING'
#  'MAGNETIC RESONANCE IMAGING (MRI)'
#  'COLONOSCOPY AND PROCTOSCOPY WITH BIOPSY' 'ADRENALECTOMY'
#  'PITUITARY GLAND RESECTION' 'COLECTOMY' 'FEMUR FIXATION'
#  'CARDIOVASCULAR DEVICE PROCEDURES, NEC' 'PLAIN RADIOGRAPHY'
#  'MEASUREMENT DURING CARDIAC CATHETERIZATION'
#  'UPPER GI THERAPEUTIC PROCEDURES, NEC (ENDOSCOPIC)'
#  'COMPUTERIZED TOMOGRAPHY (CT) WITH CONTRAST'
#  'SKIN EXCISION AND DEBRIDEMENT' 'BONE MARROW BIOPSY' 'SALPINGECTOMY'
#  'INCISION AND DRAINAGE OF SUBCUTANEOUS TISSUE AND FASCIA'
#  'EYE PROCEDURES' 'FRENECTOMY' 'INFUSION OF VASOPRESSOR'
#  'POTENTIAL COVID-19 THERAPIES'
#  'ENT EXCISION (EXCLUDING NASAL PASSAGE, SINUSES, TONGUE, SALIVARY GLANDS, LARYNX)'
#  'OTHER GI SYSTEM DEVICE PROCEDURES'
#  'SKIN LACERATION REPAIR (EXCLUDING PERINEUM)'
#  'ADMINISTRATION AND TRANSFUSION OF BONE MARROW, STEM CELLS, PANCREATIC ISLET CELLS, AND T-CELLS'
#  'EYELID PROCEDURES' 'REGIONAL ANESTHESIA'
#  'HEART VALVE REPLACEMENT AND OTHER VALVE PROCEDURES (NON-ENDOVASCULAR)'
#  'ENT REPAIR' 'PACKING AND DRESSING PROCEDURES' 'ARTHROCENTESIS'
#  'VESSEL REPAIR AND REPLACEMENT' 'BEAM RADIATION'
#  'SPINAL CORD DECOMPRESSION' 'CHOLECYSTECTOMY'
#  'GI SYSTEM REPAIR (EXCLUDING ANORECTAL)' 'BRONCHOSCOPY (DIAGNOSTIC)'
#  'MUSCULOSKELETAL PROCEDURES, NEC' 'HEART TRANSPLANT'
#  'INCISION AND DRAINAGE OF MUSCULOSKELETAL TISSUE AND JOINTS'
#  'FEMALE LOWER GENITAL TRACT EXCISION' 'TRACHEOSTOMY'
#  'HEPATOBILIARY RESECTION AND ABLATION' 'SUBSTANCE USE DETOXIFICATION'
#  'ABDOMINAL WALL PROCEDURES, NEC' 'BONE AND JOINT BIOPSY'
#  'FEMALE GENITAL TRACT REPAIR (EXCLUDING VULVA)'
#  'COMPUTERIZED TOMOGRAPHY (CT) WITHOUT CONTRAST' 'SKIN GRAFT'
#  'RETROPERITONEAL PROCEDURES, NEC' 'EXTRACORPOREAL MEMBRANE OXYGENATION'
#  'HIP ARTHROPLASTY'
#  'LOWER GI THERAPEUTIC PROCEDURES, NEC (EXCLUDING OPEN AND LAPAROSCOPIC)'
#  'INCISION AND DRAINAGE OF SKIN' 'KNEE ARTHROPLASTY'
#  'URETER AND OTHER URINARY TRACT DILATION'
#  'ENT DRAINAGE (EXCLUDING MYRINGOTOMY)' 'ANEURYSM REPAIR PROCEDURES'
#  'CEREBROSPINAL FLUID SHUNT PROCEDURES'
#  'PERINEAL MUSCLE LACERATION REPAIR (2ND DEGREE OBSTETRICAL AND OTHER)'
#  'MINIMALLY INVASIVE CNS BIOPSY'
#  'RH IMMUNOGLOBULIN AND OTHER SERUM INFUSION'
#  'FLUOROSCOPY OF NON-CIRCULATORY ORGANS' 'SPLENECTOMY'
#  'VENTRICULOSTOMY [PERCUTANEOUS APPROACH]' 'ILEOSTOMY AND COLOSTOMY'
#  'GI SYSTEM BIOPSY (NON-ENDOSCOPIC)' 'GI SYSTEM LYSIS OF ADHESIONS'
#  'ENT PROCEDURES, NEC' 'MYRINGOTOMY'
#  'GI SYSTEM ENDOSCOPY WITHOUT BIOPSY (DIAGNOSTIC)'
#  'ENT DIAGNOSTIC PROCEDURES (NON-ENDOSCOPIC)'
#  'IRRIGATION (DIAGNOSTIC AND THERAPEUTIC)'
#  'FEMALE UPPER GENITAL TRACT EXCISION' 'CARDIAC MONITORING'
#  'DECOMPRESSIVE CRANIECTOMY'
#  'ADMINISTRATION OF THROMBOLYTICS AND PLATELET INHIBITORS'
#  'LOWER GI THERAPEUTIC PROCEDURES, NEC (OPEN AND LAPAROSCOPIC)'
#  'FETAL HEART RATE MONITORING'
#  'CYSTOSCOPY AND URETEROSCOPY (INCLUDING BIOPSY)'
#  'OTHER CORONARY ARTERY PROCEDURES (EXCLUDING CABG AND PCI)'
#  'INTRACRANIAL EPIDURAL AND SUBDURAL SPACE DRAINAGE'
#  'NEPHRECTOMY AND URETERECTOMY'
#  'HEART VALVE REPLACEMENT AND OTHER VALVE PROCEDURES (ENDOVASCULAR)'
#  'SUBCUTANEOUS TISSUE AND FASCIA EXCISION'
#  'CLOSED REDUCTION OF BONES AND JOINTS'
#  'SUBCUTANEOUS TISSUE AND FASCIA PROCEDURES, NEC' 'LIVER BIOPSY'
#  'EXPLORATION OF PERITONEAL CAVITY' 'PERIPHERAL NERVE DENERVATION'
#  'PHYSICAL, OCCUPATIONAL, AND RESPIRATORY THERAPY TREATMENT'
#  'BLADDER CATHETERIZATION AND DRAINAGE' 'DENTAL PROCEDURES'
#  'MEASUREMENT AND MONITORING, NEC' 'CESAREAN SECTION' 'NAIL PROCEDURES'
#  'INGUINAL AND FEMORAL HERNIA REPAIR' 'INTRAVENOUS INDUCTION OF LABOR'
#  'FEMALE REPRODUCTIVE SYSTEM PROCEDURES, NEC'
#  'JOINT TISSUE EXCISION (EXCLUDING DISCECTOMY)'
#  'LYMPHATIC PROCEDURES, NEC'
#  'ENT DIAGNOSTIC ENDOSCOPY (EXCLUDING LARYNGOSCOPY)'
#  'BILIARY AND PANCREATIC CALCULUS REMOVAL'
#  'IMMOBILIZATION BY SPLINT OR OTHER EXTERNAL DEVICE'
#  'CNS NEUROSTIMULATOR PROCEDURES'
#  'TENDON, MUSCLE, BURSA, AND LIGAMENT REPAIR (EXCLUDING PERINEAL)'
#  'ANGIOPLASTY AND RELATED VESSEL PROCEDURES (ENDOVASCULAR; EXCLUDING CAROTID)'
#  'COUNSELING FOR SUBSTANCE USE'
#  'PERINEAL SKIN REPAIR (1ST DEGREE OBSTETRICAL AND OTHER)'
#  'NEPHROSTOMY AND URETEROSTOMY PROCEDURES (INCLUDING STENTS)'
#  'GASTRECTOMY' 'TOE AND MID FOOT AMPUTATION' 'KIDNEY TRANSPLANT'
#  'CERVICAL RIPENING' 'LUMBOSACRAL NERVE DECOMPRESSION'
#  'GASTRO-JEJUNAL BYPASS (INCLUDING BARIATRIC)' 'ASSISTED VAGINAL DELIVERY'
#  'MALE PERINEUM PROCEDURES' 'LYMPH NODE DISSECTION'
#  'LUNG, PLEURA, OR DIAPHRAGM BIOPSY (NON-ENDOSCOPIC)'
#  'VERTEBRAL DISCECTOMY' 'SKIN BIOPSY AND DIAGNOSTIC DRAINAGE'
#  'REMOVAL OF ECTOPIC PREGNANCY'
#  'REMOVAL OF PLACENTA AND OTHER RETAINED PRODUCTS OF CONCEPTION'
#  'ELECTROCARDIOGRAM (ECG)' 'FINGER AND OTHER UPPER EXTREMITY AMPUTATION'
#  'REMOVAL OF CALCULI AND OTHER MATTER FROM URINARY TRACT'
#  'HEPATOBILIARY AND PANCREATIC DRAINAGE' 'CERVICAL CERCLAGE'
#  'PHERESIS THERAPY' 'INTRAUTERINE DEVICE (IUD) INSERTION'
#  'ANORECTAL REPAIR (3RD AND 4TH DEGREE OBSTETRICAL REPAIRS AND OTHER)'
#  'SUBCUTANEOUS TISSUE, FASCIA, AND MUSCLE BIOPSY'
#  'CONTROL OF BLEEDING (NON-ENDOSCOPIC)'
#  'KIDNEY AND OTHER URINARY TRACT BIOPSY (NON-ENDOSCOPIC)' 'EPISIOTOMY'
#  'PERICARDIAL PROCEDURES' 'HEART CONDUCTION MECHANISM PROCEDURES'
#  'ELECTROCONVULSIVE THERAPY' 'PHARMACOTHERAPY FOR SUBSTANCE USE'
#  'DIAPHRAGMATIC HERNIA REPAIR' 'URINARY TRACT REPAIR'
#  'DIAGNOSTIC ERCP WITH OR WITHOUT BIOPSY'
#  'OPEN AND THORACOSCOPIC PLEURAL DRAINAGE' 'CERVICAL DILATION'
#  'PENIS PROCEDURES (EXCLUDING CIRCUMCISION)' 'THYROIDECTOMY'
#  'ELECTROPHYSIOLOGIC STUDIES' 'ENDOSCOPIC CONTROL OF BLEEDING'
#  'PROCTECTOMY OR ANAL RESECTION' 'ABORTION'
#  'RESPIRATORY SYSTEM PROCEDURES, NEC'
#  'COMMON BILE DUCT SPHINCTEROTOMY AND STENTING' 'VULVAR LACERATION REPAIR'
#  'CARDIOVERSION' 'ARTHROPLASTY OF OTHER JOINT (EXCLUDING KNEE AND HIP)'
#  'PACEMAKER AND DEFIBRILLATOR PROCEDURES' 'MEDIASTINAL PROCEDURES, NEC'
#  'MUSCLE, TENDON, BURSA, AND LIGAMENT EXCISION'
#  'FLUOROSCOPIC ANGIOGRAPHY (EXCLUDING CORONARY)'
#  'BRONCHOSCOPY (THERAPEUTIC)'
#  'FLUOROSCOPIC GUIDANCE FOR CIRCULATORY SYSTEM PROCEDURES'
#  'FALLOPIAN TUBE LIGATION AND EXCISION' 'URINARY SYSTEM PROCEDURES, NEC'
#  'HEPATOBILIARY AND PANCREATIC PROCEDURES, NEC'
#  'HEART ASSIST DEVICE PROCEDURES' 'PERITONEAL DIALYSIS'
#  'MASTECTOMY AND LUMPECTOMY' 'PERIPHERAL ARTERIAL BYPASS PROCEDURES'
#  'PERIPHERAL NERVE DECOMPRESSION (EXCLUDING LUMBOSACRAL AND CERVICOTHORACIC)'
#  'COVID-19 VACCINATIONS' 'HYPERBARIC OXYGEN THERAPY'
#  'CORONARY ARTERY BYPASS GRAFTS (CABG)' 'LYMPH NODE BIOPSY'
#  'MENINGES REPAIR' 'SUBCUTANEOUS CONTRACEPTIVE IMPLANT'
#  'CARDIAC CHEST COMPRESSION' 'CHEST WALL PROCEDURES, NEC'
#  'OTHER CNS DRAINAGE AND RELATED PROCEDURES' 'HYSTERECTOMY'
#  'PACEMAKER AND DEFIBRILLATOR INTERROGATION' 'RELEASE OF LUNG AND PLEURA'
#  'PSYCHOTHERAPY FOR SUBSTANCE USE'
#  'INFERIOR VENA CAVA (IVC) FILTER PROCEDURES' 'NERVE REPAIR'
#  'OMENTECTOMY OR PERITONEUM RESECTION'
#  'PERCUTANEOUS CORONARY INTERVENTIONS (PCI)'
#  'SKIN AND BREAST PROCEDURES, NEC' 'CARDIAC STRESS TESTS'
#  'BELOW KNEE AMPUTATION' 'HEART BIOPSY' 'BRACHYTHERAPY'
#  'BREAST RECONSTRUCTION' 'THYMECTOMY' 'PROSTATECTOMY'
#  'CARDIAC AND CORONARY FLUOROSCOPY' 'CARDIAC ASSISTANCE WITH BALLOON PUMP'
#  'SPINAL CANAL AND SPINAL CORD DRAINAGE (EXCLUDING LUMBAR PUNCTURE)'
#  'BONE MARROW ASPIRATION (THERAPEUTIC)'
#  'EMBOLECTOMY, ENDARTERECTOMY, AND RELATED VESSEL PROCEDURES (NON-ENDOVASCULAR; EXCLUDING CAROTID)'
#  'PREGNANCY AND FETAL PROCEDURES, NEC' 'ROBOTIC-ASSISTED PROCEDURES'
#  'PANCREATIC AND PROXIMAL BILIARY DILATION AND STENTING'
#  'PORTAL AND OTHER VENOUS BYPASS PROCEDURES'
#  'PHYSICAL, OCCUPATIONAL, AND RESPIRATORY THERAPY EVALUATION'
#  'THORACENTESIS (DIAGNOSTIC)' 'PARATHYROIDECTOMY'
#  'LYMPH NODE EXCISION (THERAPEUTIC)' 'LIVER TRANSPLANT'
#  'ADMINISTRATION OF DIAGNOSTIC SUBSTANCES, NEC'
#  'SAPHENOUS VEIN HARVEST AND OTHER THERAPEUTIC VESSEL REMOVAL'
#  'COSMETIC PROCEDURES' 'LUNG TRANSPLANT'
#  'PERIPHERAL ARTERIOVENOUS FISTULA AND SHUNT PROCEDURES'
#  'NASAL AND SINUS EXCISION' 'PANCREATECTOMY'
#  'CYSTECTOMY (INCLUDING FULGURATION) AND URETHRECTOMY'
#  'LEFT ATRIAL APPENDAGE PROCEDURES'
#  'GI SYSTEM ENDOSCOPIC THERAPEUTIC PROCEDURES' 'SALIVARY GLAND EXCISION'
#  'PLANAR NUCLEAR MEDICINE IMAGING' 'CAROTID ENDARTERECTOMY AND STENTING'
#  'PROSTATE AND SEMINAL VESICLE PROCEDURES (EXCLUDING PROSTATECTOMY)'
#  'CARDIAC PACING' 'URINARY DIVERSION WITH ANASTOMOSIS OR OSTOMY'
#  'ABOVE KNEE AND OTHER PROXIMAL LOWER EXTREMITY AMPUTATION'
#  'POSITRON EMISSION TOMOGRAPHIC (PET) IMAGING' 'SPEECH THERAPY EVALUATION'
#  'SPEECH THERAPY TREATMENT' 'PULMONARY FUNCTION TESTS'
#  'PANCREATICOBILIARY BIOPSY'
#  'CARDIAC ASSISTANCE WITH VENTRICULAR ASSIST DEVICE' 'DUODENAL RESECTION'
#  'TRANSFUSION OF CLOTTING FACTORS'
#  'SPLEEN PROCEDURES (EXCLUDING SPLENECTOMY)' 'TONGUE EXCISION']
#
# APR DRG Code:
# [626 138 640 383 695 639 222 754 593 607 249 621 137 750 755 422 612 560
#  720  53 315 351  21 625 121 470 420 753 542 663 344 633 233 141 320 756
#  234  89 139 130 309 133 810  97 861 246 466 816 346 602 634 115 757 723
#  313 143 513 691 614 483 591 160 662 227 343 724 314 114 175 721 463 711
#  518 588 722 751 254 636 581 303 696 817 243  55 844 113 661 631 660 812
#  608 622 229 231 167 815  58 192 248 421 690 511 204 207 364  82 811 930
#  251 404  57 252 384   7  98  49 758 532  41 247  27 609 423 163  95  43
#   51 230 630  23 426 760 263 566 468 613  22 224 201   8   2 144 279 342
#   73 794 710 424 241 405 950   5 623 220 773 862 228 260  30 284 842 308
#    9 253 324 680  92 145 813 325 465  48  50 132 759 385  26 245 283 223
#   52 650 776 863 282  29 261  42 462 120  44 956 134  20 911 531 443 952
#  469  54 589 611 194 540 142 381 110 530 651 340 316 347 182  56 772 539
#  321 894 403 770 440 519 203 310 752 199  47 561 280 317 740 244  45 912
#  681 226 197  40 547 892 774 445 304 951 162 860 775 135 341 312 446 564
#  425 910 264 850 427 543 501 548 111   4 240 136 890 242 955 179 131 281
#  193 541 161 326 180 362 232 361 190 447 200 166 363 206 793 169 323  59
#  380 198 442 174 305 205 181 140 480 444 401 165  46 893 510 512 484 441
#  191 694 196 349   1 382 792 843 183 482 171 177 322  91  24 178 461 176
#  692 500 170 517]
#
# APR DRG Description:
# ['NEONATE BIRTH WEIGHT 2000-2499 GRAMS, NORMAL NEWBORN OR NEONATE WITH OTHER PROBLEM'
#  'BRONCHIOLITIS AND RSV PNEUMONIA'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS, NORMAL NEWBORN OR NEONATE WITH OTHER PROBLEM'
#  'CELLULITIS AND OTHER SKIN INFECTIONS' 'CHEMOTHERAPY FOR ACUTE LEUKEMIA'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH OTHER SIGNIFICANT CONDITION'
#  'OTHER STOMACH, ESOPHAGEAL AND DUODENAL PROCEDURES'
#  'DEPRESSION EXCEPT MAJOR DEPRESSIVE DISORDER'
#  'NEONATE BIRTH WEIGHT 750-999 GRAMS WITHOUT MAJOR PROCEDURE'
#  'NEONATE BIRTH WEIGHT 1250-1499 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CONDITION OR MAJOR ANOMALY'
#  'OTHER GASTROENTERITIS, NAUSEA AND VOMITING'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH MAJOR ANOMALY'
#  'MAJOR RESPIRATORY INFECTIONS AND INFLAMMATIONS' 'SCHIZOPHRENIA'
#  'ADJUSTMENT DISORDERS AND NEUROSES EXCEPT DEPRESSIVE DIAGNOSES'
#  'HYPOVOLEMIA AND RELATED ELECTROLYTE DISORDERS'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CONDITION'
#  'VAGINAL DELIVERY' 'SEPTICEMIA AND DISSEMINATED INFECTIONS' 'SEIZURE'
# ...
#  'PENIS, TESTES AND SCROTAL PROCEDURES'
#  'NEONATE BIRTH WEIGHT 500-749 GRAMS WITHOUT MAJOR PROCEDURE'
#  'MAJOR CARDIOTHORACIC REPAIR OF HEART ANOMALY'
#  'SICKLE CELL ANEMIA CRISIS'
#  'HERNIA PROCEDURES EXCEPT INGUINAL, FEMORAL AND UMBILICAL'
#  'MUSCULOSKELETAL MALIGNANCY AND PATHOLOGICAL FRACTURE DUE TO MUSCULOSKELETAL MALIGNANCY'
#  'OTHER INFECTIOUS AND PARASITIC DISEASES' 'FOOT AND TOE PROCEDURES'
#  'DENTAL DISEASES AND DISORDERS'
#  'PERCUTANEOUS CARDIAC INTERVENTION WITHOUT AMI'
#  'POST-OPERATIVE, POST-TRAUMATIC, OTHER DEVICE INFECTIONS'
#  'KIDNEY AND URINARY TRACT INFECTIONS'
#  'POST-OPERATIVE, POST-TRAUMA, OTHER DEVICE INFECTIONS WITH O.R. PROCEDURE'
#  'OTHER FEMALE REPRODUCTIVE SYSTEM AND RELATED PROCEDURES'
#  'NEONATE BIRTH WEIGHT < 1500 GRAMS WITH MAJOR PROCEDURE'
#  'FEVER AND INFLAMMATORY CONDITIONS'
#  'MAJOR DEPRESSIVE DISORDERS AND OTHER OR UNSPECIFIED PSYCHOSES'
#  'OTHER DIGESTIVE SYSTEM DIAGNOSES'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH CONGENITAL OR PERINATAL INFECTION'
#  'NEONATE, TRANSFERRED < 5 DAYS OLD, BORN HERE'
#  'DORSAL AND LUMBAR FUSION PROCEDURE FOR CURVATURE OF BACK'
#  'OTHER CHEMOTHERAPY' 'INTENTIONAL SELF-HARM AND ATTEMPTED SUICIDE'
#  'OTHER ESOPHAGEAL DISORDERS'
#  'HEAD TRAUMA WITH COMA > 1 HOUR OR HEMORRHAGE'
#  'PARTIAL THICKNESS BURNS WITHOUT SKIN GRAFT'
#  'INFECTIONS OF UPPER RESPIRATORY TRACT'
#  'COAGULATION AND PLATELET DISORDERS'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH OTHER MAJOR PROCEDURE'
#  'MAJOR HEMATOLOGIC OR IMMUNOLOGIC DIAGNOSES EXCEPT SICKLE CELL CRISIS AND COAGULATION'
#  'POISONING OF MEDICINAL AGENTS'
#  'NEONATE BIRTH WEIGHT 1250-1499 GRAMS WITH OR WITHOUT SIGNIFICANT CONDITION'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CONDITION'
#  'OTHER DIGESTIVE SYSTEM AND ABDOMINAL PROCEDURES'
#  'MAJOR LARGE BOWEL PROCEDURES'
#  'OTHER CARDIOTHORACIC AND THORACIC VASCULAR PROCEDURES'
#  'OTHER INJURY, POISONING AND TOXIC EFFECT DIAGNOSES'
#  'OTHER DISORDERS OF NERVOUS SYSTEM'
#  'CARDIAC CATHETERIZATION FOR OTHER NON-CORONARY CONDITIONS'
#  'MAJOR GASTROINTESTINAL AND PERITONEAL INFECTIONS'
#  'MALNUTRITION, FAILURE TO THRIVE AND OTHER NUTRITIONAL DISORDERS'
#  'ACUTE LEUKEMIA'
#  'UTERINE AND ADNEXA PROCEDURES FOR OVARIAN AND ADNEXAL MALIGNANCY'
#  'SYNCOPE AND COLLAPSE' 'OTHER CIRCULATORY SYSTEM DIAGNOSES'
#  'OTHER SKIN, SUBCUTANEOUS TISSUE AND RELATED PROCEDURES'
#  'EYE INFECTIONS AND OTHER EYE DISORDERS' 'ALLERGIC REACTIONS'
#  'MULTIPLE SIGNIFICANT TRAUMA WITHOUT O.R. PROCEDURE' 'ABDOMINAL PAIN'
#  'THYROID, PARATHYROID AND THYROGLOSSAL PROCEDURES'
#  'CONCUSSION, CLOSED SKULL FRACTURE NOS, AND UNCOMPLICATED INTRACRANIAL INJURY, COMA < 1 HOUR OR NO COMA'
#  'MALFUNCTION, REACTION AND COMPLICATION OF GASTROINTESTINAL DEVICE OR PROCEDURE'
#  'CONTUSION, OPEN WOUND AND OTHER TRAUMA TO SKIN AND SUBCUTANEOUS TISSUE'
#  'ALLOGENEIC BONE MARROW TRANSPLANT'
#  'OTHER EAR, NOSE, MOUTH AND THROAT PROCEDURES'
#  'BACTERIAL AND TUBERCULOUS INFECTIONS OF NERVOUS SYSTEM'
#  'BEHAVIORAL DISORDERS'
#  'MENSTRUAL AND OTHER FEMALE REPRODUCTIVE SYSTEM DISORDERS'
#  'NERVOUS SYSTEM MALIGNANCY' 'INTESTINAL OBSTRUCTION'
#  'OTHER OPEN CRANIOTOMY'
#  'NEONATE BIRTH WEIGHT 1500-2499 GRAMS WITH MAJOR PROCEDURE'
#  'INBORN ERRORS OF METABOLISM'
#  'CARDIAC VALVE PROCEDURES WITHOUT AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'CLEFT LIP AND PALATE REPAIR'
#  'MULTIPLE SCLEROSIS, OTHER DEMYELINATING DISEASE AND INFLAMMATORY NEUROPATHIES'
#  'VIRAL MENINGITIS' 'MAJOR SMALL BOWEL PROCEDURES'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH MAJOR CARDIOVASCULAR PROCEDURE'
#  'SPINAL PROCEDURES' 'NON-HYPOVOLEMIC SODIUM DISORDERS'
#  'OTHER MENTAL HEALTH DISORDERS' 'CHOLECYSTECTOMY'
#  'ANTEPARTUM WITHOUT O.R. PROCEDURE'
#  'OTHER KIDNEY AND URINARY TRACT DIAGNOSES, SIGNS AND SYMPTOMS'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH CONGENITAL OR PERINATAL INFECTION'
#  'VENTRICULAR SHUNT PROCEDURES' 'PERITONEAL ADHESIOLYSIS'
#  'CARDIAC ARRHYTHMIA AND CONDUCTION DISORDERS'
#  'AUTOLOGOUS BONE MARROW TRANSPLANT OR T-CELL IMMUNOTHERAPY'
#  'HEART AND/OR LUNG TRANSPLANT'
#  'RESPIRATORY SIGNS, SYMPTOMS AND MISCELLANEOUS DIAGNOSES'
#  'HEPATIC COMA AND OTHER MAJOR ACUTE LIVER DISORDERS'
#  'FRACTURES AND DISLOCATIONS EXCEPT FEMUR, PELVIS AND BACK'
#  'ORBIT AND EYE PROCEDURES'
#  'NON-EXTENSIVE O.R. PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT'
#  'INFECTIOUS AND PARASITIC DISEASES INCLUDING HIV WITH O.R. PROCEDURE'
#  'OTHER ENDOCRINE DISORDERS' 'PEPTIC ULCER AND GASTRITIS'
#  'OTHER PROCEDURES FOR ENDOCRINE, NUTRITIONAL AND METABOLIC DISORDERS'
#  'EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS'
#  'TRACHEOSTOMY WITH MV >96 HOURS WITHOUT EXTENSIVE PROCEDURE'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH CONGENITAL OR PERINATAL INFECTION'
#  'MAJOR STOMACH, ESOPHAGEAL AND DUODENAL PROCEDURES'
#  'OPIOID ABUSE AND DEPENDENCE' 'OTHER AFTERCARE AND CONVALESCENCE'
#  'INGUINAL, FEMORAL AND UMBILICAL HERNIA PROCEDURES'
#  'MAJOR PANCREAS, LIVER AND SHUNT PROCEDURES'
#  'PERCUTANEOUS INTRACRANIAL AND EXTRACRANIAL VASCULAR PROCEDURES'
#  'DISORDERS OF GALLBLADDER AND BILIARY TRACT'
#  'BURNS WITH SKIN GRAFT EXCEPT EXTENSIVE THIRD DEGREE BURNS'
#  'HIP AND FEMUR FRACTURE REPAIR'
#  'EXTRACORPOREAL MEMBRANE OXYGENATION (ECMO)'
#  'OTHER AND UNSPECIFIED GASTROINTESTINAL HEMORRHAGE'
#  'ELECTIVE HIP JOINT REPLACEMENT'
#  'MAJOR O.R. PROCEDURES FOR LYMPHATIC, HEMATOPOIETIC OR OTHER NEOPLASMS'
#  'FACIAL BONE PROCEDURES EXCEPT MAJOR CRANIAL OR FACIAL BONE PROCEDURES'
#  'ACUTE BRONCHITIS AND RELATED SYMPTOMS'
#  'OTHER COMPLICATIONS OF TREATMENT'
#  'NON-ELECTIVE OR COMPLEX KNEE JOINT REPLACEMENT'
#  'URINARY STONES AND ACQUIRED UPPER URINARY TRACT OBSTRUCTION'
#  'PERIPHERAL, CRANIAL AND AUTONOMIC NERVE DISORDERS'
#  'NON-BACTERIAL INFECTIONS OF NERVOUS SYSTEM EXCEPT VIRAL MENINGITIS'
#  'BPD AND OTHER CHRONIC RESPIRATORY DISEASES ARISING IN PERINATAL PERIOD'
#  'EATING DISORDERS' 'OTHER SKIN, SUBCUTANEOUS TISSUE AND BREAST DISORDERS'
#  'OTHER NERVOUS SYSTEM AND RELATED PROCEDURES'
#  'INFLAMMATORY BOWEL DISEASE' 'OTHER DISORDERS OF THE LIVER'
#  'OTHER SMALL AND LARGE BOWEL PROCEDURES' 'ALTERATION IN CONSCIOUSNESS'
#  'SPLENECTOMY' 'OTHER DRUG ABUSE AND DEPENDENCE' 'NEONATAL AFTERCARE'
#  'DISORDERS OF PANCREAS EXCEPT MALIGNANCY'
#  'OTHER PERCUTANEOUS INTRACRANIAL PROCEDURES'
#  'MAJOR BILIARY TRACT PROCEDURES'
#  'DEGENERATIVE NERVOUS SYSTEM DISORDERS EXCEPT MULTIPLE SCLEROSIS'
#  'NEPHRITIS AND NEPHROSIS' 'MAJOR RESPIRATORY AND CHEST PROCEDURES'
#  'INTRACRANIAL HEMORRHAGE' 'UNGROUPABLE' 'PULMONARY EMBOLISM'
#  'OPEN CRANIOTOMY FOR TRAUMA'
#  'EXTENSIVE ABDOMINAL OR THORACIC PROCEDURES FOR MULTIPLE SIGNIFICANT TRAUMA'
#  'FEMALE REPRODUCTIVE SYSTEM INFECTIONS'
#  'KIDNEY AND URINARY TRACT PROCEDURES FOR NON-MALIGNANCY'
#  'NON-EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS'
#  'ACUTE KIDNEY INJURY' 'MIGRAINE AND OTHER HEADACHES'
#  'NEONATE BIRTH WEIGHT < 500 GRAMS, OR BIRTH WEIGHT 500-999 GRAMS AND GESTATIONAL AGE <24 WEEKS, OR BIRTH WEIGHT 500-749 GRAMS WITH MAJOR ANOMALY OR WITHOUT LIFE SUSTAINING INTERVENTION'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH MAJOR ANOMALY' 'HEART FAILURE'
#  'CESAREAN SECTION WITHOUT STERILIZATION'
#  'INTERSTITIAL AND ALVEOLAR LUNG DISEASES' 'MAJOR SKIN DISORDERS'
#  'EAR, NOSE, MOUTH, THROAT AND CRANIAL OR FACIAL MALIGNANCIES'
#  'FEMALE REPRODUCTIVE SYSTEM MALIGNANCY'
#  'OTHER PROCEDURES OF BLOOD AND BLOOD-FORMING ORGANS' 'FRACTURE OF FEMUR'
#  'HAND AND WRIST PROCEDURES'
#  'OTHER BACK AND NECK DISORDERS, FRACTURES AND INJURIES'
#  'OTHER PERIPHERAL VASCULAR AND RELATED PROCEDURES'
#  'BRAIN CONTUSION OR LACERATION AND COMPLICATED SKULL FRACTURE, COMA < 1 HOUR OR NO COMA'
#  'ALCOHOL AND DRUG DEPENDENCE WITH REHABILITATION AND/OR DETOXIFICATION THERAPY'
#  'CESAREAN SECTION WITH STERILIZATION'
#  'SPINAL FUSION AND OTHER BACK AND NECK PROCEDURES EXCEPT FOR DISC PROCEDURES'
#  'HIV WITH ONE SIGNIFICANT HIV CONDITION OR WITHOUT SIGNIFICANT RELATED CONDITIONS'
#  'PROCEDURES FOR OBESITY'
#  'DRUG AND ALCOHOL ABUSE OR DEPENDENCE, LEFT AGAINST MEDICAL ADVICE'
#  'KIDNEY TRANSPLANT' 'UTERINE AND ADNEXA PROCEDURES FOR LEIOMYOMA'
#  'CHEST PAIN'
#  'VERTEBRAL AND INTERVERTEBRAL SPINAL PROCEDURES INCLUDING DISC PROCEDURES'
#  'DISORDERS OF PERSONALITY AND IMPULSE CONTROL' 'HYPERTENSION'
#  'TRANSIENT ISCHEMIA'
#  'POSTPARTUM AND POST ABORTION DIAGNOSES WITHOUT PROCEDURE'
#  'ALCOHOLIC LIVER DISEASE'
#  'TENDON, MUSCLE AND OTHER SOFT TISSUE PROCEDURES'
#  'MENTAL ILLNESS DIAGNOSIS WITH O.R. PROCEDURE'
#  'DIVERTICULITIS AND DIVERTICULOSIS'
#  'CVA AND PRECEREBRAL OCCLUSION WITH INFARCTION'
#  'MUSCULOSKELETAL AND OTHER PROCEDURES FOR MULTIPLE SIGNIFICANT TRAUMA'
#  'OTHER O.R. PROCEDURES FOR LYMPHATIC, HEMATOPOIETIC OR OTHER NEOPLASMS'
#  'ANAL AND PERINEAL PROCEDURES' 'PERIPHERAL AND OTHER VASCULAR DISORDERS'
#  'SPINAL DISORDERS AND INJURIES' 'ANTEPARTUM WITH O.R. PROCEDURE'
#  'HIV WITH MAJOR HIV RELATED CONDITION' 'COCAINE ABUSE AND DEPENDENCE'
#  'OTHER BLADDER PROCEDURES'
#  'DORSAL AND LUMBAR FUSION PROCEDURE EXCEPT FOR CURVATURE OF BACK'
#  'MODERATELY EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS'
#  'CARDIAC VALVE PROCEDURES WITH AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'REHABILITATION' 'ALCOHOL ABUSE AND DEPENDENCE'
#  'MAJOR CHEST AND RESPIRATORY TRAUMA'
#  'FRACTURE OF PELVIS OR DISLOCATION OF HIP'
#  'SKIN GRAFT, EXCEPT HAND, FOR MUSCULOSKELETAL AND CONNECTIVE TISSUE DIAGNOSES'
#  'URETHRAL AND TRANSURETHRAL PROCEDURES'
#  'ABORTION WITHOUT D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY'
#  'OTHER NON-HYPOVOLEMIC ELECTROLYTE DISORDERS'
#  'CRANIOTOMY FOR MULTIPLE SIGNIFICANT TRAUMA'
#  'OTHER HEPATOBILIARY, PANCREAS AND ABDOMINAL PROCEDURES'
#  'PROCEDURE WITH DIAGNOSIS OF REHABILITATION, AFTERCARE OR OTHER CONTACT WITH HEALTH SERVICES'
#  'THYROID DISORDERS'
#  'ABORTION WITH D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY'
#  'MALE REPRODUCTIVE SYSTEM DIAGNOSES EXCEPT MALIGNANCY'
#  'POSTPARTUM AND POST ABORTION DIAGNOSIS WITH O.R. PROCEDURE'
#  'VERTIGO AND OTHER LABYRINTH DISORDERS'
#  'TRACHEOSTOMY WITH MV >96 HOURS WITH EXTENSIVE PROCEDURE'
#  'DIGESTIVE MALIGNANCY' 'RESPIRATORY MALIGNANCY'
#  'HIV WITH MULTIPLE MAJOR HIV RELATED CONDITIONS'
#  'MAJOR ESOPHAGEAL DISORDERS'
#  'PRINCIPAL DIAGNOSIS INVALID AS DISCHARGE DIAGNOSIS'
#  'DEFIBRILLATOR IMPLANTS' 'CYSTIC FIBROSIS - PULMONARY DISEASE'
#  'MALIGNANCY OF HEPATOBILIARY SYSTEM AND PANCREAS'
#  'ACUTE AND SUBACUTE ENDOCARDITIS'
#  'VAGINAL DELIVERY WITH STERILIZATION AND/OR D&C'
#  'IMPLANTABLE HEART ASSIST SYSTEMS' 'ELECTIVE KNEE JOINT REPLACEMENT'
#  'OTHER CIRCULATORY SYSTEM PROCEDURES' 'MASTECTOMY PROCEDURES'
#  'GASTRIC FUNDOPLICATION'
#  'SKIN GRAFT FOR SKIN AND SUBCUTANEOUS TISSUE DIAGNOSES'
#  'ACUTE MYOCARDIAL INFARCTION'
#  'OTHER KIDNEY, URINARY TRACT AND RELATED PROCEDURES'
#  'CARDIAC STRUCTURAL AND VALVULAR DISORDERS'
#  'CORONARY BYPASS WITHOUT AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'BREAST PROCEDURES EXCEPT MASTECTOMY'
#  'MALFUNCTION, REACTION, COMPLICATION OF CARDIAC OR VASCULAR DEVICE OR PROCEDURE'
#  'MODERATELY EXTENSIVE O.R. PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT'
#  'MAJOR ABDOMINAL VASCULAR PROCEDURES'
#  'NON-ELECTIVE OR COMPLEX HIP JOINT REPLACEMENT'
#  'ANOXIC AND OTHER SEVERE BRAIN DAMAGE' 'SKIN ULCERS'
#  'ANGINA PECTORIS AND CORONARY ATHEROSCLEROSIS'
#  'KIDNEY AND URINARY TRACT PROCEDURES FOR MALIGNANCY'
#  'PERCUTANEOUS CARDIAC INTERVENTION WITH AMI'
#  'AMPUTATION OF LOWER LIMB EXCEPT TOES' 'CARDIOMYOPATHY'
#  'LOWER EXTREMITY ARTERIAL PROCEDURES'
#  'CHRONIC OBSTRUCTIVE PULMONARY DISEASE' 'MAJOR MALE PELVIC PROCEDURES'
#  'RENAL DIALYSIS ACCESS DEVICE PROCEDURES' 'ADRENAL PROCEDURES'
#  'CORONARY BYPASS WITH AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'NONSPECIFIC CVA AND PRECEREBRAL OCCLUSION WITHOUT INFARCTION'
#  'HIV WITH MULTIPLE SIGNIFICANT HIV RELATED CONDITIONS'
#  'PELVIC EVISCERATION, RADICAL HYSTERECTOMY AND OTHER RADICAL GYNECOLOGICAL PROCEDURES'
#  'UTERINE AND ADNEXA PROCEDURES FOR NON-OVARIAN AND NON-ADNEXAL MALIGNANCY'
#  'OTHER MALE REPRODUCTIVE SYSTEM AND RELATED PROCEDURES'
#  'MAJOR BLADDER PROCEDURES'
#  'CARDIAC CATHETERIZATION FOR CORONARY ARTERY DISEASE'
#  'LYMPHATIC AND OTHER MALIGNANCIES AND NEOPLASMS OF UNCERTAIN BEHAVIOR'
#  'CARDIAC ARREST AND SHOCK'
#  'MALFUNCTION, REACTION, COMPLICATION OF ORTHOPEDIC DEVICE OR PROCEDURE'
#  'LIVER TRANSPLANT AND/OR INTESTINAL TRANSPLANT'
#  'MALIGNANT BREAST DISORDERS'
#  'EXTENSIVE O.R. PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT'
#  'EXTENSIVE THIRD DEGREE BURNS WITHOUT SKIN GRAFT'
#  'PERCUTANEOUS STRUCTURAL CARDIAC PROCEDURES'
#  'TRANSURETHRAL PROSTATECTOMY'
#  'PERMANENT CARDIAC PACEMAKER IMPLANT WITHOUT AMI, HEART FAILURE OR SHOCK'
#  'CARDIAC PACEMAKER AND DEFIBRILLATOR REVISION EXCEPT DEVICE REPLACEMENT'
#  'SHOULDER AND ELBOW JOINT REPLACEMENT'
#  'OTHER MAJOR HEAD AND NECK PROCEDURES'
#  'OPEN EXTRACRANIAL VASCULAR PROCEDURES' 'EXTERNAL HEART ASSIST SYSTEMS'
#  'KIDNEY AND URINARY TRACT MALIGNANCY'
#  'INSERTION, REVISION AND REPLACEMENTS OF PACEMAKER AND OTHER CARDIAC DEVICES'
#  'RADIOTHERAPY' 'MALIGNANCY, MALE REPRODUCTIVE SYSTEM'
#  'PERMANENT CARDIAC PACEMAKER IMPLANT WITH AMI, HEART FAILURE OR SHOCK'
#  'DILATION AND CURETTAGE FOR NON-OBSTETRIC DIAGNOSES']
#
# APR MDC Code:
# [15  4  9 17  6 19 10 14 18  1  8 11 16  3 21 23 13 12  5 22  2 25  7 20
#   0 24]
#
# APR MDC Description:
# ['NEWBORNS AND OTHER NEONATES WITH CONDITIONS ORIGINATING IN THE PERINATAL PERIOD'
#  'DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM'
#  'DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEOUS TISSUE AND BREAST'
#  'MYELOPROLIFERATIVE DISEASES AND DISORDERS, AND POORLY DIFFERENTIATED NEOPLASM'
#  'DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM'
#  'MENTAL DISEASES AND DISORDERS'
#  'ENDOCRINE, NUTRITIONAL AND METABOLIC DISEASES AND DISORDERS'
#  'PREGNANCY, CHILDBIRTH AND THE PUERPERIUM'
#  'INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR UNSPECIFIED SITES)'
#  'DISEASES AND DISORDERS OF THE NERVOUS SYSTEM'
#  'DISEASES AND DISORDERS OF THE MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE'
#  'DISEASES AND DISORDERS OF THE KIDNEY AND URINARY TRACT'
#  'DISEASES AND DISORDERS OF THE BLOOD AND BLOOD FORMING ORGANS AND IMMUNOLOGICAL DISORDERS'
#  'DISEASES AND DISORDERS OF THE EAR, NOSE, MOUTH AND THROAT'
#  'INJURIES, POISONINGS AND TOXIC EFFECTS OF DRUGS'
#  'FACTORS INFLUENCING HEALTH STATUS AND OTHER CONTACTS WITH HEALTH SERVICES'
#  'DISEASES AND DISORDERS OF THE FEMALE REPRODUCTIVE SYSTEM'
#  'DISEASES AND DISORDERS OF THE MALE REPRODUCTIVE SYSTEM'
#  'DISEASES AND DISORDERS OF THE CIRCULATORY SYSTEM' 'BURNS'
#  'DISEASES AND DISORDERS OF THE EYE' 'MULTIPLE SIGNIFICANT TRAUMA'
#  'DISEASES AND DISORDERS OF THE HEPATOBILIARY SYSTEM AND PANCREAS'
#  'ALCOHOL/DRUG USE AND ALCOHOL/DRUG INDUCED ORGANIC MENTAL DISORDERS'
#  'PRE MDC' 'HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS']
#
# APR Severity of Illness Code:
# [3 2 1 4 0]
#
# APR Severity of Illness Description:
# ['Major' 'Moderate' 'Minor' 'Extreme' nan]
#
# APR Risk of Mortality:
# ['Minor' 'Moderate' 'Major' 'Extreme' nan]
#
# APR Medical Surgical Description:
# ['Medical' 'Surgical' 'Not Applicable']
#
# Payment Typology 1:
# ['Private Health Insurance' 'Medicaid' 'Self-Pay' 'Blue Cross/Blue Shield'
#  'Managed Care, Unspecified' 'Medicare' 'Federal/State/Local/VA'
#  'Miscellaneous/Other' 'Department of Corrections']
#
# Payment Typology 2:
# [nan 'Medicaid' 'Self-Pay' 'Private Health Insurance'
#  'Blue Cross/Blue Shield' 'Federal/State/Local/VA' 'Medicare'
#  'Managed Care, Unspecified' 'Miscellaneous/Other'
#  'Department of Corrections']
#
# Payment Typology 3:
# [nan 'Self-Pay' 'Medicaid' 'Private Health Insurance'
#  'Miscellaneous/Other' 'Blue Cross/Blue Shield' 'Medicare'
#  'Federal/State/Local/VA' 'Managed Care, Unspecified']
#
# Birth Weight:
# ['02200' nan '03300' '03000' '03900' '02600' '02700' '03800' '00700'
#  '01300' '02000' '03400' '03600' '03200' '01500' '03100' '02300' '04400'
#  '02900' '02800' '03700' '04500' '02400' '04000' '02100' '03500' '01600'
#  '01200' '04100' '01100' '02500' '01900' '04200' '00500' '04300' '00900'
#  '01400' '04700' '01800' '01700' '04600' '01000' '04800' '05900' '05100'
#  'UNKN' '05000' '00400' '00600' '00800' '09800']
#
# Emergency Department Indicator:
# ['N' 'Y']
#
# Total Charges:
# ['222,316.93' '74,852.95' '3,495.75' ... '34,669.21' '96,396.62'
#  '38,711.39']
#
# Total Costs:
# ['44,922.65' '16,076.28' '2,012.15' ... '4,634.61' '19,994.74' '8,805.60']

# %% [markdown]
# Checking for exact duplicate records and removing them

# %%
print(f"Duplicate records: {health_data.duplicated().sum()}")
health_data = health_data.drop_duplicates()
# Out:
# Duplicate records: 1

# %% [markdown]
# Treating missing values

# %% [markdown]
# Dropping columns having more than 50% missing values

# %%
missing_values_percentage = (health_data.isnull().mean() * 100)
print(missing_values_percentage.sort_values(ascending=False))

columns_to_drop = missing_values_percentage[missing_values_percentage > 50].index

health_data = health_data.drop(columns_to_drop, axis=1)
# Out:
# Payment Typology 3                     87.019481
# Birth Weight                           86.115445
# Payment Typology 2                     57.710308
# CCSR Procedure Code                    26.281051
# CCSR Procedure Description             26.281051
# Zip Code - 3 digits                     2.160086
# Operating Certificate Number            0.340014
# Hospital County                         0.320013
# Hospital Service Area                   0.320013
# Permanent Facility Id                   0.320013
# Total Costs                             0.188008
# APR Risk of Mortality                   0.036001
# APR Severity of Illness Description     0.036001
# Length of Stay                          0.000000
# Total Charges                           0.000000
# Emergency Department Indicator          0.000000
# Facility Name                           0.000000
# Age Group                               0.000000
# Payment Typology 1                      0.000000
# APR Medical Surgical Description        0.000000
# APR Severity of Illness Code            0.000000
# Ethnicity                               0.000000
# APR MDC Code                            0.000000
# APR DRG Description                     0.000000
# APR DRG Code                            0.000000
# Gender                                  0.000000
# Race                                    0.000000
# CCSR Diagnosis Description              0.000000
# CCSR Diagnosis Code                     0.000000
# Discharge Year                          0.000000
# Patient Disposition                     0.000000
# Type of Admission                       0.000000
# APR MDC Description                     0.000000
# dtype: float64

# %% [markdown]
# Dropping ['Operating Certificate Number','Discharge Year'] since they don't have any significant importance in the prediction and analysis

# %%
health_data = health_data.drop(['Operating Certificate Number','Discharge Year'], axis = 1)

# %% [markdown]
# Imputing missing values in
# - CCSR Procedure Code on the basis of mode of its grouped CCSR Diagnosis Code
# - CCSR Procedure Description on the basis of mode of its grouped CCSR Procedure Code

# %%
def map_and_fill_missing_values(dataframe, from_col, to_col):
   temp_df = dataframe.copy()

   map = temp_df.groupby(from_col)[to_col].agg(
      lambda x: x.value_counts().idxmax() if x.count() > 0 else None
   ).to_dict()
    
   temp_df[to_col] = temp_df[to_col].fillna(temp_df[from_col].map(map))
   
   return temp_df

# %%
health_data = map_and_fill_missing_values(health_data, "CCSR Diagnosis Code", "CCSR Procedure Code")

# %%
health_data = map_and_fill_missing_values(health_data, "CCSR Procedure Code", "CCSR Procedure Description")

# %% [markdown]
# Checking for missing values

# %%
health_data.isna().sum()
# Out:
# Hospital Service Area                   80
# Hospital County                         80
# Permanent Facility Id                   80
# Facility Name                            0
# Age Group                                0
# Zip Code - 3 digits                    540
# Gender                                   0
# Race                                     0
# Ethnicity                                0
# Length of Stay                           0
# Type of Admission                        0
# Patient Disposition                      0
# CCSR Diagnosis Code                      0
# CCSR Diagnosis Description               0
# CCSR Procedure Code                     16
# CCSR Procedure Description              16
# APR DRG Code                             0
# APR DRG Description                      0
# APR MDC Code                             0
# APR MDC Description                      0
# APR Severity of Illness Code             0
# APR Severity of Illness Description      9
# APR Risk of Mortality                    9
# APR Medical Surgical Description         0
# Payment Typology 1                       0
# Emergency Department Indicator           0
# Total Charges                            0
# Total Costs                             47
# dtype: int64

# %% [markdown]
# Dropping records having missing values since the count is negligible

# %%
health_data = health_data.dropna(axis=0)

health_data.isna().sum()
# Out:
# Hospital Service Area                  0
# Hospital County                        0
# Permanent Facility Id                  0
# Facility Name                          0
# Age Group                              0
# Zip Code - 3 digits                    0
# Gender                                 0
# Race                                   0
# Ethnicity                              0
# Length of Stay                         0
# Type of Admission                      0
# Patient Disposition                    0
# CCSR Diagnosis Code                    0
# CCSR Diagnosis Description             0
# CCSR Procedure Code                    0
# CCSR Procedure Description             0
# APR DRG Code                           0
# APR DRG Description                    0
# APR MDC Code                           0
# APR MDC Description                    0
# APR Severity of Illness Code           0
# APR Severity of Illness Description    0
# APR Risk of Mortality                  0
# APR Medical Surgical Description       0
# Payment Typology 1                     0
# Emergency Department Indicator         0
# Total Charges                          0
# Total Costs                            0
# dtype: int64

# %% [markdown]
# Imputing missing/unknown values of ["Gender", "Type of Admission"] columns with corresponding mode value

# %%
def impute_missing_values_with_mode(dataframe, column, missing_value=None):
    temp_df = dataframe.copy()
    mode_value = temp_df[column].mode()[0]
    temp_df[column] = temp_df[column].replace(missing_value, mode_value)
    return temp_df

# %%
health_data = impute_missing_values_with_mode(health_data, "Gender", missing_value="U")

# %%
health_data = impute_missing_values_with_mode(health_data, "Type of Admission", missing_value="Not Available")

# %% [markdown]
# Treating unknown ethinicity using race

# %%
mode_race_for_unknown_ethinicity = health_data[health_data["Ethnicity"] == "Unknown"]["Race"].mode()[0]
mode_ethinicity_for_selection = health_data[health_data["Race"] == mode_race_for_unknown_ethinicity]["Ethnicity"].mode()[0]
health_data["Ethnicity"] = health_data["Ethnicity"].replace("Unknown", mode_ethinicity_for_selection)

# %% [markdown]
# Converting to different data types:
# - Limiting "120 +" stay duration to 120 and converting column to integer type
# - Replacing "OOS" zip code with largest 3 digit integer and converting values to int type
# - Converting Permanent Facility Id to type int

# %%
health_data["Length of Stay"] = health_data["Length of Stay"].replace("120 +", "120").astype(int)

# %%
health_data["Zip Code - 3 digits"] = health_data["Zip Code - 3 digits"].replace("OOS", "999").astype(int)

# %%
health_data["Permanent Facility Id"] = health_data["Permanent Facility Id"].astype(int)

# %%
health_data["Total Charges"] = health_data["Total Charges"].replace(",", "", regex=True).astype(float)

# %%
health_data["Total Costs"] = health_data["Total Costs"].replace(",", "", regex=True).astype(float)

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24391 entries, 0 to 24999
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Hospital Service Area                24391 non-null  object
#  1   Hospital County                      24391 non-null  object
#  2   Permanent Facility Id                24391 non-null  int32
#  3   Facility Name                        24391 non-null  object
#  4   Age Group                            24391 non-null  object
#  5   Zip Code - 3 digits                  24391 non-null  int32
#  6   Gender                               24391 non-null  object
#  7   Race                                 24391 non-null  object
#  8   Ethnicity                            24391 non-null  object
#  9   Length of Stay                       24391 non-null  int32
#  10  Type of Admission                    24391 non-null  object
#  11  Patient Disposition                  24391 non-null  object
#  12  CCSR Diagnosis Code                  24391 non-null  object
#  13  CCSR Diagnosis Description           24391 non-null  object
#  14  CCSR Procedure Code                  24391 non-null  object
#  15  CCSR Procedure Description           24391 non-null  object
#  16  APR DRG Code                         24391 non-null  int64
#  17  APR DRG Description                  24391 non-null  object
#  18  APR MDC Code                         24391 non-null  int64
#  19  APR MDC Description                  24391 non-null  object
#  20  APR Severity of Illness Code         24391 non-null  int64
#  21  APR Severity of Illness Description  24391 non-null  object
#  22  APR Risk of Mortality                24391 non-null  object
#  23  APR Medical Surgical Description     24391 non-null  object
#  24  Payment Typology 1                   24391 non-null  object
#  25  Emergency Department Indicator       24391 non-null  object
#  26  Total Charges                        24391 non-null  float64
#  27  Total Costs                          24391 non-null  float64
# dtypes: float64(2), int32(3), int64(3), object(20)
# memory usage: 5.1+ MB

# %% [markdown]
# Normally distributing ["Total Charges", "Total Costs"] using Boxcox Power Transformation

# %%
health_data["Total Charges"] = stats.boxcox(health_data["Total Charges"])[0]
health_data["Total Costs"] = stats.boxcox(health_data["Total Costs"])[0]

# %% [markdown]
# Dealing with Outliers

# %%
def detect_and_impute_outliers(dataframe, column):
    temp_df = dataframe.copy()

    q1 = dataframe[column].quantile(0.25)
    q3 = dataframe[column].quantile(0.75)
    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    outlier_count = temp_df[(temp_df[column] < lower_bound) | (temp_df[column] > upper_bound)].shape[0]
    print(f"Number of outliers in {column}: {outlier_count}")

    temp_df[column] = temp_df[column].mask(temp_df[column] < lower_bound, lower_bound, axis=0)
    temp_df[column] = temp_df[column].mask(temp_df[column] > upper_bound, upper_bound, axis=0)
    return temp_df

# %%
health_data = detect_and_impute_outliers(health_data, "Total Charges")
# Out:
# Number of outliers in Total Charges: 396

# %%
health_data = detect_and_impute_outliers(health_data, "Total Costs")
# Out:
# Number of outliers in Total Costs: 443

# %%
health_data.head()
# Out:
#   Hospital Service Area Hospital County  Permanent Facility Id  \
# 0         New York City       Manhattan                   1458
# 1         New York City       Manhattan                   1464
# 2            Central NY        Tompkins                    977
# 3         New York City           Kings                   1306
# 4          Finger Lakes         Chemung                    116
#
#                                        Facility Name Age Group  \
# 0  New York-Presbyterian Hospital - New York Weil...   0 to 17
# 1  New York-Presbyterian Hospital - Columbia Pres...   0 to 17
# 2                    Cayuga Medical Center at Ithaca   0 to 17
# 3  New York - Presbyterian Brooklyn Methodist Hos...   0 to 17
# 4                         Arnot Ogden Medical Center   0 to 17
#
#    Zip Code - 3 digits Gender                    Race          Ethnicity  \
# 0                  104      F              Other Race   Spanish/Hispanic
# 1                  109      M                   White  Not Span/Hispanic
# 2                  148      M              Other Race  Not Span/Hispanic
# 3                  112      F  Black/African American  Not Span/Hispanic
# 4                  148      F                   White  Not Span/Hispanic
#
#    Length of Stay  ... APR MDC Code  \
# 0              10  ...           15
# 1               4  ...            4
# 2               3  ...           15
# 3               1  ...            9
# 4               1  ...           15
#
#                                  APR MDC Description  \
# 0  NEWBORNS AND OTHER NEONATES WITH CONDITIONS OR...
# 1   DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 2  NEWBORNS AND OTHER NEONATES WITH CONDITIONS OR...
# 3  DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEO...
# 4  NEWBORNS AND OTHER NEONATES WITH CONDITIONS OR...
#
#   APR Severity of Illness Code APR Severity of Illness Description  \
# 0                            3                               Major
# 1                            3                               Major
# 2                            2                            Moderate
# 3                            1                               Minor
# 4                            1                               Minor
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0                 Minor                          Medical
# 1              Moderate                          Medical
# 2                 Minor                          Medical
# 3                 Minor                          Medical
# 4                 Minor                          Medical
#
#          Payment Typology 1 Emergency Department Indicator  Total Charges  \
# 0  Private Health Insurance                              N       9.872085
# 1                  Medicaid                              Y       9.170213
# 2                  Self-Pay                              N       7.034587
# 3                  Medicaid                              Y       7.858378
# 4                  Medicaid                              N       6.783993
#
#   Total Costs
# 0    9.072055
# 1    8.330147
# 2    6.753241
# 3    6.952654
# 4    6.070277
#
# [5 rows x 28 columns]

# %% [markdown]
# Saving data for analytics

# %%
health_data.to_csv('../../datasets/electronic-health-record/output/transformed_electronic_health_record_dataset_for_analytics.csv', index=False)

# %% [markdown]
# Dropping redundant columns

# %%
for col in health_data.columns:
    print(f"{col}: {health_data[col].nunique()}")
# Out:
# Hospital Service Area: 8
# Hospital County: 56
# Permanent Facility Id: 191
# Facility Name: 190
# Age Group: 5
# Zip Code - 3 digits: 50
# Gender: 2
# Race: 4
# Ethnicity: 3
# Length of Stay: 106
# Type of Admission: 5
# Patient Disposition: 19
# CCSR Diagnosis Code: 376
# CCSR Diagnosis Description: 376
# CCSR Procedure Code: 290
# CCSR Procedure Description: 290
# APR DRG Code: 320
# APR DRG Description: 320
# APR MDC Code: 24
# APR MDC Description: 24
# APR Severity of Illness Code: 4
# APR Severity of Illness Description: 4
# APR Risk of Mortality: 4
# APR Medical Surgical Description: 2
# Payment Typology 1: 9
# Emergency Department Indicator: 2
# Total Charges: 23734
# Total Costs: 23656

# %%
redundant_columns = ["Facility Name", "CCSR Diagnosis Description", "CCSR Procedure Description", "APR DRG Description", "APR MDC Description", "APR Severity of Illness Description"]
health_data = health_data.drop(redundant_columns, axis=1)

# %%
for col in health_data.columns:
    if health_data[col].dtype == "object":
        print(f"{col}: {health_data[col].nunique()}")
# Out:
# Hospital Service Area: 8
# Hospital County: 56
# Age Group: 5
# Gender: 2
# Race: 4
# Ethnicity: 3
# Type of Admission: 5
# Patient Disposition: 19
# CCSR Diagnosis Code: 376
# CCSR Procedure Code: 290
# APR Risk of Mortality: 4
# APR Medical Surgical Description: 2
# Payment Typology 1: 9
# Emergency Department Indicator: 2

# %% [markdown]
# Encoding categorical data:
# - Target Encoding: ["Hospital Service Area", "Hospital County", "Patient Disposition", "CCSR Diagnosis Code", "CCSR Procedure Code"]
# - Label Encoding: ['Age Group']
# - Direct mapping: ['APR Risk of Mortality', 'Payment Typology 1']
# - One Hot Encoding: ["Gender", "Race", "Ethnicity", "Type of Admission", "APR Medical Surgical Description", "Emergency Department Indicator"]

# %%
target_encoding_columns = ["Hospital Service Area", "Hospital County", "Patient Disposition", "CCSR Diagnosis Code", "CCSR Procedure Code"]
for col in target_encoding_columns:
    health_data[col] = health_data[col].map(dict(health_data.groupby(col)["Length of Stay"].mean()))

# %%
health_data['Age Group'] = LabelEncoder().fit_transform(health_data['Age Group'])

# %%
health_data['APR Risk of Mortality'] = health_data['APR Risk of Mortality'].map({'Minor': 0, 'Moderate': 1, 'Major': 2, 'Extreme': 3})

# %%
temp_dict = dict(health_data['Payment Typology 1'].value_counts() / len(health_data))
health_data['Payment Typology 1'] = health_data['Payment Typology 1'].map(temp_dict)

# %%
for col in health_data.columns:
    if health_data[col].dtype == "object":
        print(f"{col}: {health_data[col].nunique()}")
# Out:
# Gender: 2
# Race: 4
# Ethnicity: 3
# Type of Admission: 5
# APR Medical Surgical Description: 2
# Emergency Department Indicator: 2

# %%
def one_hot_encoding(dataframe, columns):
    encoded_df = pd.get_dummies(dataframe, columns=columns)
    return encoded_df

# %%
one_hot_encoding_columns = ["Gender", "Race", "Ethnicity", "Type of Admission", "APR Medical Surgical Description", "Emergency Department Indicator"]

health_data = one_hot_encoding(health_data, one_hot_encoding_columns)

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24391 entries, 0 to 24999
# Data columns (total 34 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Hospital Service Area                      24391 non-null  float64
#  1   Hospital County                            24391 non-null  float64
#  2   Permanent Facility Id                      24391 non-null  int32
#  3   Age Group                                  24391 non-null  int32
#  4   Zip Code - 3 digits                        24391 non-null  int32
#  5   Length of Stay                             24391 non-null  int32
#  6   Patient Disposition                        24391 non-null  float64
#  7   CCSR Diagnosis Code                        24391 non-null  float64
#  8   CCSR Procedure Code                        24391 non-null  float64
#  9   APR DRG Code                               24391 non-null  int64
#  10  APR MDC Code                               24391 non-null  int64
#  11  APR Severity of Illness Code               24391 non-null  int64
#  12  APR Risk of Mortality                      24391 non-null  int64
#  13  Payment Typology 1                         24391 non-null  float64
#  14  Total Charges                              24391 non-null  float64
#  15  Total Costs                                24391 non-null  float64
#  16  Gender_F                                   24391 non-null  bool
#  17  Gender_M                                   24391 non-null  bool
#  18  Race_Black/African American                24391 non-null  bool
#  19  Race_Multi-racial                          24391 non-null  bool
#  20  Race_Other Race                            24391 non-null  bool
#  21  Race_White                                 24391 non-null  bool
#  22  Ethnicity_Multi-ethnic                     24391 non-null  bool
#  23  Ethnicity_Not Span/Hispanic                24391 non-null  bool
#  24  Ethnicity_Spanish/Hispanic                 24391 non-null  bool
#  25  Type of Admission_Elective                 24391 non-null  bool
#  26  Type of Admission_Emergency                24391 non-null  bool
#  27  Type of Admission_Newborn                  24391 non-null  bool
#  28  Type of Admission_Trauma                   24391 non-null  bool
#  29  Type of Admission_Urgent                   24391 non-null  bool
#  30  APR Medical Surgical Description_Medical   24391 non-null  bool
#  31  APR Medical Surgical Description_Surgical  24391 non-null  bool
#  32  Emergency Department Indicator_N           24391 non-null  bool
#  33  Emergency Department Indicator_Y           24391 non-null  bool
# dtypes: bool(18), float64(8), int32(4), int64(4)
# memory usage: 3.2 MB

# %%
health_data.to_csv('../../datasets/electronic-health-record/output/transformed_electronic_health_record_dataset.csv', index=False)
